# %%
from datetime import datetime

import eikon as ek
import pandas as pd

from utilities import columns, filter_dataset

# %% [markdown]
# # CONSTANTS

# %%
with open('key.secret') as file:
    KEY = file.read()

# %%
FILENAME = 'db.xlsx'

# %%
try:
    ek.set_app_key(KEY)
    bonds, err = ek.get_data(['CN151819SH='], 'TR.FirstAnnounceDate')
    # sanity check to prevent silent error
    sanity_check = bonds['First Announcement Date'][0]
    if sanity_check != '2019-07-11':
        raise ValueError(f'Sanity check not passed: {sanity_check}')
except ek.EikonError:
    raise ValueError('Please check key.secret, then run Eikon Desktop or Eikon API Proxy')

# %% [markdown]
# # CHECK DB

# %%
green_bonds = pd.read_excel(FILENAME, parse_dates=['Issue Date'])

# %%
col_set = set(green_bonds.columns)

if columns.col_names != col_set:
    if len(col_set) < len(columns.col_names):
        raise TypeError(
            f"{columns.col_names - set(green_bonds.columns)} ARE MISSING COLUMNS!")

    elif len(col_set) > len(columns.col_names):
        raise TypeError(f"{set(green_bonds.columns) - columns.col_names} ARE ADDITIONAL COLUMNS!\nPlease ADD THEM"
                        " to columns.py OR REMOVE THEM")

    else:
        raise TypeError(
            f"{columns.col_names - set(green_bonds.columns)} ARE MISSING COLUMNS!")

# %% [markdown]
# # FILTER DB

# %%
green_bonds = filter_dataset.filter_dataset(green_bonds)
# Out:
# Excluded 459 rows over 2323. Green bonds before 2012 must be due to errors and 2020 might pollute data due to COVID and year not finished yet.

# %% [markdown]
# # GET ADDITIONAL COLUMNS

# %%
ADDITIONAL_COLUMNS = ['TR.FirstAnnounceDate', 'TR.IssuerRating',
                      'TR.IsPublic', 'TR.FiParentLongName',
                      'TR.UltimateParentID', 'TR.FiCouponClassDescription']

# %%
# Moodys Rating has WR for non-active bonds, so only Issuer Rating is relevant
bonds, err = ek.get_data(green_bonds.ISIN.dropna().to_list(),
                         ADDITIONAL_COLUMNS)

# %%
bonds
# Out:
#         Instrument First Announcement Date Issuer Rating  \
# 0     XS1890845875              2019-02-05            A-
# 1     CND10000C3L5              2016-09-01           Ba1
# 2     XS2082433736              2019-11-26
# 3     CND100017CJ8              2017-09-08           AAA
# 4     CND10001WQ91              2019-01-02           AAA
# ...            ...                     ...           ...
# 1842  XS1207105161              2015-03-20             B
# 1843  US83417KFC71              2015-11-30
# 1844  XS1512929842              2016-10-28           P-1
# 1845  XS1566937154              2017-07-26           F1+
# 1846  US83417KBK34              2015-05-18
#
#      Organization Is Public Flag  \
# 0                          False
# 1                           True
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 1842                       False
# 1843                       False
# 1844                       False
# 1845                       False
# 1846                       False
#
#                                    Parent Long Name  Ultimate Parent Id  \
# 0                                      IBERDROLA SA          4295889602
# 1     XINJIANG GOLDWIND SCIENCE & TECHNOLOGY CO LTD          4295864350
# 2               AC ENERGY FINANCE INTERNATIONAL LTD          5067501160
# 3          CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)          5000036491
# 4          CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)          5000036491
# ...                                             ...                 ...
# 1842                              PAPREC HOLDING SA          5045515418
# 1843                                      TESLA INC          4297089638
# 1844       CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)          5000036491
# 1845                              RUE LA BOETIE SAS          4298458216
# 1846                                      TESLA INC          4297089638
#
#      Coupon Class Description
# 0             Floating Coupon
# 1             Floating Coupon
# 2                Fixed Coupon
# 3             Floating Coupon
# 4             Floating Coupon
# ...                       ...
# 1842             Fixed Coupon
# 1843             Fixed Coupon
# 1844             Fixed Coupon
# 1845             Fixed Coupon
# 1846             Fixed Coupon
#
# [1847 rows x 7 columns]

# %%
isin_merged = green_bonds.merge(right=bonds, how='outer', left_on='ISIN', right_on='Instrument')
isin_merged.drop(columns=['Instrument'])
# Out:
#                                                 Issuer  Ticker Coupon  \
# 0                           Iberdrola International BV   IBERD   3.25
# 1        Xinjiang Goldwind Science & Technology Co Ltd   XINGO    4.2
# 2                  Ac Energy Finance International Ltd   ACFTE   5.65
# 3                                  CGN Wind Energy Ltd  SASABZ   5.25
# 4                                  CGN Wind Energy Ltd  SASABZ   4.31
# ...                                                ...     ...    ...
# 1859                                 Paprec Holding SA   PAPIG  7.375
# 1860                       Tesla Energy Operations Inc   TSLAS    1.6
# 1861                     Bank of China (London Branch)  BKCHNL  1.875
# 1862  Credit Agricole Corporate and Investment Bank SA  CAGRAB   9.55
# 1863                       Tesla Energy Operations Inc   TSLAS   2.65
#
#                  Maturity Issue Date          ISIN Preferred RIC  \
# 0                     NaN 2019-02-12  XS1890845875  ES189084587=
# 1                     NaN 2016-09-01  CND10000C3L5  CN131656002=
# 2                     NaN 2019-12-04  XS2082433736  KY208243373=
# 3                     NaN 2017-09-14  CND100017CJ8  CN131751002=
# 4                     NaN 2019-01-07  CND10001WQ91  CN131900001=
# ...                   ...        ...           ...           ...
# 1859  2023-04-01 00:00:00 2015-03-27  XS1207105161           NaN
# 1860  2016-12-17 00:00:00 2015-12-17  US83417KFC71           NaN
# 1861  2019-11-09 00:00:00 2016-11-09  XS1512929842           NaN
# 1862  2020-07-27 00:00:00 2017-07-26  XS1566937154           NaN
# 1863  2018-05-21 00:00:00 2015-05-21  US83417KBK34           NaN
#
#      Principal Currency  Country of Issue Issuer Type  ...   SIC  \
# 0                  Euro   Eurobond Market   Corporate  ...  6726
# 1          Chinese Yuan  China (Mainland)   Corporate  ...  3511
# 2             US Dollar   Eurobond Market   Corporate  ...  6799
# 3          Chinese Yuan  China (Mainland)   Corporate  ...  4911
# 4          Chinese Yuan  China (Mainland)   Corporate  ...  4911
# ...                 ...               ...         ...  ...   ...
# 1859               Euro   Eurobond Market   Corporate  ...  6799
# 1860          US Dollar     United States   Corporate  ...  4911
# 1861          US Dollar   Eurobond Market   Corporate  ...  6081
# 1862       Turkish Lira   Eurobond Market   Corporate  ...  6029
# 1863          US Dollar     United States   Corporate  ...  4911
#
#               Use of Proceeds PBOC Bond Rating Current Coupon Class  \
# 0           Energy Efficiency              NaN         Fixed Coupon
# 1          Alternative Energy            AAA/1         Fixed Coupon
# 2           Energy Efficiency              NaN         Fixed Coupon
# 3     Eligible Green Projects            AAA/1         Fixed Coupon
# 4     Electric & Public Power            AAA/1         Fixed Coupon
# ...                       ...              ...                  ...
# 1859  Repay Intercompany Debt              NaN         Fixed Coupon
# 1860       Alternative Energy              NaN         Fixed Coupon
# 1861          Clean Transport              NaN         Fixed Coupon
# 1862       Alternative Energy              NaN         Fixed Coupon
# 1863       Alternative Energy              NaN         Fixed Coupon
#
#      First Announcement Date Issuer Rating  Organization Is Public Flag  \
# 0                 2019-02-05            A-                        False
# 1                 2016-09-01           Ba1                         True
# 2                 2019-11-26                                      False
# 3                 2017-09-08           AAA                        False
# 4                 2019-01-02           AAA                        False
# ...                      ...           ...                          ...
# 1859              2015-03-20             B                        False
# 1860              2015-11-30                                      False
# 1861              2016-10-28           P-1                        False
# 1862              2017-07-26           F1+                        False
# 1863              2015-05-18                                      False
#
#                                    Parent Long Name Ultimate Parent Id  \
# 0                                      IBERDROLA SA         4295889602
# 1     XINJIANG GOLDWIND SCIENCE & TECHNOLOGY CO LTD         4295864350
# 2               AC ENERGY FINANCE INTERNATIONAL LTD         5067501160
# 3          CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)         5000036491
# 4          CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)         5000036491
# ...                                             ...                ...
# 1859                              PAPREC HOLDING SA         5045515418
# 1860                                      TESLA INC         4297089638
# 1861       CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)         5000036491
# 1862                              RUE LA BOETIE SAS         4298458216
# 1863                                      TESLA INC         4297089638
#
#      Coupon Class Description
# 0             Floating Coupon
# 1             Floating Coupon
# 2                Fixed Coupon
# 3             Floating Coupon
# 4             Floating Coupon
# ...                       ...
# 1859             Fixed Coupon
# 1860             Fixed Coupon
# 1861             Fixed Coupon
# 1862             Fixed Coupon
# 1863             Fixed Coupon
#
# [1864 rows x 26 columns]

# %%
# get RICs from where we don't have ISIN
rics = green_bonds[green_bonds.ISIN.isna()]['Preferred RIC'].dropna().to_list()

# %%
bonds, err = ek.get_data(rics,
                         ADDITIONAL_COLUMNS)

# %%
bonds
# Out:
#      Instrument First Announcement Date Issuer Rating  \
# 0   CN114265SZ=              2017-12-01           AA+
# 1   CN143952SH=              2018-03-07           AAA
# 2   CN150502SH=              2018-06-21           AAA
# 3   CN150701SH=              2018-11-07           AAA
# 4   CN155057SH=              2018-11-29           AAA
# 5   CN155956SH=              2019-02-27           AAA
# 6   CN143518SH=              2018-03-14           AAA
# 7   CN143745SH=              2018-07-31           AAA
# 8   CN143525SH=              2018-08-15           AAA
# 9   CN150646SH=              2018-08-21            AA
# 10  CN143822SH=              2018-09-17            AA
# 11  CN114375SZ=              2018-09-20            AA
# 12  CN114415SZ=              2018-12-19            AA
# 13  CN151739SH=              2019-06-27           AAA
# 14  CN151819SH=              2019-07-11           AAA
# 15  CN163044SH=              2019-11-28           AAA
#
#    Organization Is Public Flag                          Parent Long Name  \
# 0                        False   SUZHOU GCL NEW ENERGY INVESTMENT CO LTD
# 1                         True                        HEBEI, PROVINCE OF
# 2                        False  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 3                        False  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 4                         True  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 5                         True                        HEBEI, PROVINCE OF
# 6                        False                 SHANGHAI, MUNICIPALITY OF
# 7                        False  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 8                         True  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 9                        False                           URUMQI, CITY OF
# 10                       False  CHINA, PEOPLE'S REPUBLIC OF (GOVERNMENT)
# 11                       False        QIANJIANG, DISTRICT OF (CHONGQING)
# 12                       False        QIANJIANG, DISTRICT OF (CHONGQING)
# 13                       False                      SICHUAN, PROVINCE OF
# 14                       False                      SICHUAN, PROVINCE OF
# 15                       False                            ZHUHAI,CITY OF
#
#     Ultimate Parent Id Coupon Class Description
# 0           4295871879             Fixed Coupon
# 1           5000040363             Fixed Coupon
# 2           5000036491             Fixed Coupon
# 3           5000036491             Fixed Coupon
# 4           5000036491             Fixed Coupon
# 5           5000040363             Fixed Coupon
# 6           5000063159          Variable Coupon
# 7           5000036491             Fixed Coupon
# 8           5000036491             Fixed Coupon
# 9           5050923137             Fixed Coupon
# 10          5000036491             Fixed Coupon
# 11          5037359824             Fixed Coupon
# 12          5037359824             Fixed Coupon
# 13          4297239484             Fixed Coupon
# 14          4297239484             Fixed Coupon
# 15          4296535063             Fixed Coupon

# %%
isin_merged.set_index('Preferred RIC', inplace=True)
bonds.set_index('Instrument', inplace=True)

# %%
# updating entire df gives error
for col in bonds.columns:
    isin_merged[col].fillna(bonds[col], inplace=True)

# %%
isin_merged.reset_index(inplace=True)

# %%
bonds, err = ek.get_data(list(isin_merged['Ultimate Parent Id'].dropna().unique().astype(str)),
                         ['TR.IsPublic'])

# %%
bonds.rename(columns={'Organization Is Public Flag': 'IsParentPublic'}, inplace=True)
bonds
# Out:
#      Instrument IsParentPublic
# 0    4295889602           True
# 1    4295864350           True
# 2    5067501160          False
# 3    5000036491          False
# 4    4295866323           True
# ..          ...            ...
# 501  4296014747          False
# 502  4296062372           True
# 503  4296698857          False
# 504  4295891741           True
# 505  4295878477           True
#
# [506 rows x 2 columns]

# %%
isin_merged['IsParentPublic'] = isin_merged['Ultimate Parent Id'].map(
    dict(zip(bonds.Instrument, bonds.IsParentPublic)))

# %%
isin_merged.rename({'Organization Is Public Flag': 'IsPublic'}, inplace=True)

# %%
isin_merged.to_csv('cleaned_green_bonds.csv', index=False)

# %% [markdown]
# # GET FINANCIAL DATA

# %%
CURRENT_YEAR = datetime.now().year
years_to_2012 = CURRENT_YEAR - 2012

assets, errors = ek.get_data(list(isin_merged.ISIN.dropna().unique()),
                             [
    f"TR.F.TotAssets(SDate=0,EDate=-{years_to_2012},Period=FY0,Frq=FY)",
    f'TR.ROAActValue(SDate=0FY,EDate=-{years_to_2012}FY,Period=FY0,Frq=FY)'
]
)

# %%
assets
# Out:
#         Instrument  Total Assets  Return On Assets - Actual
# 0     XS1890845875           NaN                        NaN
# 1     CND10000C3L5  1.030571e+11                      2.397
# 2     CND10000C3L5  8.136405e+10                      4.173
# 3     CND10000C3L5  7.278784e+10                      4.452
# 4     CND10000C3L5  6.443716e+10                      5.133
# ...            ...           ...                        ...
# 8354  US83417KBK34  1.342300e+09                        NaN
# 8355  US83417KBK34  8.131730e+08                        NaN
# 8356  US83417KBK34  3.712640e+08                        NaN
# 8357  US83417KBK34  1.641540e+08                        NaN
# 8358  US83417KBK34  7.880000e+07                        NaN
#
# [8359 rows x 3 columns]

# %%
grouped_assets = assets.dropna().groupby('Instrument')

# %%
assets_dict = dict()

for name, asset_table in grouped_assets:
    company_assets = asset_table.sort_index().reset_index()
    company_assets['Year'] = [CURRENT_YEAR - x for x in company_assets.index]
    assets_dict[name] = dict(zip(company_assets.Year, company_assets['Total Assets']))

# %%
test, errors = ek.get_data('FR0013310505=',
                           [f'TR.NetProfitActValue(SDate=0FY,EDate=-{years_to_2012}FY,Period=FY0,Frq=FY)'])

# %%
test['Net Income - Actual']
# Out:
# 0    2683000000
# 1    2425000000
# 2    2662000000
# 3    2477000000
# 4    2588000000
# 5    3027000000
# 6    5234000000
# 7    3800000000
# 8    3546218000
# Name: Net Income - Actual, dtype: Int64

# %%
[net_income / assets for net_income, assets in (zip(test['Net Income - Actual'], assets_dict['FR0013310505'].values()))]
# Out:
# [0.016790472674022016,
#  0.015777283314465654,
#  0.017730118556014387,
#  0.015627858850844483,
#  0.01610875275429795,
#  0.01831160581954569,
#  0.033565913346843494,
#  0.018819893618075022,
#  0.016616925167517924]

# %%
test, errors = ek.get_data('FR0013310505=',
                           f'TR.ROAActValue(SDate=0FY,EDate=-{years_to_2012}FY,Period=FY0,Frq=FY)')

# %%
test
# Out:
#       Instrument  Return On Assets - Actual
# 0  FR0013310505=                      1.710
# 1  FR0013310505=                      1.600
# 2  FR0013310505=                      1.540
# 3  FR0013310505=                      2.069
# 4  FR0013310505=                      1.588
# 5  FR0013310505=                      1.880
# 6  FR0013310505=                      2.867
# 7  FR0013310505=                      1.814
# 8  FR0013310505=                      1.780
