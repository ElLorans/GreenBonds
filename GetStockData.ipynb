# %% [markdown]
# # Get Stock Data

# %% [markdown]
# # PROBLEM: Tickers ARE WRONG

# %%
import datetime as dt

import eikon as ek
import pandas as pd
from pandas.errors import MergeError
import pandas_datareader.data as web
#from pandas_datareader._utils import RemoteDataError
from tqdm.auto import tqdm

from utilities import columns, filter_dataset
# Out:
# C:\Users\Lorenzo\miniconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
with open('key.secret') as file:
    KEY = file.read()
FILENAME = 'cleaned_green_bonds.csv'

# %%
try:
    ek.set_app_key(KEY)
    bonds, err = ek.get_data(['CN151819SH='], 'TR.FirstAnnounceDate')
    # sanity check to prevent silent error
    sanity_check = bonds['First Announcement Date'][0]
    if sanity_check != '2019-07-11':
        raise ValueError(f'Sanity check not passed: {sanity_check}')
except ek.EikonError:
    raise ValueError('Please check key.secret, then run Eikon Desktop or Eikon API Proxy')

# %%
FILENAME = 'cleaned_green_bonds.csv'
df = pd.read_csv(FILENAME,
                 parse_dates=['Issue Date', 'First Announcement Date'],
                 dtype={'Ultimate Parent ID': str})

# only public companies
df = df[df['Organization Is Public Flag'] == True]
df = filter_dataset.filter_dataset(df)
# Out:
# Excluded 0 rows over 456. Green bonds before 2012 must be due to errors and 2020 might pollute data due to COVID and year not finished yet.

# %%
df.columns
# Out:
# Index(['Preferred RIC', 'Issuer', 'Ticker', 'Coupon', 'Maturity', 'Issue Date',
#        'ISIN', 'Principal Currency', 'Country of Issue', 'Issuer Type',
#        'Instrument Type', 'Amount Issued (USD)', 'Green Bond', 'Sector',
#        'TRBC Sector', 'Country of Incorporation', 'SIC', 'Use of Proceeds',
#        'PBOC Bond Rating', 'Current Coupon Class', 'Instrument',
#        'First Announcement Date', 'Issuer Rating',
#        'Organization Is Public Flag', 'Parent Long Name', 'Ultimate Parent Id',
#        'Coupon Class Description', 'IsParentPublic'],
#       dtype='object')

# %%
pivot_column = 'Country of Incorporation'

country_count = pd.pivot_table(df[[pivot_column, 'Ticker']],
               index=[pivot_column],
               aggfunc='count')
country_count
# Out:
#                           Ticker
# Country of Incorporation
# Australia                     11
# Austria                        7
# Belgium                        1
# Bermuda                        5
# Brazil                        10
# Canada                         6
# Cayman Islands                 6
# Chile                          4
# China (Mainland)              55
# Colombia                       2
# Denmark                        8
# Finland                        6
# France                        43
# Germany                        8
# Hong Kong                      3
# India                          8
# Italy                         13
# Japan                         70
# Lithuania                      2
# Luxembourg                     2
# Mexico                         3
# Morocco                        1
# Netherlands                    9
# New Zealand                   11
# Nigeria                        1
# Norway                         9
# Peru                           3
# Philippines                    3
# Portugal                       1
# Singapore                      5
# South Africa                   3
# South Korea                    9
# Spain                          7
# Sweden                        67
# Switzerland                    8
# Taiwan                         4
# Thailand                      11
# Turkey                         1
# United Arab Emirates           2
# United Kingdom                 8
# United States                 20

# %%
country_count['Ticker'].index
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Bermuda', 'Brazil', 'Canada',
#        'Cayman Islands', 'Chile', 'China (Mainland)', 'Colombia', 'Denmark',
#        'Finland', 'France', 'Germany', 'Hong Kong', 'India', 'Italy', 'Japan',
#        'Lithuania', 'Luxembourg', 'Mexico', 'Morocco', 'Netherlands',
#        'New Zealand', 'Nigeria', 'Norway', 'Peru', 'Philippines', 'Portugal',
#        'Singapore', 'South Africa', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'United Arab Emirates',
#        'United Kingdom', 'United States'],
#       dtype='object', name='Country of Incorporation')

# %%
country_to_index = {'Australia': '^AXJO',
                    'Austria': '^ATX',
                    'Belgium': '^BFX',
                    #'Bermuda': '^BSX',
                    'Brazil': '^BVSP',
                    'Canada': '^GSPTSE',
                    # 'Cayman Islands': None, # ?????
                    #'Chile': '^IPSA',
                    'China (Mainland)': '000001.SS',  # ???
                    #'Colombia': '^SPCOLCSP',
                    #'Denmark': '^OMXC20',
                    'Finland': '^OMXH25',
                    'France': '^FCHI',
                    'Germany': '^GDAXI',
                    'Hong Kong': '^HSI',
                    'India': '^BSESN',
                    #'Italy': 'FTSEMIB.MI',
                    'Japan': '^N225',
                    'Lithuania': '^OMXVGI',
                    #'Luxembourg': 'MCXNUK.L',
                    'Mexico': '^MXX',
                    #'Morocco': '^NQMAEUR',  # ??
                    'Netherlands': '^AEX',
                    'New Zealand': '^NZ50',
                    # 'Nigeria', # ??????
                    #'Norway': 'OBX.OL',
                    'Peru': '^SPBLPGPT',
                    'Philippines': 'PSEI.PS',
                    #'Portugal': 'PSI20.LS',
                    #'Singapore': '^STI',
                    'South Africa': 'JSEJF',
                    'South Korea': '^KS11',
                    'Spain': '^IBEX',
                    'Sweden': '^OMX',
                    'Switzerland': '^SSMI',
                    'Taiwan': '^TWII',
                    #'Thailand': '^SET.BK',
                    #'Turkey': 'XU100.IS',
                    'United Arab Emirates': 'UAE',
                    #'United Kingdom': 'FT30.L',
                    'United States': '^GSPC'
                    }

# %%
web.DataReader('^FTSE', 'yahoo', '2019-10-1', '2020-10-1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     156             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 157             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     158         except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-70-81f0e3223079> in <module>
# ----> 1 web.DataReader('^FTSE', 'yahoo', '2019-10-1', '2020-10-1')
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\miniconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     385             retry_count=retry_count,
#     386             pause=pause,
# --> 387             session=session,
#     388         ).read()
#     389
#
# ~\miniconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     249         # If a single symbol, (e.g., 'GOOG')
#     250         if isinstance(self.symbols, (string_types, int)):
# --> 251             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     252         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     253         elif isinstance(self.symbols, DataFrame):
#
# ~\miniconda3\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     158         except KeyError:
#     159             msg = "No data fetched for symbol {} using {}"
# --> 160             raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
#     161
#     162         # price data
#
# RemoteDataError: No data fetched for symbol ^FTSE using YahooDailyReader

# %%
for k, v in country_to_index.items():
    print(k)
    web.DataReader(v, 'yahoo', '2019-10-10', '2020-10-10')
# Out:
# United Arab Emirates
# United Kingdom
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-9d4002f117b1> in <module>
#       1 for k, v in country_to_index.items():
#       2     print(k)
# ----> 3     web.DataReader(v, 'yahoo', '2019-10-10', '2020-10-10')
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\miniconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     385             retry_count=retry_count,
#     386             pause=pause,
# --> 387             session=session,
#     388         ).read()
#     389
#
# ~\miniconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     249         # If a single symbol, (e.g., 'GOOG')
#     250         if isinstance(self.symbols, (string_types, int)):
# --> 251             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     252         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     253         elif isinstance(self.symbols, DataFrame):
#
# ~\miniconda3\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     163         prices = DataFrame(data["prices"])
#     164         prices.columns = [col.capitalize() for col in prices.columns]
# --> 165         prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#     166
#     167         if "Data" in prices.columns:
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
min_date = min(df['First Announcement Date'])
max_date = max(df['First Announcement Date'])

starting_date = str((first_date - dt.timedelta(280)).date())
ending_date = str((last_date + dt.timedelta(80)).date())

# %%
# ClosePrice gives different results from PriceClose...
# see https://community.developers.refinitiv.com/questions/57842/get-data-inconsistent-between-an-index-and-a-singl.html
# ClosePrice appears to be superior as it incorporates specific calendar holidays

# convert Ultimate Parent Id to List[str] and remove .0
identifiers = list(df['Ultimate Parent Id'].astype(
    str).str.split('.', expand=True)[0].unique())

stock_prices, err = ek.get_data(
    identifiers,
    ['TR.ClosePrice.date', 'TR.ClosePrice'],
    {'SDate': starting_date,
     'EDate': ending_date})

# %%
stock_prices

# %%
stock_prices = stock_prices.pivot(index='Instrument', columns='Date', values='Close Price').transpose()

# %%
web.DataReader(, 'yahoo', str((first_date - dt.timedelta(280)).date()),
               str((last_date + dt.timedelta(80)).date()))
# Out:
# Attributes    Adj Close                     Close                      High  \
# Symbols           ^GSPC        ^AXJO        ^GSPC        ^AXJO        ^GSPC
# Date
# 2011-07-21  1343.800049  4556.000000  1343.800049  4556.000000  1347.000000
# 2011-07-22  1345.020020  4602.899902  1345.020020  4602.899902  1346.099976
# 2011-07-25  1337.430054  4530.399902  1337.430054  4530.399902  1344.319946
# 2011-07-26  1331.939941  4573.299805  1331.939941  4573.299805  1338.510010
# 2011-07-27  1304.890015  4537.399902  1304.890015  4537.399902  1331.910034
# ...                 ...          ...          ...          ...          ...
# 2020-03-04  3130.120117  6395.700195  3130.120117  6395.700195  3130.969971
# 2020-03-05  3023.939941  6216.200195  3023.939941  6216.200195  3083.040039
# 2020-03-06  2972.370117          NaN  2972.370117          NaN  2985.929932
# 2020-03-08          NaN  5760.600098          NaN  5760.600098          NaN
# 2020-03-09  2746.560059  5939.600098  2746.560059  5939.600098  2863.889893
#
# Attributes                       Low                      Open               \
# Symbols           ^AXJO        ^GSPC        ^AXJO        ^GSPC        ^AXJO
# Date
# 2011-07-21  4576.100098  1325.650024  4551.299805  1325.650024  4551.299805
# 2011-07-22  4612.200195  1336.949951  4565.299805  1343.800049  4565.299805
# 2011-07-25  4595.399902  1331.089966  4529.200195  1344.319946  4595.299805
# 2011-07-26  4582.700195  1329.589966  4536.200195  1337.390015  4536.299805
# 2011-07-27  4570.500000  1303.489990  4536.600098  1331.910034  4564.600098
# ...                 ...          ...          ...          ...          ...
# 2020-03-04  6447.100098  3034.379883  6325.399902  3045.750000  6325.399902
# 2020-03-05  6395.700195  2999.830078  6216.200195  3075.699951  6395.700195
# 2020-03-06          NaN  2901.540039          NaN  2954.199951          NaN
# 2020-03-08  6216.200195          NaN  5760.600098          NaN  6216.200195
# 2020-03-09  5939.600098  2734.429932  5538.899902  2863.889893  5760.600098
#
# Attributes        Volume
# Symbols            ^GSPC      ^AXJO
# Date
# 2011-07-21  4.837430e+09        0.0
# 2011-07-22  3.522830e+09        0.0
# 2011-07-25  3.536890e+09        0.0
# 2011-07-26  4.007050e+09        0.0
# 2011-07-27  3.479040e+09        0.0
# ...                  ...        ...
# 2020-03-04  5.035480e+09   989800.0
# 2020-03-05  5.575550e+09   959400.0
# 2020-03-06  6.552140e+09        NaN
# 2020-03-08           NaN  1444300.0
# 2020-03-09  8.423050e+09  1803100.0
#
# [2448 rows x 12 columns]

# %%
indexes, err = ek.get_data(
    '0#.SPX',
    ['TR.PriceClose.date', 'TR.PriceClose'],
    {'SDate': str((first_date - dt.timedelta(280)).date()),
     'EDate': str((last_date + dt.timedelta(80)).date())})
# Out:
# 2020-10-18 18:01:06,554 P[12040] [MainThread 11876] UDF Core request failed. Gateway Time-out
# ---------------------------------------------------------------------------
# EikonError                                Traceback (most recent call last)
# <ipython-input-17-82cabdb0bdf6> in <module>
#       3     ['TR.PriceClose.date', 'TR.PriceClose'],
#       4     {'SDate': str((first_date - dt.timedelta(280)).date()),
# ----> 5      'EDate': str((last_date + dt.timedelta(80)).date())})
#
# ~\miniconda3\lib\site-packages\eikon\data_grid.py in get_data(instruments, fields, parameters, field_name, raw_output, debug)
#     188         payload = {'requests': [payload]}
#     189
# --> 190     result = eikon.json_requests.send_json_request(_endpoint, payload, debug=debug)
#     191
#     192     if result.get('responses'):
#
# ~\miniconda3\lib\site-packages\eikon\json_requests.py in send_json_request(entity, payload, debug)
#     125                         ticket = _check_ticket_async(result)
#     126
# --> 127                 _check_server_error(result)
#     128                 return result
#     129             else:
#
# ~\miniconda3\lib\site-packages\eikon\json_requests.py in _check_server_error(server_response)
#     201             status, reason_phrase, version, content, headers = error_message.split(',')[:5]
#     202         logger.error(error_message)
# --> 203         raise EikonError(int(server_response['ErrorCode']), error_message)
#     204
#     205     # check DataGrid response (server response is JSON and it can contain error + transactionId keys)
#
# EikonError: Error code 2504 | UDF Core request failed. Gateway Time-out

# %%
indexes

# %%
data.columns
# Out:
# Index(['Instrument', 'Date', 'Price Close'], dtype='object')

# %%
data = bonds.copy()
data['Date'] = pd.to_datetime(data['Date'])
#data.set_index('Date', inplace = True)

# %%
data.head()
# Out:
#    Instrument                      Date  Price Close
# 0  4295864350 2011-07-21 00:00:00+00:00    10.291925
# 1  4295864350 2011-07-22 00:00:00+00:00    10.284924
# 2  4295864350 2011-07-25 00:00:00+00:00     9.815836
# 3  4295864350 2011-07-26 00:00:00+00:00     9.857844
# 4  4295864350 2011-07-27 00:00:00+00:00     9.934859

# %% [raw]
# a = pd.DataFrame()
#
# for instrument, dataframe in bonds.set_index('Date').groupby('Instrument'):
#     #dataframe.index.astype('datetime64[ns]', copy=False)
#     dataframe.rename(columns={'Price Close': instrument}, inplace=True)
#     dataframe.drop(columns='Instrument', inplace=True)
#
#     if len(a.index) == 0:
#         a = dataframe.copy()
#     else:
#         a[instrument] = dataframe[instrument]
#         #a = a.merge(dataframe, how='outer', right_on=dataframe.index, left_on=a.index)

# %%
bonds
# Out:
#         Instrument                  Date  Price Close
# 0       4295864350  2011-07-21T00:00:00Z    10.291925
# 1       4295864350  2011-07-22T00:00:00Z    10.284924
# 2       4295864350  2011-07-25T00:00:00Z     9.815836
# 3       4295864350  2011-07-26T00:00:00Z     9.857844
# 4       4295864350  2011-07-27T00:00:00Z     9.934859
# ...            ...                   ...          ...
# 400098  4296062372  2020-03-03T00:00:00Z     8.300000
# 400099  4296062372  2020-03-04T00:00:00Z     8.300000
# 400100  4296062372  2020-03-05T00:00:00Z     8.540000
# 400101  4296062372  2020-03-06T00:00:00Z     8.400000
# 400102  4296062372  2020-03-09T00:00:00Z     8.150000
#
# [400103 rows x 3 columns]

# %%
b
# Out:
# Index(['2011-07-21T00:00:00Z', '2011-07-22T00:00:00Z', '2011-07-25T00:00:00Z',
#        '2011-07-26T00:00:00Z', '2011-07-27T00:00:00Z', '2011-07-28T00:00:00Z',
#        '2011-07-29T00:00:00Z', '2011-08-01T00:00:00Z', '2011-08-02T00:00:00Z',
#        '2011-08-03T00:00:00Z',
#        ...
#        '2020-02-25T00:00:00Z', '2020-02-26T00:00:00Z', '2020-02-27T00:00:00Z',
#        '2020-02-28T00:00:00Z', '2020-03-02T00:00:00Z', '2020-03-03T00:00:00Z',
#        '2020-03-04T00:00:00Z', '2020-03-05T00:00:00Z', '2020-03-06T00:00:00Z',
#        '2020-03-09T00:00:00Z'],
#       dtype='object', name='Date', length=2187)

# %%
bonds.set_index('Date')
# Out:
#                       Instrument  Price Close
# Date
# 2011-07-21T00:00:00Z  4295864350    10.291925
# 2011-07-22T00:00:00Z  4295864350    10.284924
# 2011-07-25T00:00:00Z  4295864350     9.815836
# 2011-07-26T00:00:00Z  4295864350     9.857844
# 2011-07-27T00:00:00Z  4295864350     9.934859
# ...                          ...          ...
# 2020-03-03T00:00:00Z  4296062372     8.300000
# 2020-03-04T00:00:00Z  4296062372     8.300000
# 2020-03-05T00:00:00Z  4296062372     8.540000
# 2020-03-06T00:00:00Z  4296062372     8.400000
# 2020-03-09T00:00:00Z  4296062372     8.150000
#
# [400103 rows x 2 columns]

# %%
def get_stock_data(stock: str, announcement_date) -> None:
    """
    Download from Yahoo stock Close price in period [-220, 60] around announcement_date.
    :param stock: str of stock ticker (e.g.: AAPL)
    :return: None
    """
    start = announcement_date - dt.timedelta(420)
    end = announcement_date + dt.timedelta(120)
    try:
        df = web.DataReader(stock.upper(), 'yahoo', start, end)
    except Exception as e:
        print(stock, ':', e)
        return None
    
    # >= announcement_date might be a non-trading day, so get first day that is greater or equal to announcement.
    announcement_date_position = (df.index>=announcement_date).searchsorted(1)
    df = df.iloc[announcement_date_position-220: announcement_date_position+60]
    return df.Close

# %%
len(set(zip(df.Ticker, df['First Announcement Date'])))
# Out:
# 1274

# %%
is_private = dict()
results = dict()

# %%
for ticker, announcement_date in tqdm(set(zip(df.Ticker, df['First Announcement Date']))):
    if is_private.get(ticker) is not True:
        results[(ticker, announcement_date)] = get_stock_data(ticker, announcement_date)
        
        if results[(ticker, announcement_date)] is None:
            is_private[ticker] = True
        else:
            print(ticker, 'found prices')
            is_private[ticker] = False
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1274.0), HTML(value='')))
# EAXX : No data fetched for symbol EAXX using YahooDailyReader
# KOMBK : No data fetched for symbol KOMBK using YahooDailyReader
# ZHGOVE : No data fetched for symbol ZHGOVE using YahooDailyReader
# ENGIE : No data fetched for symbol ENGIE using YahooDailyReader
# CABKO : No data fetched for symbol CABKO using YahooDailyReader
# GETP : No data fetched for symbol GETP using YahooDailyReader
# CAGRAF : No data fetched for symbol CAGRAF using YahooDailyReader
# ELLKV : No data fetched for symbol ELLKV using YahooDailyReader
# SUMFGI : No data fetched for symbol SUMFGI using YahooDailyReader
# FRNYKR : No data fetched for symbol FRNYKR using YahooDailyReader
# SMFRS : No data fetched for symbol SMFRS using YahooDailyReader
# BNP : 'Date'
# HSBABB : No data fetched for symbol HSBABB using YahooDailyReader
# MNDEFA : No data fetched for symbol MNDEFA using YahooDailyReader
# VWS : No data fetched for symbol VWS using YahooDailyReader
# VATTE : No data fetched for symbol VATTE using YahooDailyReader
# ZHDHQ : No data fetched for symbol ZHDHQ using YahooDailyReader
# VASKNV : No data fetched for symbol VASKNV using YahooDailyReader
# HRSEG : No data fetched for symbol HRSEG using YahooDailyReader
# ATRLJ : No data fetched for symbol ATRLJ using YahooDailyReader
# JRCTT : No data fetched for symbol JRCTT using YahooDailyReader
# CTDM : No data fetched for symbol CTDM using YahooDailyReader
# SFFHOS : No data fetched for symbol SFFHOS using YahooDailyReader
# IREDA : No data fetched for symbol IREDA using YahooDailyReader
# AKUOE : No data fetched for symbol AKUOE using YahooDailyReader
# RWI : No data fetched for symbol RWI using YahooDailyReader
# NHRCB : No data fetched for symbol NHRCB using YahooDailyReader
# INGTR : No data fetched for symbol INGTR using YahooDailyReader
# PLAZL : No data fetched for symbol PLAZL using YahooDailyReader
# RFSHW : No data fetched for symbol RFSHW using YahooDailyReader
# CAGRAB : No data fetched for symbol CAGRAB using YahooDailyReader
# BTHLL : No data fetched for symbol BTHLL using YahooDailyReader
# NRGEY : No data fetched for symbol NRGEY using YahooDailyReader
# NRWBK : No data fetched for symbol NRWBK using YahooDailyReader
# BYWG : No data fetched for symbol BYWG using YahooDailyReader
# TOKYO : No data fetched for symbol TOKYO using YahooDailyReader
# SPRBG : No data fetched for symbol SPRBG using YahooDailyReader
# ALNDR : No data fetched for symbol ALNDR using YahooDailyReader
# EWRSFY : No data fetched for symbol EWRSFY using YahooDailyReader
# FDSPA : No data fetched for symbol FDSPA using YahooDailyReader
# YPBTRM : No data fetched for symbol YPBTRM using YahooDailyReader
# SRMIF : No data fetched for symbol SRMIF using YahooDailyReader
# URW : No data fetched for symbol URW using YahooDailyReader
# PPSIB : No data fetched for symbol PPSIB using YahooDailyReader
# RECM : 'Date'
# EEWCA : No data fetched for symbol EEWCA using YahooDailyReader
# CNLYP : No data fetched for symbol CNLYP using YahooDailyReader
# BARIV : No data fetched for symbol BARIV using YahooDailyReader
# CBKG : No data fetched for symbol CBKG using YahooDailyReader
# CQTGB : No data fetched for symbol CQTGB using YahooDailyReader
# ICBAFH : No data fetched for symbol ICBAFH using YahooDailyReader
# ATTND : No data fetched for symbol ATTND using YahooDailyReader
# OERBO : No data fetched for symbol OERBO using YahooDailyReader
# HUZHU : No data fetched for symbol HUZHU using YahooDailyReader
# SOGFJ : No data fetched for symbol SOGFJ using YahooDailyReader
# SOPWR : No data fetched for symbol SOPWR using YahooDailyReader
# SOGRP : No data fetched for symbol SOGRP using YahooDailyReader
# SBAB : No data fetched for symbol SBAB using YahooDailyReader
# AFSUK : No data fetched for symbol AFSUK using YahooDailyReader
# NANBK : No data fetched for symbol NANBK using YahooDailyReader
# BAMWAF : No data fetched for symbol BAMWAF using YahooDailyReader
# INGBK : No data fetched for symbol INGBK using YahooDailyReader
# BEJINR : No data fetched for symbol BEJINR using YahooDailyReader
# TSLAS : No data fetched for symbol TSLAS using YahooDailyReader
# DAIOP : No data fetched for symbol DAIOP using YahooDailyReader
# ICBCA : No data fetched for symbol ICBCA using YahooDailyReader
# KLOV : No data fetched for symbol KLOV using YahooDailyReader
# ALUPTT : No data fetched for symbol ALUPTT using YahooDailyReader
# ZJDQCB : No data fetched for symbol ZJDQCB using YahooDailyReader
# SIHRB : No data fetched for symbol SIHRB using YahooDailyReader
# VVIN : 'Date'
# CYPRF : No data fetched for symbol CYPRF using YahooDailyReader
# TAISHA : No data fetched for symbol TAISHA using YahooDailyReader
# KDB : No data fetched for symbol KDB using YahooDailyReader
# IBERD : No data fetched for symbol IBERD using YahooDailyReader
# TOFINA : No data fetched for symbol TOFINA using YahooDailyReader
# GEOGF : No data fetched for symbol GEOGF using YahooDailyReader
# MALMO : No data fetched for symbol MALMO using YahooDailyReader
# BIC : No data fetched for symbol BIC using YahooDailyReader
# KFW : No data fetched for symbol KFW using YahooDailyReader
# CECWP : No data fetched for symbol CECWP using YahooDailyReader
# EIBKCM : No data fetched for symbol EIBKCM using YahooDailyReader
# QDRCB : No data fetched for symbol QDRCB using YahooDailyReader
# CPPIBC : No data fetched for symbol CPPIBC using YahooDailyReader
# ISAAC : No data fetched for symbol ISAAC using YahooDailyReader
# BKJIJ : No data fetched for symbol BKJIJ using YahooDailyReader
# GTBRG : No data fetched for symbol GTBRG using YahooDailyReader
# SASAEJ : No data fetched for symbol SASAEJ using YahooDailyReader
# OSTND : No data fetched for symbol OSTND using YahooDailyReader
# IOFX : No data fetched for symbol IOFX using YahooDailyReader
# NEWDVH : No data fetched for symbol NEWDVH using YahooDailyReader
# ARGZ : No data fetched for symbol ARGZ using YahooDailyReader
# SOGNTW : No data fetched for symbol SOGNTW using YahooDailyReader
# YIWUGO : No data fetched for symbol YIWUGO using YahooDailyReader
# KLED : No data fetched for symbol KLED using YahooDailyReader
# SCMANT : No data fetched for symbol SCMANT using YahooDailyReader
# SOGNSI : No data fetched for symbol SOGNSI using YahooDailyReader
# NORDLD : No data fetched for symbol NORDLD using YahooDailyReader
# DFC : 'Date'
# KGYEYT : No data fetched for symbol KGYEYT using YahooDailyReader
# GRKOED : No data fetched for symbol GRKOED using YahooDailyReader
# MODLA : No data fetched for symbol MODLA using YahooDailyReader
# ADNARE : No data fetched for symbol ADNARE using YahooDailyReader
# ANAFN : No data fetched for symbol ANAFN using YahooDailyReader
# TORNT : No data fetched for symbol TORNT using YahooDailyReader
# DANSKT : NaTType does not support timetuple
# HRAMLP : No data fetched for symbol HRAMLP using YahooDailyReader
# TELHY : No data fetched for symbol TELHY using YahooDailyReader
# AGBKC : No data fetched for symbol AGBKC using YahooDailyReader
# KEPCO : No data fetched for symbol KEPCO using YahooDailyReader
# BNGBA : No data fetched for symbol BNGBA using YahooDailyReader
# JHFA : No data fetched for symbol JHFA using YahooDailyReader
# VERGE : No data fetched for symbol VERGE using YahooDailyReader
# ICBACF : No data fetched for symbol ICBACF using YahooDailyReader
# SCAA : No data fetched for symbol SCAA using YahooDailyReader
# ARISE : No data fetched for symbol ARISE using YahooDailyReader
# NJGVKJ : No data fetched for symbol NJGVKJ using YahooDailyReader
# SWEDX : No data fetched for symbol SWEDX using YahooDailyReader
# CACTC : No data fetched for symbol CACTC using YahooDailyReader
# LGCHE : No data fetched for symbol LGCHE using YahooDailyReader
# SAGA : No data fetched for symbol SAGA using YahooDailyReader
# HUISH : No data fetched for symbol HUISH using YahooDailyReader
# FUXIN : No data fetched for symbol FUXIN using YahooDailyReader
# ASJAT : No data fetched for symbol ASJAT using YahooDailyReader
# BCPXZ : No data fetched for symbol BCPXZ using YahooDailyReader
# CHGQCJ : No data fetched for symbol CHGQCJ using YahooDailyReader
# HUMLG : No data fetched for symbol HUMLG using YahooDailyReader
# RANIC : No data fetched for symbol RANIC using YahooDailyReader
# JENEN : No data fetched for symbol JENEN using YahooDailyReader
# CCTCE : No data fetched for symbol CCTCE using YahooDailyReader
# WHGVTS : No data fetched for symbol WHGVTS using YahooDailyReader
# NABNY : No data fetched for symbol NABNY using YahooDailyReader
# SASEPS : No data fetched for symbol SASEPS using YahooDailyReader
# GRKOEO : No data fetched for symbol GRKOEO using YahooDailyReader
# AKDHU : No data fetched for symbol AKDHU using YahooDailyReader
# OSLOK : No data fetched for symbol OSLOK using YahooDailyReader
# FORSAW : No data fetched for symbol FORSAW using YahooDailyReader
# TRPLD : No data fetched for symbol TRPLD using YahooDailyReader
# SUSTAF : No data fetched for symbol SUSTAF using YahooDailyReader
# IBEFN : No data fetched for symbol IBEFN using YahooDailyReader
# EBKG : No data fetched for symbol EBKG using YahooDailyReader
# LVENG : No data fetched for symbol LVENG using YahooDailyReader
# AZREO : No data fetched for symbol AZREO using YahooDailyReader
# JSFLC : No data fetched for symbol JSFLC using YahooDailyReader
# STERV : No data fetched for symbol STERV using YahooDailyReader
# ORSTEW : No data fetched for symbol ORSTEW using YahooDailyReader
# BRKMFC : No data fetched for symbol BRKMFC using YahooDailyReader
# SPDEV : No data fetched for symbol SPDEV using YahooDailyReader
# ICBACC : No data fetched for symbol ICBACC using YahooDailyReader
# RENPW : No data fetched for symbol RENPW using YahooDailyReader
# HYSNYH : No data fetched for symbol HYSNYH using YahooDailyReader
# NAGOYB : No data fetched for symbol NAGOYB using YahooDailyReader
# JIANGE : No data fetched for symbol JIANGE using YahooDailyReader
# BALD : No data fetched for symbol BALD using YahooDailyReader
# ESSIT : No data fetched for symbol ESSIT using YahooDailyReader
# NSWTC : No data fetched for symbol NSWTC using YahooDailyReader
# BKCOM : No data fetched for symbol BKCOM using YahooDailyReader
# CONRK : No data fetched for symbol CONRK using YahooDailyReader
# TAEEC : No data fetched for symbol TAEEC using YahooDailyReader
# GRN : 'Date'
# DNBDN : No data fetched for symbol DNBDN using YahooDailyReader
# NDAFI : No data fetched for symbol NDAFI using YahooDailyReader
# STKBO : No data fetched for symbol STKBO using YahooDailyReader
# FUXINH : No data fetched for symbol FUXINH using YahooDailyReader
# PRLERP : No data fetched for symbol PRLERP using YahooDailyReader
# KRCLP : No data fetched for symbol KRCLP using YahooDailyReader
# BKKAS : No data fetched for symbol BKKAS using YahooDailyReader
# EQROP : No data fetched for symbol EQROP using YahooDailyReader
# KAER : No data fetched for symbol KAER using YahooDailyReader
# BEJINK : No data fetched for symbol BEJINK using YahooDailyReader
# ESUFIC : No data fetched for symbol ESUFIC using YahooDailyReader
# MASIT : No data fetched for symbol MASIT using YahooDailyReader
# SUZBEI : No data fetched for symbol SUZBEI using YahooDailyReader
# LKBF : No data fetched for symbol LKBF using YahooDailyReader
# AGDBC : No data fetched for symbol AGDBC using YahooDailyReader
# HSBA : No data fetched for symbol HSBA using YahooDailyReader
# TNETH : No data fetched for symbol TNETH using YahooDailyReader
# SEVIAA : No data fetched for symbol SEVIAA using YahooDailyReader
# STEMLF : No data fetched for symbol STEMLF using YahooDailyReader
# JPHRT : No data fetched for symbol JPHRT using YahooDailyReader
# VSTDAV : No data fetched for symbol VSTDAV using YahooDailyReader
# DHREI : No data fetched for symbol DHREI using YahooDailyReader
# NOMRS : No data fetched for symbol NOMRS using YahooDailyReader
# ONPWG : No data fetched for symbol ONPWG using YahooDailyReader
# MTFGI : No data fetched for symbol MTFGI using YahooDailyReader
# SSE : 'Date'
# TENZZT : No data fetched for symbol TENZZT using YahooDailyReader
# PAPIG : No data fetched for symbol PAPIG using YahooDailyReader
# CEWL : No data fetched for symbol CEWL using YahooDailyReader
# XINGO : No data fetched for symbol XINGO using YahooDailyReader
# QIFSC : No data fetched for symbol QIFSC using YahooDailyReader
# RATP : No data fetched for symbol RATP using YahooDailyReader
# SODRA : No data fetched for symbol SODRA using YahooDailyReader
# SINOPD : No data fetched for symbol SINOPD using YahooDailyReader
# VELLN : No data fetched for symbol VELLN using YahooDailyReader
# CHNWDI : No data fetched for symbol CHNWDI using YahooDailyReader
# AFD : No data fetched for symbol AFD using YahooDailyReader
# FICOL : No data fetched for symbol FICOL using YahooDailyReader
# JACCS : No data fetched for symbol JACCS using YahooDailyReader
# DBSMX : 'Date'
# CENXX : No data fetched for symbol CENXX using YahooDailyReader
# SASAIO : No data fetched for symbol SASAIO using YahooDailyReader
# NABLC : No data fetched for symbol NABLC using YahooDailyReader
# SHB : No data fetched for symbol SHB using YahooDailyReader
# FRSTO : No data fetched for symbol FRSTO using YahooDailyReader
# HRA : No data fetched for symbol HRA using YahooDailyReader
# LNPSHS : No data fetched for symbol LNPSHS using YahooDailyReader
# HBCBK : No data fetched for symbol HBCBK using YahooDailyReader
# HRAMGV : No data fetched for symbol HRAMGV using YahooDailyReader
# UNBLRG : No data fetched for symbol UNBLRG using YahooDailyReader
# FABG : No data fetched for symbol FABG using YahooDailyReader
# SASABZ : No data fetched for symbol SASABZ using YahooDailyReader
# MTRCN : No data fetched for symbol MTRCN using YahooDailyReader
# EDPPF : 'Date'
# CPBEN : No data fetched for symbol CPBEN using YahooDailyReader
# BNACR : No data fetched for symbol BNACR using YahooDailyReader
# AVREI : No data fetched for symbol AVREI using YahooDailyReader
# ENTRA : No data fetched for symbol ENTRA using YahooDailyReader
# SMKRF : No data fetched for symbol SMKRF using YahooDailyReader
# BXPPI : No data fetched for symbol BXPPI using YahooDailyReader
# LREITN : No data fetched for symbol LREITN using YahooDailyReader
# JHJHNG : No data fetched for symbol JHJHNG using YahooDailyReader
# KEXIM : No data fetched for symbol KEXIM using YahooDailyReader
# JXPJRO : No data fetched for symbol JXPJRO using YahooDailyReader
# SDONWA : No data fetched for symbol SDONWA using YahooDailyReader
# SASADH : No data fetched for symbol SASADH using YahooDailyReader
# LADSA : No data fetched for symbol LADSA using YahooDailyReader
# SNCFER : No data fetched for symbol SNCFER using YahooDailyReader
# BKCHNX : No data fetched for symbol BKCHNX using YahooDailyReader
# KALINH : No data fetched for symbol KALINH using YahooDailyReader
# CAAEN : No data fetched for symbol CAAEN using YahooDailyReader
# ARN : 'Date'
# CNPP : 'Date'
# AESEG : No data fetched for symbol AESEG using YahooDailyReader
# ANWTRR : No data fetched for symbol ANWTRR using YahooDailyReader
# SLHN : 'Date'
# NDLWR : No data fetched for symbol NDLWR using YahooDailyReader
# ENEID : No data fetched for symbol ENEID using YahooDailyReader
# SRTFGR : No data fetched for symbol SRTFGR using YahooDailyReader
# CNFBG : No data fetched for symbol CNFBG using YahooDailyReader
# SOLTA : No data fetched for symbol SOLTA using YahooDailyReader
# DUKDP : No data fetched for symbol DUKDP using YahooDailyReader
# PEGCL : No data fetched for symbol PEGCL using YahooDailyReader
# DWASG : No data fetched for symbol DWASG using YahooDailyReader
# VASCE : No data fetched for symbol VASCE using YahooDailyReader
# NREMF : No data fetched for symbol NREMF using YahooDailyReader
# MING : No data fetched for symbol MING using YahooDailyReader
# SEK : No data fetched for symbol SEK using YahooDailyReader
# SASAXX : No data fetched for symbol SASAXX using YahooDailyReader
# DNBDB : No data fetched for symbol DNBDB using YahooDailyReader
# ICBATF : No data fetched for symbol ICBATF using YahooDailyReader
# SBHLS : No data fetched for symbol SBHLS using YahooDailyReader
# CXRCO : No data fetched for symbol CXRCO using YahooDailyReader
# YCGOHX : No data fetched for symbol YCGOHX using YahooDailyReader
# LNTST : No data fetched for symbol LNTST using YahooDailyReader
# GYCBK : No data fetched for symbol GYCBK using YahooDailyReader
# BPI : No data fetched for symbol BPI using YahooDailyReader
# BAZLEF : No data fetched for symbol BAZLEF using YahooDailyReader
# WALL : 'Date'
# NPPRT : No data fetched for symbol NPPRT using YahooDailyReader
# BOGZ : No data fetched for symbol BOGZ using YahooDailyReader
# GUILB : No data fetched for symbol GUILB using YahooDailyReader
# SICHAW : No data fetched for symbol SICHAW using YahooDailyReader
# UITMPS : No data fetched for symbol UITMPS using YahooDailyReader
# FUBFNB : No data fetched for symbol FUBFNB using YahooDailyReader
# BNPPT : No data fetched for symbol BNPPT using YahooDailyReader
# HYMTRD : No data fetched for symbol HYMTRD using YahooDailyReader
# ZUGN : No data fetched for symbol ZUGN using YahooDailyReader
# GRWER : No data fetched for symbol GRWER using YahooDailyReader
# ULVR : No data fetched for symbol ULVR using YahooDailyReader
# QTC : No data fetched for symbol QTC using YahooDailyReader
# SPRSK : No data fetched for symbol SPRSK using YahooDailyReader
# OGIFIB : No data fetched for symbol OGIFIB using YahooDailyReader
# MSFNL : No data fetched for symbol MSFNL using YahooDailyReader
# RABO : No data fetched for symbol RABO using YahooDailyReader
# ESNSA : No data fetched for symbol ESNSA using YahooDailyReader
# HZUBK : No data fetched for symbol HZUBK using YahooDailyReader
# KOMEFS : No data fetched for symbol KOMEFS using YahooDailyReader
# MTRCNC : No data fetched for symbol MTRCNC using YahooDailyReader
# ALPER : No data fetched for symbol ALPER using YahooDailyReader
# HERFTW : No data fetched for symbol HERFTW using YahooDailyReader
# BLGGD : No data fetched for symbol BLGGD using YahooDailyReader
# CNZHE : No data fetched for symbol CNZHE using YahooDailyReader
# BOBJG : No data fetched for symbol BOBJG using YahooDailyReader
# DKNTR : No data fetched for symbol DKNTR using YahooDailyReader
# NEDJNE : No data fetched for symbol NEDJNE using YahooDailyReader
# JAIRJ : No data fetched for symbol JAIRJ using YahooDailyReader
# SOGN : No data fetched for symbol SOGN using YahooDailyReader
# GUNBK : No data fetched for symbol GUNBK using YahooDailyReader
# REGEN : No data fetched for symbol REGEN using YahooDailyReader
# PPBLG : No data fetched for symbol PPBLG using YahooDailyReader
# SASATB : No data fetched for symbol SASATB using YahooDailyReader
# TKSGO : No data fetched for symbol TKSGO using YahooDailyReader
# CTYAS : No data fetched for symbol CTYAS using YahooDailyReader
# RBIV : No data fetched for symbol RBIV using YahooDailyReader
# AXBKD : No data fetched for symbol AXBKD using YahooDailyReader
# BRFSC : No data fetched for symbol BRFSC using YahooDailyReader
# SIKAM : No data fetched for symbol SIKAM using YahooDailyReader
# SUMWH : No data fetched for symbol SUMWH using YahooDailyReader
# CNGZBU : No data fetched for symbol CNGZBU using YahooDailyReader
# TJMURN : No data fetched for symbol TJMURN using YahooDailyReader
# GNANC : No data fetched for symbol GNANC using YahooDailyReader
# ALNPW : No data fetched for symbol ALNPW using YahooDailyReader
# QUANSS : No data fetched for symbol QUANSS using YahooDailyReader
# ORSTE : No data fetched for symbol ORSTE using YahooDailyReader
# HITCAC : No data fetched for symbol HITCAC using YahooDailyReader
# FPAR : No data fetched for symbol FPAR using YahooDailyReader
# SWDIA : No data fetched for symbol SWDIA using YahooDailyReader
# LYSE : No data fetched for symbol LYSE using YahooDailyReader
# UPPSTU : No data fetched for symbol UPPSTU using YahooDailyReader
# GRARW : No data fetched for symbol GRARW using YahooDailyReader
# STEDI : No data fetched for symbol STEDI using YahooDailyReader
# INRYF : No data fetched for symbol INRYF using YahooDailyReader
# VILSAB : NaTType does not support timetuple
# SHMNNP : No data fetched for symbol SHMNNP using YahooDailyReader
# TCLEA : No data fetched for symbol TCLEA using YahooDailyReader
# NJGVTO : No data fetched for symbol NJGVTO using YahooDailyReader
# DGBG : No data fetched for symbol DGBG using YahooDailyReader
# ERG : No data fetched for symbol ERG using YahooDailyReader
# SHONLS : No data fetched for symbol SHONLS using YahooDailyReader
# KBC : No data fetched for symbol KBC using YahooDailyReader
# KISERH : No data fetched for symbol KISERH using YahooDailyReader
# CNCHKG : No data fetched for symbol CNCHKG using YahooDailyReader
# BUSFYV : No data fetched for symbol BUSFYV using YahooDailyReader
# CNDBK : No data fetched for symbol CNDBK using YahooDailyReader
# STRGYW : No data fetched for symbol STRGYW using YahooDailyReader
# FARET : No data fetched for symbol FARET using YahooDailyReader
# LRENT : No data fetched for symbol LRENT using YahooDailyReader
# SHMZU : No data fetched for symbol SHMZU using YahooDailyReader
# DLRLT : No data fetched for symbol DLRLT using YahooDailyReader
# RGINTR : No data fetched for symbol RGINTR using YahooDailyReader
# OPPLYL : No data fetched for symbol OPPLYL using YahooDailyReader
# CAGRL : No data fetched for symbol CAGRL using YahooDailyReader
# MITBKA : No data fetched for symbol MITBKA using YahooDailyReader
# LANZH : No data fetched for symbol LANZH using YahooDailyReader
# DUKDE : No data fetched for symbol DUKDE using YahooDailyReader
# YZGOTI : No data fetched for symbol YZGOTI using YahooDailyReader
# VNOVR : No data fetched for symbol VNOVR using YahooDailyReader
# SUNTG : No data fetched for symbol SUNTG using YahooDailyReader
# TSIHSH : No data fetched for symbol TSIHSH using YahooDailyReader
# HASIH : No data fetched for symbol HASIH using YahooDailyReader
# SWRAYM : No data fetched for symbol SWRAYM using YahooDailyReader
# ITMAR : No data fetched for symbol ITMAR using YahooDailyReader
# HUAXG : No data fetched for symbol HUAXG using YahooDailyReader
# SENGV : No data fetched for symbol SENGV using YahooDailyReader
# BNKJS : No data fetched for symbol BNKJS using YahooDailyReader
# GASI : No data fetched for symbol GASI using YahooDailyReader
# RZDCP : No data fetched for symbol RZDCP using YahooDailyReader
# OFFENO : No data fetched for symbol OFFENO using YahooDailyReader
# CVOY : No data fetched for symbol CVOY using YahooDailyReader
# UNIKB : No data fetched for symbol UNIKB using YahooDailyReader
# ACSSE : No data fetched for symbol ACSSE using YahooDailyReader
# CSCBK : No data fetched for symbol CSCBK using YahooDailyReader
# CARXE : No data fetched for symbol CARXE using YahooDailyReader
# MRBLD : No data fetched for symbol MRBLD using YahooDailyReader
# ORICO : No data fetched for symbol ORICO using YahooDailyReader
# IDBIDU : No data fetched for symbol IDBIDU using YahooDailyReader
# TWCOFB : No data fetched for symbol TWCOFB using YahooDailyReader
# EVRR : No data fetched for symbol EVRR using YahooDailyReader
# HELVIH : No data fetched for symbol HELVIH using YahooDailyReader
# MNCHY : No data fetched for symbol MNCHY using YahooDailyReader
# SKAFL : No data fetched for symbol SKAFL using YahooDailyReader
# HITCA : No data fetched for symbol HITCA using YahooDailyReader
# YESB : No data fetched for symbol YESB using YahooDailyReader
# SSEHT : No data fetched for symbol SSEHT using YahooDailyReader
# ACFTE : No data fetched for symbol ACFTE using YahooDailyReader
# EESTEL : No data fetched for symbol EESTEL using YahooDailyReader
# SGPXM : No data fetched for symbol SGPXM using YahooDailyReader
# CNVTF : No data fetched for symbol CNVTF using YahooDailyReader
# CDGODT : No data fetched for symbol CDGODT using YahooDailyReader
# OMEI : No data fetched for symbol OMEI using YahooDailyReader
# SBILO : No data fetched for symbol SBILO using YahooDailyReader
# GCLNW : No data fetched for symbol GCLNW using YahooDailyReader
# GEELYL : No data fetched for symbol GEELYL using YahooDailyReader
# CAGRAH : No data fetched for symbol CAGRAH using YahooDailyReader
# KLBNDF : No data fetched for symbol KLBNDF using YahooDailyReader
# AGDER : No data fetched for symbol AGDER using YahooDailyReader
# LNDHYN : No data fetched for symbol LNDHYN using YahooDailyReader
# AQNLP : No data fetched for symbol AQNLP using YahooDailyReader
# EIDEN : No data fetched for symbol EIDEN using YahooDailyReader
# HCMIF : No data fetched for symbol HCMIF using YahooDailyReader
# ABNAM : No data fetched for symbol ABNAM using YahooDailyReader
# TLGOVI : No data fetched for symbol TLGOVI using YahooDailyReader
# VESCO : No data fetched for symbol VESCO using YahooDailyReader
# WCTES : No data fetched for symbol WCTES using YahooDailyReader
# SICUM : No data fetched for symbol SICUM using YahooDailyReader
# AZREA : No data fetched for symbol AZREA using YahooDailyReader
# CENMT : No data fetched for symbol CENMT using YahooDailyReader
# MTSFD : No data fetched for symbol MTSFD using YahooDailyReader
# PTNL : No data fetched for symbol PTNL using YahooDailyReader
# HZCIGD : No data fetched for symbol HZCIGD using YahooDailyReader
# ICBALF : No data fetched for symbol ICBALF using YahooDailyReader
# PARIS : No data fetched for symbol PARIS using YahooDailyReader
# ENEIEG : No data fetched for symbol ENEIEG using YahooDailyReader
# NAFIN : No data fetched for symbol NAFIN using YahooDailyReader
# ASEDVB : No data fetched for symbol ASEDVB using YahooDailyReader
# TWBSB : No data fetched for symbol TWBSB using YahooDailyReader
# JRFIC : No data fetched for symbol JRFIC using YahooDailyReader
# ALSSBM : No data fetched for symbol ALSSBM using YahooDailyReader
# BARC : No data fetched for symbol BARC using YahooDailyReader
# LAPST : No data fetched for symbol LAPST using YahooDailyReader
# EBKGI : No data fetched for symbol EBKGI using YahooDailyReader
# STEXE : No data fetched for symbol STEXE using YahooDailyReader
# QINGDD : No data fetched for symbol QINGDD using YahooDailyReader
# CHGQTO : No data fetched for symbol CHGQTO using YahooDailyReader
# SEKRT : No data fetched for symbol SEKRT using YahooDailyReader
# SOGNER : No data fetched for symbol SOGNER using YahooDailyReader
# IDCOL : No data fetched for symbol IDCOL using YahooDailyReader
# HUANAB : No data fetched for symbol HUANAB using YahooDailyReader
# OPOSUY : No data fetched for symbol OPOSUY using YahooDailyReader
# INCI : No data fetched for symbol INCI using YahooDailyReader
# NACKA : No data fetched for symbol NACKA using YahooDailyReader
# TCV : No data fetched for symbol TCV using YahooDailyReader
# RIKINR : No data fetched for symbol RIKINR using YahooDailyReader
# KNDIX : No data fetched for symbol KNDIX using YahooDailyReader
# QBE : No data fetched for symbol QBE using YahooDailyReader
# STIABN : No data fetched for symbol STIABN using YahooDailyReader
# ITOCA : No data fetched for symbol ITOCA using YahooDailyReader
# BOB : No data fetched for symbol BOB using YahooDailyReader
# SASAHR : No data fetched for symbol SASAHR using YahooDailyReader
# HALUP : No data fetched for symbol HALUP using YahooDailyReader
# XTRCB : No data fetched for symbol XTRCB using YahooDailyReader
# XELPS : No data fetched for symbol XELPS using YahooDailyReader
# EEOCA : No data fetched for symbol EEOCA using YahooDailyReader
# LTFHRA : No data fetched for symbol LTFHRA using YahooDailyReader
# EXIMB : No data fetched for symbol EXIMB using YahooDailyReader
# PKOHTZ : No data fetched for symbol PKOHTZ using YahooDailyReader
# NAB : 'Date'
# WBC : 'Date'
# FZGOVD : No data fetched for symbol FZGOVD using YahooDailyReader
# NODTR : No data fetched for symbol NODTR using YahooDailyReader
# COFX : No data fetched for symbol COFX using YahooDailyReader
# FINGD : No data fetched for symbol FINGD using YahooDailyReader
# GDONPD : No data fetched for symbol GDONPD using YahooDailyReader
# AGUA : No data fetched for symbol AGUA using YahooDailyReader
# CONTUE : No data fetched for symbol CONTUE using YahooDailyReader
# LOTEJC : No data fetched for symbol LOTEJC using YahooDailyReader
# JOHNB : No data fetched for symbol JOHNB using YahooDailyReader
# BAMOHL : No data fetched for symbol BAMOHL using YahooDailyReader
# CPFECI : No data fetched for symbol CPFECI using YahooDailyReader
# STGRE : No data fetched for symbol STGRE using YahooDailyReader
# UMQCB : No data fetched for symbol UMQCB using YahooDailyReader
# ADRBCA : No data fetched for symbol ADRBCA using YahooDailyReader
# BKWB : No data fetched for symbol BKWB using YahooDailyReader
# SBBHF : No data fetched for symbol SBBHF using YahooDailyReader
# GLPCP : No data fetched for symbol GLPCP using YahooDailyReader
# CNCBLK : No data fetched for symbol CNCBLK using YahooDailyReader
# CCGMH : No data fetched for symbol CCGMH using YahooDailyReader
# ENCEN : No data fetched for symbol ENCEN using YahooDailyReader
# EVRGT : No data fetched for symbol EVRGT using YahooDailyReader
# ZJCZC : No data fetched for symbol ZJCZC using YahooDailyReader
# BJEWGC : No data fetched for symbol BJEWGC using YahooDailyReader
# ELECSF : No data fetched for symbol ELECSF using YahooDailyReader
# AGBKFH : No data fetched for symbol AGBKFH using YahooDailyReader
# BKCHIN : No data fetched for symbol BKCHIN using YahooDailyReader
# MSULF : No data fetched for symbol MSULF using YahooDailyReader
# TOKTT : No data fetched for symbol TOKTT using YahooDailyReader
# BALDL : No data fetched for symbol BALDL using YahooDailyReader
# EVRBKH : No data fetched for symbol EVRBKH using YahooDailyReader
# BJEWG : No data fetched for symbol BJEWG using YahooDailyReader
# DACCO : No data fetched for symbol DACCO using YahooDailyReader
# SKIRJ : No data fetched for symbol SKIRJ using YahooDailyReader
# BKCHNL : No data fetched for symbol BKCHNL using YahooDailyReader
# HSTLP : No data fetched for symbol HSTLP using YahooDailyReader
# FUDIAN : No data fetched for symbol FUDIAN using YahooDailyReader
# KITUS : No data fetched for symbol KITUS using YahooDailyReader
# SRTFGB : No data fetched for symbol SRTFGB using YahooDailyReader
# PSTATG : No data fetched for symbol PSTATG using YahooDailyReader
# SUOYL : No data fetched for symbol SUOYL using YahooDailyReader
# ESTRW : No data fetched for symbol ESTRW using YahooDailyReader
# NOBIN : No data fetched for symbol NOBIN using YahooDailyReader
# CGPWI : No data fetched for symbol CGPWI using YahooDailyReader
# TAEECJ : No data fetched for symbol TAEECJ using YahooDailyReader
# VAEST : No data fetched for symbol VAEST using YahooDailyReader
# VOD : 'Date'
# GEALGR : No data fetched for symbol GEALGR using YahooDailyReader
# FUYOG : No data fetched for symbol FUYOG using YahooDailyReader
# NTPC : No data fetched for symbol NTPC using YahooDailyReader
# RMNTCN : No data fetched for symbol RMNTCN using YahooDailyReader
# TODA : No data fetched for symbol TODA using YahooDailyReader
# ALTUM : No data fetched for symbol ALTUM using YahooDailyReader
# BNDES : No data fetched for symbol BNDES using YahooDailyReader
# LMTREB : No data fetched for symbol LMTREB using YahooDailyReader
# SDFLCF : No data fetched for symbol SDFLCF using YahooDailyReader
# CASTZ : No data fetched for symbol CASTZ using YahooDailyReader
# DLRDE : No data fetched for symbol DLRDE using YahooDailyReader
# SRBANB : No data fetched for symbol SRBANB using YahooDailyReader
# NBCBK : No data fetched for symbol NBCBK using YahooDailyReader
# SBARQ : No data fetched for symbol SBARQ using YahooDailyReader
# MOEATF : No data fetched for symbol MOEATF using YahooDailyReader
# XINGON : No data fetched for symbol XINGON using YahooDailyReader
# ADNGN : No data fetched for symbol ADNGN using YahooDailyReader
# DTEED : No data fetched for symbol DTEED using YahooDailyReader
# NETHR : No data fetched for symbol NETHR using YahooDailyReader
# BPCSA : No data fetched for symbol BPCSA using YahooDailyReader
# AERIT : No data fetched for symbol AERIT using YahooDailyReader
# MARUI : No data fetched for symbol MARUI using YahooDailyReader
# BJCPC : No data fetched for symbol BJCPC using YahooDailyReader
# FSPCNN : No data fetched for symbol FSPCNN using YahooDailyReader
# DBAHNE : No data fetched for symbol DBAHNE using YahooDailyReader
# SUNSB : No data fetched for symbol SUNSB using YahooDailyReader
# HITZO : No data fetched for symbol HITZO using YahooDailyReader
# HKCNGF : No data fetched for symbol HKCNGF using YahooDailyReader
# AUMRCC : No data fetched for symbol AUMRCC using YahooDailyReader
# CWENCC : No data fetched for symbol CWENCC using YahooDailyReader
# OBAYA : No data fetched for symbol OBAYA using YahooDailyReader
# MITES : No data fetched for symbol MITES using YahooDailyReader
# GREG : No data fetched for symbol GREG using YahooDailyReader
# SVSKG : No data fetched for symbol SVSKG using YahooDailyReader
# PPSIN : No data fetched for symbol PPSIN using YahooDailyReader
# AMZCB : No data fetched for symbol AMZCB using YahooDailyReader
# KEPCOM : No data fetched for symbol KEPCOM using YahooDailyReader
# PNBKH : No data fetched for symbol PNBKH using YahooDailyReader
# ZYBCL : No data fetched for symbol ZYBCL using YahooDailyReader
# GARAN : No data fetched for symbol GARAN using YahooDailyReader
# REIVL : No data fetched for symbol REIVL using YahooDailyReader
# CNPEDC : No data fetched for symbol CNPEDC using YahooDailyReader
# BKCHNW : No data fetched for symbol BKCHNW using YahooDailyReader
# HSBASR : No data fetched for symbol HSBASR using YahooDailyReader
# ODERY : 'Date'
# HANEN : No data fetched for symbol HANEN using YahooDailyReader
# ASEID : No data fetched for symbol ASEID using YahooDailyReader
# RCB : 'Date'
# MS : 'Date'
# IGYIG : No data fetched for symbol IGYIG using YahooDailyReader
# THPPT : No data fetched for symbol THPPT using YahooDailyReader
# CHNWD : No data fetched for symbol CHNWD using YahooDailyReader
# JPEXC : No data fetched for symbol JPEXC using YahooDailyReader
# PWFC : No data fetched for symbol PWFC using YahooDailyReader
# ROSCG : No data fetched for symbol ROSCG using YahooDailyReader
# CSDPR : No data fetched for symbol CSDPR using YahooDailyReader
# NDXG : No data fetched for symbol NDXG using YahooDailyReader
# CENTL : No data fetched for symbol CENTL using YahooDailyReader
# TRNSL : No data fetched for symbol TRNSL using YahooDailyReader
# CIPHL : No data fetched for symbol CIPHL using YahooDailyReader
# AIGRAH : No data fetched for symbol AIGRAH using YahooDailyReader
# XINJGQ : No data fetched for symbol XINJGQ using YahooDailyReader
# TLINK : No data fetched for symbol TLINK using YahooDailyReader
# CTBCHA : No data fetched for symbol CTBCHA using YahooDailyReader
# GRTJ : No data fetched for symbol GRTJ using YahooDailyReader
# XELPOW : No data fetched for symbol XELPOW using YahooDailyReader
# KMUNK : No data fetched for symbol KMUNK using YahooDailyReader
# IREE : No data fetched for symbol IREE using YahooDailyReader
# ACTVA : No data fetched for symbol ACTVA using YahooDailyReader
# MEIDE : No data fetched for symbol MEIDE using YahooDailyReader
# LAPSTE : No data fetched for symbol LAPSTE using YahooDailyReader
# NPYKK : No data fetched for symbol NPYKK using YahooDailyReader
# COSMB : No data fetched for symbol COSMB using YahooDailyReader
# TIETA : No data fetched for symbol TIETA using YahooDailyReader
# AGR : No data fetched for symbol AGR using YahooDailyReader
# ACCNZ : No data fetched for symbol ACCNZ using YahooDailyReader
# LUNDK : No data fetched for symbol LUNDK using YahooDailyReader
# LGPHL : No data fetched for symbol LGPHL using YahooDailyReader
# CARXI : No data fetched for symbol CARXI using YahooDailyReader
# KEPCOH : No data fetched for symbol KEPCOH using YahooDailyReader
# UNURB : No data fetched for symbol UNURB using YahooDailyReader
# RICLS : No data fetched for symbol RICLS using YahooDailyReader
# EONG : No data fetched for symbol EONG using YahooDailyReader
# MZFG : No data fetched for symbol MZFG using YahooDailyReader
# FANASF : No data fetched for symbol FANASF using YahooDailyReader
# PECENA : No data fetched for symbol PECENA using YahooDailyReader
# ICPFF : No data fetched for symbol ICPFF using YahooDailyReader
# LITOOS : No data fetched for symbol LITOOS using YahooDailyReader
# OEG : 'Date'
# TRRFGP : No data fetched for symbol TRRFGP using YahooDailyReader
# OBOSLO : No data fetched for symbol OBOSLO using YahooDailyReader
# VOLBK : No data fetched for symbol VOLBK using YahooDailyReader
# PASUK : No data fetched for symbol PASUK using YahooDailyReader
# VORARH : No data fetched for symbol VORARH using YahooDailyReader
# ELELUX : No data fetched for symbol ELELUX using YahooDailyReader
# BDCOM : No data fetched for symbol BDCOM using YahooDailyReader
# ZJHYC : No data fetched for symbol ZJHYC using YahooDailyReader
# TOYOMF : No data fetched for symbol TOYOMF using YahooDailyReader
# CBA : 'Date'
# BACPHB : No data fetched for symbol BACPHB using YahooDailyReader
# SPDEVP : No data fetched for symbol SPDEVP using YahooDailyReader
# OTAWA : No data fetched for symbol OTAWA using YahooDailyReader
# SORRB : No data fetched for symbol SORRB using YahooDailyReader
# GDWPI : No data fetched for symbol GDWPI using YahooDailyReader
# ENEIL : No data fetched for symbol ENEIL using YahooDailyReader
# LREITS : No data fetched for symbol LREITS using YahooDailyReader
# BKCHMA : No data fetched for symbol BKCHMA using YahooDailyReader
# DANSKE : No data fetched for symbol DANSKE using YahooDailyReader
# SZGCN : No data fetched for symbol SZGCN using YahooDailyReader
# OCBCAU : No data fetched for symbol OCBCAU using YahooDailyReader
# NTGYA : No data fetched for symbol NTGYA using YahooDailyReader
# KLBNDA : No data fetched for symbol KLBNDA using YahooDailyReader
# CDCEC : No data fetched for symbol CDCEC using YahooDailyReader
# RIZHA : No data fetched for symbol RIZHA using YahooDailyReader
# KEAHOY : No data fetched for symbol KEAHOY using YahooDailyReader
# ABGABG : No data fetched for symbol ABGABG using YahooDailyReader
# VSGTL : No data fetched for symbol VSGTL using YahooDailyReader
# BBVAX : No data fetched for symbol BBVAX using YahooDailyReader
# NIDEC : No data fetched for symbol NIDEC using YahooDailyReader
# GRKOEI : No data fetched for symbol GRKOEI using YahooDailyReader
# SOGEP : No data fetched for symbol SOGEP using YahooDailyReader
# FIBRCO : No data fetched for symbol FIBRCO using YahooDailyReader
# NANCB : No data fetched for symbol NANCB using YahooDailyReader
# JREIT : No data fetched for symbol JREIT using YahooDailyReader
# PTMIE : No data fetched for symbol PTMIE using YahooDailyReader
# JIADO : No data fetched for symbol JIADO using YahooDailyReader
# DREAL : No data fetched for symbol DREAL using YahooDailyReader
# INGPBH : No data fetched for symbol INGPBH using YahooDailyReader
# DBJPN : No data fetched for symbol DBJPN using YahooDailyReader
# CAPET : No data fetched for symbol CAPET using YahooDailyReader
# FOINV : No data fetched for symbol FOINV using YahooDailyReader
# RENPWL : No data fetched for symbol RENPWL using YahooDailyReader
# SUMFG : No data fetched for symbol SUMFG using YahooDailyReader
# BGRIMR : No data fetched for symbol BGRIMR using YahooDailyReader
# DGCBK : No data fetched for symbol DGCBK using YahooDailyReader
# XINJNE : No data fetched for symbol XINJNE using YahooDailyReader
# SOLIS : No data fetched for symbol SOLIS using YahooDailyReader
# ACCES : NaTType does not support timetuple
# MTSIOK : No data fetched for symbol MTSIOK using YahooDailyReader
# NORDG : No data fetched for symbol NORDG using YahooDailyReader
# TEFEMI : No data fetched for symbol TEFEMI using YahooDailyReader
# DUKNG : No data fetched for symbol DUKNG using YahooDailyReader
# CLPHLM : No data fetched for symbol CLPHLM using YahooDailyReader
# BKCHTO : No data fetched for symbol BKCHTO using YahooDailyReader
# ORIXJ : No data fetched for symbol ORIXJ using YahooDailyReader
# SBABS : No data fetched for symbol SBABS using YahooDailyReader
# DNHGP : No data fetched for symbol DNHGP using YahooDailyReader
# WBCSR : No data fetched for symbol WBCSR using YahooDailyReader
# SENGSS : No data fetched for symbol SENGSS using YahooDailyReader
# JAPRI : No data fetched for symbol JAPRI using YahooDailyReader
# KWATR : No data fetched for symbol KWATR using YahooDailyReader
# ZZCOM : No data fetched for symbol ZZCOM using YahooDailyReader
# NEXI : No data fetched for symbol NEXI using YahooDailyReader

# %%
results

# %%
set(zip(df.Ticker, df['First Announcement Date']))
# Out:
# {('EAXX', Timestamp('2019-07-25 00:00:00')),
#  ('KOMBK', Timestamp('2015-05-18 00:00:00')),
#  ('ZHGOVE', Timestamp('2019-11-28 00:00:00')),
#  ('ENGIE', Timestamp('2018-01-10 00:00:00')),
#  ('CABKO', Timestamp('2018-04-19 00:00:00')),
#  ('GETP', Timestamp('2018-09-26 00:00:00')),
#  ('CAGRAF', Timestamp('2019-02-12 00:00:00')),
#  ('ELLKV', Timestamp('2019-12-05 00:00:00')),
#  ('SUMFGI', Timestamp('2018-12-20 00:00:00')),
#  ('FRNYKR', Timestamp('2019-05-02 00:00:00')),
#  ('SMFRS', Timestamp('2018-09-11 00:00:00')),
#  ('BNP', Timestamp('2019-05-14 00:00:00')),
#  ('HSBABB', Timestamp('2017-11-21 00:00:00')),
#  ('MNDEFA', Timestamp('2017-06-28 00:00:00')),
#  ('VWS', Timestamp('2015-03-04 00:00:00')),
#  ('VATTE', Timestamp('2019-06-13 00:00:00')),
#  ('ZHDHQ', Timestamp('2019-11-20 00:00:00')),
#  ('VASKNV', Timestamp('2018-08-27 00:00:00')),
#  ('HRSEG', Timestamp('2016-12-20 00:00:00')),
#  ('ATRLJ', Timestamp('2018-04-11 00:00:00')),
#  ('JRCTT', Timestamp('2019-11-22 00:00:00')),
#  ('CTDM', Timestamp('2019-01-09 00:00:00')),
#  ('SFFHOS', Timestamp('2017-10-19 00:00:00')),
#  ('IREDA', Timestamp('2017-03-28 00:00:00')),
#  ('VASKNV', Timestamp('2019-11-14 00:00:00')),
#  ('AKUOE', Timestamp('2015-05-18 00:00:00')),
#  ('RWI', Timestamp('2019-07-05 00:00:00')),
#  ('NHRCB', Timestamp('2019-03-14 00:00:00')),
#  ('INGTR', Timestamp('2018-07-03 00:00:00')),
#  ('PLAZL', Timestamp('2017-12-14 00:00:00')),
#  ('RFSHW', Timestamp('2019-04-15 00:00:00')),
#  ('CAGRAB', Timestamp('2018-01-24 00:00:00')),
#  ('BTHLL', Timestamp('2019-12-19 00:00:00')),
#  ('NRGEY', Timestamp('2017-02-06 00:00:00')),
#  ('NRWBK', Timestamp('2019-01-28 00:00:00')),
#  ('BYWG', Timestamp('2019-06-17 00:00:00')),
#  ('TOKYO', Timestamp('2017-10-20 00:00:00')),
#  ('KOMBK', Timestamp('2018-08-28 00:00:00')),
#  ('SPRBG', Timestamp('2018-01-23 00:00:00')),
#  ('ALNDR', Timestamp('2019-06-17 00:00:00')),
#  ('EWRSFY', Timestamp('2016-09-19 00:00:00')),
#  ('EWRSFY', Timestamp('2017-06-07 00:00:00')),
#  ('CAGRAF', Timestamp('2018-10-03 00:00:00')),
#  ('FDSPA', Timestamp('2019-11-21 00:00:00')),
#  ('YPBTRM', Timestamp('2019-06-26 00:00:00')),
#  ('SRMIF', Timestamp('2018-06-06 00:00:00')),
#  ('URW', Timestamp('2014-02-26 00:00:00')),
#  ('PPSIB', Timestamp('2018-02-22 00:00:00')),
#  ('RECM', Timestamp('2017-06-29 00:00:00')),
#  ('EEWCA', Timestamp('2019-08-15 00:00:00')),
#  ('CNLYP', Timestamp('2017-07-24 00:00:00')),
#  ('BARIV', Timestamp('2016-09-08 00:00:00')),
#  ('CBKG', Timestamp('2018-10-16 00:00:00')),
#  ('EWRSFY', Timestamp('2018-04-10 00:00:00')),
#  ('CQTGB', Timestamp('2018-12-21 00:00:00')),
#  ('ICBAFH', Timestamp('2019-09-09 00:00:00')),
#  ('ATTND', Timestamp('2015-05-18 00:00:00')),
#  ('OERBO', Timestamp('2015-05-18 00:00:00')),
#  ('HUZHU', Timestamp('2019-03-20 00:00:00')),
#  ('SOGFJ', Timestamp('2019-04-09 00:00:00')),
#  ('SOPWR', Timestamp('2016-06-13 00:00:00')),
#  ('SOGRP', Timestamp('2018-11-22 00:00:00')),
#  ('SBAB', Timestamp('2016-06-16 00:00:00')),
#  ('AFSUK', Timestamp('2019-05-07 00:00:00')),
#  ('NANBK', Timestamp('2015-05-18 00:00:00')),
#  ('BAMWAF', Timestamp('2019-07-11 00:00:00')),
#  ('INGBK', Timestamp('2015-11-17 00:00:00')),
#  ('BEJINR', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2019-10-14 00:00:00')),
#  ('TSLAS', Timestamp('2015-09-14 00:00:00')),
#  ('DAIOP', Timestamp('2018-10-19 00:00:00')),
#  ('ICBCA', Timestamp('2018-06-13 00:00:00')),
#  ('KLOV', Timestamp('2018-03-27 00:00:00')),
#  ('ALUPTT', Timestamp('2015-05-18 00:00:00')),
#  ('ZJDQCB', Timestamp('2018-12-06 00:00:00')),
#  ('SIHRB', Timestamp('2018-04-04 00:00:00')),
#  ('VVIN', Timestamp('2018-08-31 00:00:00')),
#  ('CYPRF', Timestamp('2019-10-10 00:00:00')),
#  ('MFC', Timestamp('2018-05-07 00:00:00')),
#  ('VASKNV', Timestamp('2019-01-21 00:00:00')),
#  ('TAISHA', Timestamp('2018-06-25 00:00:00')),
#  ('KDB', Timestamp('2017-06-27 00:00:00')),
#  ('IBERD', Timestamp('2016-04-14 00:00:00')),
#  ('UBI', Timestamp('2019-04-08 00:00:00')),
#  ('ZHGOVE', Timestamp('2018-03-27 00:00:00')),
#  ('TOFINA', Timestamp('2019-04-05 00:00:00')),
#  ('GEOGF', Timestamp('2015-07-21 00:00:00')),
#  ('MALMO', Timestamp('2019-10-25 00:00:00')),
#  ('BIC', Timestamp('2018-07-18 00:00:00')),
#  ('KFW', Timestamp('2015-10-20 00:00:00')),
#  ('CECWP', Timestamp('2018-07-12 00:00:00')),
#  ('EIBKCM', Timestamp('2016-12-05 00:00:00')),
#  ('HRSEG', Timestamp('2019-06-10 00:00:00')),
#  ('QDRCB', Timestamp('2015-05-18 00:00:00')),
#  ('CPPIBC', Timestamp('2018-06-13 00:00:00')),
#  ('ISAAC', Timestamp('2019-04-11 00:00:00')),
#  ('BKJIJ', Timestamp('2018-08-13 00:00:00')),
#  ('GTBRG', Timestamp('2018-10-25 00:00:00')),
#  ('CTDM', Timestamp('2015-05-18 00:00:00')),
#  ('GTBRG', Timestamp('2015-06-23 00:00:00')),
#  ('IBERD', Timestamp('2014-04-08 00:00:00')),
#  ('SASAEJ', Timestamp('2015-05-18 00:00:00')),
#  ('OSTND', Timestamp('2017-11-28 00:00:00')),
#  ('IOFX', Timestamp('2017-03-30 00:00:00')),
#  ('NEWDVH', Timestamp('2018-11-28 00:00:00')),
#  ('ARGZ', Timestamp('2019-03-06 00:00:00')),
#  ('NRWBK', Timestamp('2018-06-25 00:00:00')),
#  ('PNC', Timestamp('2019-10-29 00:00:00')),
#  ('SOGNTW', Timestamp('2019-07-02 00:00:00')),
#  ('YIWUGO', Timestamp('2015-05-18 00:00:00')),
#  ('KLED', Timestamp('2018-06-05 00:00:00')),
#  ('SBAB', Timestamp('2019-06-18 00:00:00')),
#  ('SUMFGI', Timestamp('2015-10-14 00:00:00')),
#  ('SCMANT', Timestamp('2019-11-01 00:00:00')),
#  ('BAMWAF', Timestamp('2019-09-11 00:00:00')),
#  ('SOGNSI', Timestamp('2015-05-18 00:00:00')),
#  ('NORDLD', Timestamp('2019-07-09 00:00:00')),
#  ('DFC', Timestamp('2015-01-27 00:00:00')),
#  ('KGYEYT', Timestamp('2017-07-27 00:00:00')),
#  ('ARGZ', Timestamp('2019-10-18 00:00:00')),
#  ('GRKOED', Timestamp('2017-07-17 00:00:00')),
#  ('VASKNV', Timestamp('2018-08-23 00:00:00')),
#  ('VASKNV', Timestamp('2019-01-17 00:00:00')),
#  ('ARE', Timestamp('2018-06-12 00:00:00')),
#  ('MODLA', Timestamp('2019-04-17 00:00:00')),
#  ('CAGRAB', Timestamp('2017-06-15 00:00:00')),
#  ('EWRSFY', Timestamp('2018-10-12 00:00:00')),
#  ('ADNARE', Timestamp('2019-10-03 00:00:00')),
#  ('ANAFN', Timestamp('2015-05-18 00:00:00')),
#  ('TSLAS', Timestamp('2015-08-10 00:00:00')),
#  ('TORNT', Timestamp('2018-07-18 00:00:00')),
#  ('CAGRAB', Timestamp('2019-12-27 00:00:00')),
#  ('DANSKT', NaT),
#  ('CNLYP', Timestamp('2017-05-11 00:00:00')),
#  ('HRAMLP', Timestamp('2018-03-08 00:00:00')),
#  ('KFW', Timestamp('2017-09-27 00:00:00')),
#  ('TELHY', Timestamp('2019-08-06 00:00:00')),
#  ('AGBKC', Timestamp('2015-05-18 00:00:00')),
#  ('KEPCO', Timestamp('2019-06-17 00:00:00')),
#  ('BNGBA', Timestamp('2019-01-23 00:00:00')),
#  ('JHFA', Timestamp('2019-09-10 00:00:00')),
#  ('VERGE', Timestamp('2017-11-21 00:00:00')),
#  ('ICBACF', Timestamp('2017-09-28 00:00:00')),
#  ('SCAA', Timestamp('2015-05-18 00:00:00')),
#  ('AKUOE', Timestamp('2019-11-21 00:00:00')),
#  ('ARISE', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2019-02-25 00:00:00')),
#  ('NJGVKJ', Timestamp('2019-01-24 00:00:00')),
#  ('SWEDX', Timestamp('2017-10-30 00:00:00')),
#  ('CACTC', Timestamp('2015-05-18 00:00:00')),
#  ('LGCHE', Timestamp('2019-04-08 00:00:00')),
#  ('KFW', Timestamp('2016-01-20 00:00:00')),
#  ('SAGA', Timestamp('2019-12-12 00:00:00')),
#  ('SBAB', Timestamp('2017-10-04 00:00:00')),
#  ('HUISH', Timestamp('2018-05-22 00:00:00')),
#  ('FUXIN', Timestamp('2018-10-25 00:00:00')),
#  ('ASJAT', Timestamp('2019-12-11 00:00:00')),
#  ('BCPXZ', Timestamp('2015-05-18 00:00:00')),
#  ('CHGQCJ', Timestamp('2018-12-19 00:00:00')),
#  ('TSLAS', Timestamp('2015-04-20 00:00:00')),
#  ('HUMLG', Timestamp('2017-06-15 00:00:00')),
#  ('RANIC', Timestamp('2019-08-02 00:00:00')),
#  ('JENEN', Timestamp('2015-05-18 00:00:00')),
#  ('CCTCE', Timestamp('2019-09-30 00:00:00')),
#  ('WHGVTS', Timestamp('2018-11-28 00:00:00')),
#  ('NABNY', Timestamp('2018-06-11 00:00:00')),
#  ('SASEPS', Timestamp('2019-10-10 00:00:00')),
#  ('ICBCA', Timestamp('2015-05-18 00:00:00')),
#  ('GRKOEO', Timestamp('2019-07-22 00:00:00')),
#  ('AKDHU', Timestamp('2019-06-13 00:00:00')),
#  ('OSLOK', Timestamp('2016-11-30 00:00:00')),
#  ('CNAT', Timestamp('2019-05-07 00:00:00')),
#  ('FORSAW', Timestamp('2018-08-29 00:00:00')),
#  ('NJGVKJ', Timestamp('2018-11-08 00:00:00')),
#  ('EDF', Timestamp('2015-10-08 00:00:00')),
#  ('TRPLD', Timestamp('2018-05-25 00:00:00')),
#  ('VASKNV', Timestamp('2019-08-26 00:00:00')),
#  ('ANAFN', Timestamp('2019-08-05 00:00:00')),
#  ('SUSTAF', Timestamp('2015-05-18 00:00:00')),
#  ('IBEFN', Timestamp('2017-02-28 00:00:00')),
#  ('VASKNV', Timestamp('2019-02-13 00:00:00')),
#  ('JHFA', Timestamp('2019-01-11 00:00:00')),
#  ('EBKG', Timestamp('2019-07-29 00:00:00')),
#  ('LVENG', Timestamp('2015-06-08 00:00:00')),
#  ('AZREO', Timestamp('2019-09-17 00:00:00')),
#  ('DFC', Timestamp('2016-11-28 00:00:00')),
#  ('JSFLC', Timestamp('2019-04-03 00:00:00')),
#  ('STERV', Timestamp('2019-02-13 00:00:00')),
#  ('ORSTEW', Timestamp('2019-11-14 00:00:00')),
#  ('BRKMFC', Timestamp('2019-01-07 00:00:00')),
#  ('SPDEV', Timestamp('2015-05-18 00:00:00')),
#  ('ICBACC', Timestamp('2019-04-16 00:00:00')),
#  ('RENPW', Timestamp('2019-09-05 00:00:00')),
#  ('HYSNYH', Timestamp('2019-05-31 00:00:00')),
#  ('NAGOYB', Timestamp('2019-12-06 00:00:00')),
#  ('SOPWR', Timestamp('2016-11-10 00:00:00')),
#  ('JIANGE', Timestamp('2019-01-25 00:00:00')),
#  ('KLED', Timestamp('2019-02-28 00:00:00')),
#  ('BALD', Timestamp('2019-11-29 00:00:00')),
#  ('ESSIT', Timestamp('2015-05-18 00:00:00')),
#  ('NSWTC', Timestamp('2019-09-05 00:00:00')),
#  ('EWRSFY', Timestamp('2017-10-17 00:00:00')),
#  ('JENEN', Timestamp('2019-01-29 00:00:00')),
#  ('BKCOM', Timestamp('2015-05-18 00:00:00')),
#  ('CONRK', Timestamp('2019-02-04 00:00:00')),
#  ('TAEEC', Timestamp('2019-05-24 00:00:00')),
#  ('GRN', Timestamp('2018-07-27 00:00:00')),
#  ('DNBDN', Timestamp('2015-05-18 00:00:00')),
#  ('NORDLD', Timestamp('2017-11-16 00:00:00')),
#  ('NDAFI', Timestamp('2017-06-26 00:00:00')),
#  ('STKBO', Timestamp('2019-09-25 00:00:00')),
#  ('FUXINH', Timestamp('2018-11-13 00:00:00')),
#  ('PRLERP', Timestamp('2019-06-25 00:00:00')),
#  ('EDP', Timestamp('2019-01-23 00:00:00')),
#  ('KRCLP', Timestamp('2018-11-14 00:00:00')),
#  ('TSLAS', Timestamp('2015-05-18 00:00:00')),
#  ('BKKAS', Timestamp('2014-09-25 00:00:00')),
#  ('EQROP', Timestamp('2018-11-28 00:00:00')),
#  ('KAER', Timestamp('2018-08-30 00:00:00')),
#  ('TSLAS', Timestamp('2015-12-14 00:00:00')),
#  ('BEJINK', Timestamp('2019-09-09 00:00:00')),
#  ('ESUFIC', Timestamp('2019-08-12 00:00:00')),
#  ('MASIT', Timestamp('2014-09-22 00:00:00')),
#  ('BNP', Timestamp('2019-02-27 00:00:00')),
#  ('SUZBEI', Timestamp('2016-07-07 00:00:00')),
#  ('KDB', Timestamp('2018-05-29 00:00:00')),
#  ('NORDLD', Timestamp('2019-07-27 00:00:00')),
#  ('LKBF', Timestamp('2019-05-15 00:00:00')),
#  ('AGDBC', Timestamp('2018-11-19 00:00:00')),
#  ('ANAFN', Timestamp('2016-11-04 00:00:00')),
#  ('HSBA', Timestamp('2018-11-27 00:00:00')),
#  ('TNETH', Timestamp('2016-06-06 00:00:00')),
#  ('SEVIAA', Timestamp('2019-03-15 00:00:00')),
#  ('STEMLF', Timestamp('2018-05-24 00:00:00')),
#  ('ESUFIC', Timestamp('2015-05-18 00:00:00')),
#  ('JPHRT', Timestamp('2019-07-23 00:00:00')),
#  ('VSTDAV', Timestamp('2019-05-16 00:00:00')),
#  ('DHREI', Timestamp('2019-11-15 00:00:00')),
#  ('NOMRS', Timestamp('2016-09-09 00:00:00')),
#  ('ONPWG', Timestamp('2019-01-16 00:00:00')),
#  ('MTFGI', Timestamp('2019-09-23 00:00:00')),
#  ('VASKNV', Timestamp('2018-04-18 00:00:00')),
#  ('SSE', Timestamp('2018-08-31 00:00:00')),
#  ('TENZZT', Timestamp('2019-10-11 00:00:00')),
#  ('PAPIG', Timestamp('2018-03-15 00:00:00')),
#  ('CEWL', Timestamp('2018-08-15 00:00:00')),
#  ('TNETH', Timestamp('2018-05-22 00:00:00')),
#  ('AFSUK', Timestamp('2019-10-23 00:00:00')),
#  ('PRLERP', Timestamp('2018-10-31 00:00:00')),
#  ('XINGO', Timestamp('2016-05-23 00:00:00')),
#  ('KLED', Timestamp('2019-12-05 00:00:00')),
#  ('KOMBK', Timestamp('2015-02-04 00:00:00')),
#  ('HUMLG', Timestamp('2015-05-18 00:00:00')),
#  ('QIFSC', Timestamp('2019-08-08 00:00:00')),
#  ('SPDEV', Timestamp('2016-07-11 00:00:00')),
#  ('TORNT', Timestamp('2019-09-09 00:00:00')),
#  ('RATP', Timestamp('2017-06-21 00:00:00')),
#  ('KDB', Timestamp('2019-07-02 00:00:00')),
#  ('VASKNV', Timestamp('2015-05-18 00:00:00')),
#  ('EWRSFY', Timestamp('2015-04-27 00:00:00')),
#  ('TSLAS', Timestamp('2015-08-17 00:00:00')),
#  ('SODRA', Timestamp('2016-06-02 00:00:00')),
#  ('HUMLG', Timestamp('2019-12-04 00:00:00')),
#  ('SINOPD', Timestamp('2019-06-24 00:00:00')),
#  ('IREDA', Timestamp('2017-03-23 00:00:00')),
#  ('VELLN', Timestamp('2018-03-08 00:00:00')),
#  ('CHNWDI', Timestamp('2015-05-18 00:00:00')),
#  ('MTFGI', Timestamp('2018-01-19 00:00:00')),
#  ('AFD', Timestamp('2014-09-10 00:00:00')),
#  ('FICOL', Timestamp('2015-05-18 00:00:00')),
#  ('HYSNYH', Timestamp('2019-03-14 00:00:00')),
#  ('CAGRAB', Timestamp('2017-12-21 00:00:00')),
#  ('WBC', Timestamp('2018-02-07 00:00:00')),
#  ('JACCS', Timestamp('2019-04-09 00:00:00')),
#  ('DBSMX', Timestamp('2017-07-18 00:00:00')),
#  ('CENXX', Timestamp('2015-05-18 00:00:00')),
#  ('CENXX', Timestamp('2019-02-22 00:00:00')),
#  ('VASKNV', Timestamp('2018-11-27 00:00:00')),
#  ('SASAIO', Timestamp('2017-12-05 00:00:00')),
#  ('CAGRAB', Timestamp('2013-09-05 00:00:00')),
#  ('NABLC', Timestamp('2018-06-15 00:00:00')),
#  ('SOGRP', Timestamp('2018-10-09 00:00:00')),
#  ('SHB', Timestamp('2018-06-25 00:00:00')),
#  ('FRSTO', Timestamp('2019-07-04 00:00:00')),
#  ('BNP', Timestamp('2019-01-10 00:00:00')),
#  ('SOGRP', Timestamp('2019-03-18 00:00:00')),
#  ('WELL', Timestamp('2019-12-09 00:00:00')),
#  ('EAXX', Timestamp('2019-09-25 00:00:00')),
#  ('KOMBK', Timestamp('2016-10-26 00:00:00')),
#  ('HRA', Timestamp('2014-06-26 00:00:00')),
#  ('LNPSHS', Timestamp('2016-09-23 00:00:00')),
#  ('HBCBK', Timestamp('2017-05-02 00:00:00')),
#  ('HRAMGV', Timestamp('2015-05-18 00:00:00')),
#  ('UNBLRG', Timestamp('2015-05-18 00:00:00')),
#  ('GTBRG', Timestamp('2017-06-01 00:00:00')),
#  ('FABG', Timestamp('2018-08-23 00:00:00')),
#  ('SASABZ', Timestamp('2015-05-18 00:00:00')),
#  ('MTRCN', Timestamp('2017-09-25 00:00:00')),
#  ('EDPPF', Timestamp('2019-09-10 00:00:00')),
#  ('JRCTT', Timestamp('2017-11-17 00:00:00')),
#  ('CPBEN', Timestamp('2018-09-13 00:00:00')),
#  ('BNACR', Timestamp('2016-04-20 00:00:00')),
#  ('ENGIE', Timestamp('2019-06-14 00:00:00')),
#  ('SAGA', Timestamp('2019-12-10 00:00:00')),
#  ('AVREI', Timestamp('2019-07-17 00:00:00')),
#  ('ENTRA', Timestamp('2019-05-14 00:00:00')),
#  ('TSLAS', Timestamp('2015-12-28 00:00:00')),
#  ('SMKRF', Timestamp('2018-10-26 00:00:00')),
#  ('VASKNV', Timestamp('2018-02-02 00:00:00')),
#  ('BXPPI', Timestamp('2018-11-13 00:00:00')),
#  ('LREITN', Timestamp('2016-07-14 00:00:00')),
#  ('JHJHNG', Timestamp('2019-02-08 00:00:00')),
#  ('KEXIM', Timestamp('2016-02-02 00:00:00')),
#  ('BNP', Timestamp('2019-11-27 00:00:00')),
#  ('CABKO', Timestamp('2015-05-18 00:00:00')),
#  ('JXPJRO', Timestamp('2019-11-28 00:00:00')),
#  ('SDONWA', Timestamp('2019-02-15 00:00:00')),
#  ('SASADH', Timestamp('2018-11-27 00:00:00')),
#  ('ATRLJ', Timestamp('2019-07-02 00:00:00')),
#  ('LADSA', Timestamp('2015-05-18 00:00:00')),
#  ('SNCFER', Timestamp('2019-06-27 00:00:00')),
#  ('MTFGI', Timestamp('2019-09-24 00:00:00')),
#  ('BKCHNX', Timestamp('2016-07-05 00:00:00')),
#  ('KALINH', Timestamp('2017-09-26 00:00:00')),
#  ('IBERD', Timestamp('2018-03-19 00:00:00')),
#  ('CAAEN', Timestamp('2019-05-29 00:00:00')),
#  ('ARN', Timestamp('2019-12-19 00:00:00')),
#  ('CNPP', Timestamp('2019-11-20 00:00:00')),
#  ('IBEFN', Timestamp('2017-02-06 00:00:00')),
#  ('AESEG', Timestamp('2019-10-02 00:00:00')),
#  ('ANWTRR', Timestamp('2018-10-12 00:00:00')),
#  ('KEXIM', Timestamp('2019-02-27 00:00:00')),
#  ('GTBRG', Timestamp('2015-05-18 00:00:00')),
#  ('TSLAS', Timestamp('2015-05-26 00:00:00')),
#  ('FAB', Timestamp('2019-09-03 00:00:00')),
#  ('SLHN', Timestamp('2019-11-08 00:00:00')),
#  ('NDLWR', Timestamp('2015-08-26 00:00:00')),
#  ('ENEID', Timestamp('2015-05-18 00:00:00')),
#  ('SRTFGR', Timestamp('2019-08-30 00:00:00')),
#  ('SASADH', Timestamp('2015-05-18 00:00:00')),
#  ('CNFBG', Timestamp('2019-07-17 00:00:00')),
#  ('IREDA', Timestamp('2017-09-28 00:00:00')),
#  ('NRWBK', Timestamp('2015-05-18 00:00:00')),
#  ('CNLYP', Timestamp('2018-11-29 00:00:00')),
#  ('SOLTA', Timestamp('2018-07-10 00:00:00')),
#  ('DUKDP', Timestamp('2018-11-05 00:00:00')),
#  ('PEGCL', Timestamp('2016-09-30 00:00:00')),
#  ('DWASG', Timestamp('2018-11-22 00:00:00')),
#  ('KEXIM', Timestamp('2015-05-18 00:00:00')),
#  ('BAC', Timestamp('2018-05-14 00:00:00')),
#  ('DFC', Timestamp('2016-01-26 00:00:00')),
#  ('VASCE', Timestamp('2019-05-22 00:00:00')),
#  ('CHGQCJ', Timestamp('2018-09-20 00:00:00')),
#  ('BALD', Timestamp('2019-05-29 00:00:00')),
#  ('VASKNV', Timestamp('2019-05-14 00:00:00')),
#  ('VASKNV', Timestamp('2019-06-17 00:00:00')),
#  ('NREMF', Timestamp('2019-09-13 00:00:00')),
#  ('MING', Timestamp('2019-09-04 00:00:00')),
#  ('EWRSFY', Timestamp('2019-07-10 00:00:00')),
#  ('SEK', Timestamp('2015-05-18 00:00:00')),
#  ('JENEN', Timestamp('2018-11-14 00:00:00')),
#  ('SASAXX', Timestamp('2016-10-18 00:00:00')),
#  ('DNBDB', Timestamp('2019-01-29 00:00:00')),
#  ('ICBATF', Timestamp('2018-06-05 00:00:00')),
#  ('SBHLS', Timestamp('2019-12-05 00:00:00')),
#  ('SUZBEI', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2018-03-16 00:00:00')),
#  ('MTFGI', Timestamp('2018-10-01 00:00:00')),
#  ('CXRCO', Timestamp('2019-12-20 00:00:00')),
#  ('VASKNV', Timestamp('2017-10-19 00:00:00')),
#  ('YCGOHX', Timestamp('2019-03-25 00:00:00')),
#  ('MEL', Timestamp('2018-06-11 00:00:00')),
#  ('CAGRAB', Timestamp('2014-06-27 00:00:00')),
#  ('JRCTT', Timestamp('2018-02-07 00:00:00')),
#  ('LNTST', Timestamp('2019-09-19 00:00:00')),
#  ('SFFHOS', Timestamp('2015-05-18 00:00:00')),
#  ('GYCBK', Timestamp('2018-08-24 00:00:00')),
#  ('BPI', Timestamp('2019-08-29 00:00:00')),
#  ('BAZLEF', Timestamp('2018-05-16 00:00:00')),
#  ('GRN', Timestamp('2017-11-02 00:00:00')),
#  ('WALL', Timestamp('2015-05-18 00:00:00')),
#  ('KFW', Timestamp('2015-12-07 00:00:00')),
#  ('HSBABB', Timestamp('2019-01-18 00:00:00')),
#  ('NPPRT', Timestamp('2018-08-10 00:00:00')),
#  ('BOGZ', Timestamp('2018-11-28 00:00:00')),
#  ('TSLAS', Timestamp('2015-07-13 00:00:00')),
#  ('GUILB', Timestamp('2018-11-19 00:00:00')),
#  ('ENGIE', Timestamp('2017-03-15 00:00:00')),
#  ('SICHAW', Timestamp('2018-10-15 00:00:00')),
#  ('ING', Timestamp('2019-03-18 00:00:00')),
#  ('AGR', Timestamp('2019-05-14 00:00:00')),
#  ('SEB', Timestamp('2017-02-10 00:00:00')),
#  ('AGBKC', Timestamp('2015-10-02 00:00:00')),
#  ('UITMPS', Timestamp('2015-05-18 00:00:00')),
#  ('FUBFNB', Timestamp('2015-05-18 00:00:00')),
#  ('BNPPT', Timestamp('2019-07-30 00:00:00')),
#  ('AKUOE', Timestamp('2017-12-08 00:00:00')),
#  ('SASAIO', Timestamp('2018-09-05 00:00:00')),
#  ('NORDLD', Timestamp('2018-01-10 00:00:00')),
#  ('HYMTRD', Timestamp('2016-03-07 00:00:00')),
#  ('ZUGN', Timestamp('2019-09-04 00:00:00')),
#  ('HBCBK', Timestamp('2015-05-18 00:00:00')),
#  ('GRWER', Timestamp('2019-07-30 00:00:00')),
#  ('EDC', Timestamp('2019-07-24 00:00:00')),
#  ('CAGRAB', Timestamp('2017-10-18 00:00:00')),
#  ('ULVR', Timestamp('2015-05-18 00:00:00')),
#  ('QTC', Timestamp('2017-03-15 00:00:00')),
#  ('SPRSK', Timestamp('2019-10-14 00:00:00')),
#  ('OGIFIB', Timestamp('2019-11-27 00:00:00')),
#  ('ONPWG', Timestamp('2018-06-20 00:00:00')),
#  ('MSFNL', Timestamp('2018-02-20 00:00:00')),
#  ('VASCE', Timestamp('2018-05-31 00:00:00')),
#  ('EWRSFY', Timestamp('2019-10-28 00:00:00')),
#  ('CAGRAB', Timestamp('2017-11-28 00:00:00')),
#  ('RABO', Timestamp('2016-10-04 00:00:00')),
#  ('VASKNV', Timestamp('2019-04-15 00:00:00')),
#  ('KFW', Timestamp('2019-05-28 00:00:00')),
#  ('AKUOE', Timestamp('2016-07-11 00:00:00')),
#  ('ESNSA', Timestamp('2019-05-14 00:00:00')),
#  ('DFC', Timestamp('2015-03-27 00:00:00')),
#  ('HZUBK', Timestamp('2019-12-03 00:00:00')),
#  ('KFW', Timestamp('2018-10-17 00:00:00')),
#  ('KOMEFS', Timestamp('2017-05-16 00:00:00')),
#  ('MTRCNC', Timestamp('2016-10-24 00:00:00')),
#  ('NDLWR', Timestamp('2016-03-18 00:00:00')),
#  ('ALPER', Timestamp('2016-12-23 00:00:00')),
#  ('HERFTW', Timestamp('2015-05-18 00:00:00')),
#  ('BLGGD', Timestamp('2019-10-30 00:00:00')),
#  ('CPPIBC', Timestamp('2019-01-28 00:00:00')),
#  ('CNZHE', Timestamp('2019-09-11 00:00:00')),
#  ('HYSNYH', Timestamp('2019-04-02 00:00:00')),
#  ('ATRLJ', Timestamp('2019-03-19 00:00:00')),
#  ('BEJINR', Timestamp('2018-03-19 00:00:00')),
#  ('BOBJG', Timestamp('2017-11-23 00:00:00')),
#  ('DKNTR', Timestamp('2019-09-13 00:00:00')),
#  ('TNETH', Timestamp('2016-10-10 00:00:00')),
#  ('NEDJNE', Timestamp('2019-04-29 00:00:00')),
#  ('HUMLG', Timestamp('2019-06-24 00:00:00')),
#  ('JAIRJ', Timestamp('2017-01-25 00:00:00')),
#  ('SOGN', Timestamp('2015-11-18 00:00:00')),
#  ('CNAT', Timestamp('2019-03-15 00:00:00')),
#  ('C', Timestamp('2019-03-29 00:00:00')),
#  ('GUNBK', Timestamp('2019-11-19 00:00:00')),
#  ('HUISH', Timestamp('2017-09-01 00:00:00')),
#  ('REGEN', Timestamp('2014-05-13 00:00:00')),
#  ('PPBLG', Timestamp('2019-01-31 00:00:00')),
#  ('SASATB', Timestamp('2017-06-14 00:00:00')),
#  ('SICHAW', Timestamp('2019-07-11 00:00:00')),
#  ('VASKNV', Timestamp('2019-08-28 00:00:00')),
#  ('CAGRAB', Timestamp('2019-09-16 00:00:00')),
#  ('VZ', Timestamp('2019-02-05 00:00:00')),
#  ('BRKMFC', Timestamp('2019-10-01 00:00:00')),
#  ('TSLAS', Timestamp('2015-08-03 00:00:00')),
#  ('TKSGO', Timestamp('2019-07-09 00:00:00')),
#  ('KFW', Timestamp('2015-05-18 00:00:00')),
#  ('CTYAS', Timestamp('2019-11-18 00:00:00')),
#  ('RBIV', Timestamp('2019-10-02 00:00:00')),
#  ('DFC', Timestamp('2015-10-30 00:00:00')),
#  ('AXBKD', Timestamp('2016-05-23 00:00:00')),
#  ('BRFSC', Timestamp('2015-05-29 00:00:00')),
#  ('CAGRAB', Timestamp('2016-11-10 00:00:00')),
#  ('TSLAS', Timestamp('2015-03-16 00:00:00')),
#  ('SASAEJ', Timestamp('2016-08-15 00:00:00')),
#  ('KFW', Timestamp('2019-07-23 00:00:00')),
#  ('SIKAM', Timestamp('2015-05-18 00:00:00')),
#  ('SUMWH', Timestamp('2019-09-13 00:00:00')),
#  ('SAN', Timestamp('2019-10-01 00:00:00')),
#  ('CNGZBU', Timestamp('2018-09-17 00:00:00')),
#  ('TJMURN', Timestamp('2018-03-13 00:00:00')),
#  ('GNANC', Timestamp('2019-07-17 00:00:00')),
#  ('ALNPW', Timestamp('2018-10-18 00:00:00')),
#  ('QUANSS', Timestamp('2017-10-04 00:00:00')),
#  ('ORSTE', Timestamp('2019-05-09 00:00:00')),
#  ('JENEN', Timestamp('2018-04-10 00:00:00')),
#  ('SIHRB', Timestamp('2019-03-25 00:00:00')),
#  ('HITCAC', Timestamp('2017-12-15 00:00:00')),
#  ('NHRCB', Timestamp('2015-05-18 00:00:00')),
#  ('SNCFER', Timestamp('2019-01-14 00:00:00')),
#  ('TSLAS', Timestamp('2015-08-24 00:00:00')),
#  ('ATRLJ', Timestamp('2018-07-03 00:00:00')),
#  ('DFC', Timestamp('2016-09-19 00:00:00')),
#  ('MTRCNC', Timestamp('2017-09-25 00:00:00')),
#  ('SASABZ', Timestamp('2018-05-24 00:00:00')),
#  ('SICHAW', Timestamp('2019-06-27 00:00:00')),
#  ('FPAR', Timestamp('2018-11-23 00:00:00')),
#  ('SWDIA', Timestamp('2019-12-09 00:00:00')),
#  ('BTHLL', Timestamp('2015-05-18 00:00:00')),
#  ('HUMLG', Timestamp('2018-11-20 00:00:00')),
#  ('LYSE', Timestamp('2017-04-05 00:00:00')),
#  ('UPPSTU', Timestamp('2015-09-10 00:00:00')),
#  ('GRARW', Timestamp('2015-05-18 00:00:00')),
#  ('STEDI', Timestamp('2019-11-07 00:00:00')),
#  ('BEJINK', Timestamp('2018-09-10 00:00:00')),
#  ('NDLWR', Timestamp('2019-09-26 00:00:00')),
#  ('INRYF', Timestamp('2017-12-05 00:00:00')),
#  ('VILSAB', NaT),
#  ('FABG', Timestamp('2018-04-05 00:00:00')),
#  ('TIGO', Timestamp('2019-05-08 00:00:00')),
#  ('PRLERP', Timestamp('2018-03-01 00:00:00')),
#  ('MFC', Timestamp('2017-11-14 00:00:00')),
#  ('TD', Timestamp('2017-09-07 00:00:00')),
#  ('SHMNNP', Timestamp('2018-03-14 00:00:00')),
#  ('LKBF', Timestamp('2019-05-21 00:00:00')),
#  ('TCLEA', Timestamp('2018-11-07 00:00:00')),
#  ('NJGVTO', Timestamp('2019-03-08 00:00:00')),
#  ('VASKNV', Timestamp('2019-11-20 00:00:00')),
#  ('TSLAS', Timestamp('2015-11-30 00:00:00')),
#  ('BAC', Timestamp('2015-05-18 00:00:00')),
#  ('DGBG', Timestamp('2018-09-25 00:00:00')),
#  ('ERG', Timestamp('2019-04-04 00:00:00')),
#  ('SHONLS', Timestamp('2019-11-04 00:00:00')),
#  ('KBC', Timestamp('2018-06-25 00:00:00')),
#  ('BAZLEF', Timestamp('2017-11-29 00:00:00')),
#  ('KISERH', Timestamp('2017-04-25 00:00:00')),
#  ('CNCHKG', Timestamp('2019-10-15 00:00:00')),
#  ('CNAT', Timestamp('2019-06-28 00:00:00')),
#  ('BUSFYV', Timestamp('2015-05-18 00:00:00')),
#  ('CNDBK', Timestamp('2017-04-27 00:00:00')),
#  ('JENEN', Timestamp('2019-10-17 00:00:00')),
#  ('MTRCNC', Timestamp('2017-06-22 00:00:00')),
#  ('STRGYW', Timestamp('2018-04-17 00:00:00')),
#  ('NRWBK', Timestamp('2015-11-03 00:00:00')),
#  ('DNBDB', Timestamp('2015-05-18 00:00:00')),
#  ('FARET', Timestamp('2018-01-03 00:00:00')),
#  ('SOGNTW', Timestamp('2018-10-02 00:00:00')),
#  ('MEL', Timestamp('2017-03-06 00:00:00')),
#  ('RBIV', Timestamp('2019-09-23 00:00:00')),
#  ('SOGRP', Timestamp('2019-02-08 00:00:00')),
#  ('LRENT', Timestamp('2019-04-04 00:00:00')),
#  ('SHMZU', Timestamp('2019-12-06 00:00:00')),
#  ('SBB', Timestamp('2019-02-07 00:00:00')),
#  ('SEK', Timestamp('2019-06-26 00:00:00')),
#  ('BNP', Timestamp('2018-04-10 00:00:00')),
#  ('DLRLT', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2019-09-03 00:00:00')),
#  ('RGINTR', Timestamp('2019-05-14 00:00:00')),
#  ('LRENT', Timestamp('2015-05-18 00:00:00')),
#  ('HUMLG', Timestamp('2019-12-03 00:00:00')),
#  ('OPPLYL', Timestamp('2018-02-05 00:00:00')),
#  ('CAGRL', Timestamp('2018-11-28 00:00:00')),
#  ('MITBKA', Timestamp('2018-09-18 00:00:00')),
#  ('LANZH', Timestamp('2019-03-28 00:00:00')),
#  ('VASKNV', Timestamp('2019-10-22 00:00:00')),
#  ('SOGN', Timestamp('2016-09-28 00:00:00')),
#  ('DUKDE', Timestamp('2019-03-04 00:00:00')),
#  ('YZGOTI', Timestamp('2018-04-24 00:00:00')),
#  ('VNOVR', Timestamp('2015-05-18 00:00:00')),
#  ('MTFGI', Timestamp('2016-09-06 00:00:00')),
#  ('SUNTG', Timestamp('2018-03-07 00:00:00')),
#  ('TSIHSH', Timestamp('2017-08-18 00:00:00')),
#  ('HASIH', Timestamp('2019-09-10 00:00:00')),
#  ('SASABZ', Timestamp('2019-01-02 00:00:00')),
#  ('BRKMFC', Timestamp('2017-01-23 00:00:00')),
#  ('SWRAYM', Timestamp('2018-01-03 00:00:00')),
#  ('MEL', Timestamp('2016-03-07 00:00:00')),
#  ('CNDBK', Timestamp('2019-11-07 00:00:00')),
#  ('ITMAR', Timestamp('2017-06-21 00:00:00')),
#  ('BBVA', Timestamp('2018-05-03 00:00:00')),
#  ('AGDBC', Timestamp('2015-05-18 00:00:00')),
#  ('WHGVTS', Timestamp('2019-09-17 00:00:00')),
#  ('IBEFN', Timestamp('2017-09-06 00:00:00')),
#  ('CTDM', Timestamp('2019-06-20 00:00:00')),
#  ('VELLN', Timestamp('2019-09-27 00:00:00')),
#  ('HUAXG', Timestamp('2018-07-05 00:00:00')),
#  ('SENGV', Timestamp('2015-05-18 00:00:00')),
#  ('BNKJS', Timestamp('2019-04-16 00:00:00')),
#  ('GASI', Timestamp('2019-09-23 00:00:00')),
#  ('LRENT', Timestamp('2014-04-10 00:00:00')),
#  ('RZDCP', Timestamp('2019-05-16 00:00:00')),
#  ('OFFENO', Timestamp('2019-09-20 00:00:00')),
#  ('CVOY', Timestamp('2019-09-10 00:00:00')),
#  ('HUAXG', Timestamp('2015-05-18 00:00:00')),
#  ('SNCFER', Timestamp('2015-05-18 00:00:00')),
#  ('UNIKB', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2019-09-06 00:00:00')),
#  ('CABKO', Timestamp('2019-05-09 00:00:00')),
#  ('KFW', Timestamp('2019-07-30 00:00:00')),
#  ('EDF', Timestamp('2013-11-20 00:00:00')),
#  ('TSLAS', Timestamp('2015-05-11 00:00:00')),
#  ('ACSSE', Timestamp('2018-04-12 00:00:00')),
#  ('TSIHSH', Timestamp('2017-12-27 00:00:00')),
#  ('KFW', Timestamp('2015-11-10 00:00:00')),
#  ('TNETH', Timestamp('2018-06-01 00:00:00')),
#  ('CSCBK', Timestamp('2015-05-18 00:00:00')),
#  ('WBC', Timestamp('2017-11-16 00:00:00')),
#  ('DFC', Timestamp('2016-08-22 00:00:00')),
#  ('CARXE', Timestamp('2018-10-23 00:00:00')),
#  ('SICHAW', Timestamp('2019-03-11 00:00:00')),
#  ('MRBLD', Timestamp('2019-11-08 00:00:00')),
#  ('ATRLJ', Timestamp('2015-05-18 00:00:00')),
#  ('ORICO', Timestamp('2019-04-05 00:00:00')),
#  ('MTRCN', Timestamp('2017-07-18 00:00:00')),
#  ('IDBIDU', Timestamp('2015-11-23 00:00:00')),
#  ('TWCOFB', Timestamp('2019-11-25 00:00:00')),
#  ('OPPLYL', Timestamp('2018-02-01 00:00:00')),
#  ('OERBO', Timestamp('2019-10-02 00:00:00')),
#  ('EVRR', Timestamp('2018-11-21 00:00:00')),
#  ('ENGIE', Timestamp('2019-01-17 00:00:00')),
#  ('HELVIH', Timestamp('2017-06-21 00:00:00')),
#  ('TNETH', Timestamp('2017-06-12 00:00:00')),
#  ('TRN', Timestamp('2019-04-03 00:00:00')),
#  ('FABG', Timestamp('2018-09-07 00:00:00')),
#  ('MNCHY', Timestamp('2018-10-30 00:00:00')),
#  ('DFC', Timestamp('2017-03-20 00:00:00')),
#  ('SKAFL', Timestamp('2015-05-18 00:00:00')),
#  ('CAGRAB', Timestamp('2017-10-06 00:00:00')),
#  ('KOMBK', Timestamp('2016-10-19 00:00:00')),
#  ('QIFSC', Timestamp('2019-08-07 00:00:00')),
#  ('VASKNV', Timestamp('2018-01-09 00:00:00')),
#  ('HITCA', Timestamp('2019-02-22 00:00:00')),
#  ('YESB', Timestamp('2015-02-16 00:00:00')),
#  ('ALNDR', Timestamp('2016-04-18 00:00:00')),
#  ('NRWBK', Timestamp('2017-09-05 00:00:00')),
#  ('TD', Timestamp('2015-05-18 00:00:00')),
#  ('BAMWAF', Timestamp('2018-09-18 00:00:00')),
#  ('BOGZ', Timestamp('2018-11-13 00:00:00')),
#  ('SSEHT', Timestamp('2019-09-20 00:00:00')),
#  ('NEDJNE', Timestamp('2019-10-22 00:00:00')),
#  ('ACFTE', Timestamp('2019-01-22 00:00:00')),
#  ('TRPLD', Timestamp('2019-12-20 00:00:00')),
#  ('EESTEL', Timestamp('2015-05-18 00:00:00')),
#  ('KEXIM', Timestamp('2017-07-25 00:00:00')),
#  ('LRENT', Timestamp('2017-09-22 00:00:00')),
#  ('RENPW', Timestamp('2016-07-29 00:00:00')),
#  ('SGPXM', Timestamp('2014-10-23 00:00:00')),
#  ('CNVTF', Timestamp('2019-09-19 00:00:00')),
#  ('CDGODT', Timestamp('2018-11-30 00:00:00')),
#  ('JHFA', Timestamp('2019-12-06 00:00:00')),
#  ('OMEI', Timestamp('2017-12-11 00:00:00')),
#  ('EDC', Timestamp('2015-05-18 00:00:00')),
#  ('SBILO', Timestamp('2018-09-19 00:00:00')),
#  ('OSLOK', Timestamp('2015-12-02 00:00:00')),
#  ('FABG', Timestamp('2017-08-22 00:00:00')),
#  ('IBEFN', Timestamp('2018-12-21 00:00:00')),
#  ('GCLNW', Timestamp('2018-01-23 00:00:00')),
#  ('GEELYL', Timestamp('2016-05-19 00:00:00')),
#  ('CAGRAH', Timestamp('2019-11-27 00:00:00')),
#  ('KLBNDF', Timestamp('2017-09-12 00:00:00')),
#  ('LKBF', Timestamp('2017-12-05 00:00:00')),
#  ('MALMO', Timestamp('2019-02-20 00:00:00')),
#  ('AGDER', Timestamp('2017-10-27 00:00:00')),
#  ('LNDHYN', Timestamp('2018-05-16 00:00:00')),
#  ('AQNLP', Timestamp('2019-01-25 00:00:00')),
#  ('HERFTW', Timestamp('2016-02-15 00:00:00')),
#  ('EIDEN', Timestamp('2017-09-25 00:00:00')),
#  ('NORDLD', Timestamp('2018-09-03 00:00:00')),
#  ('HCMIF', Timestamp('2016-10-25 00:00:00')),
#  ('VERB', Timestamp('2014-11-13 00:00:00')),
#  ('ABNAM', Timestamp('2018-04-11 00:00:00')),
#  ('TLGOVI', Timestamp('2019-07-08 00:00:00')),
#  ('FABG', Timestamp('2015-05-18 00:00:00')),
#  ('VASKNV', Timestamp('2019-03-06 00:00:00')),
#  ('WHGVTS', Timestamp('2018-07-25 00:00:00')),
#  ('VESCO', Timestamp('2018-12-07 00:00:00')),
#  ('HERFTW', Timestamp('2016-12-20 00:00:00')),
#  ('IBEFN', Timestamp('2018-06-21 00:00:00')),
#  ('CAGRAB', Timestamp('2019-03-19 00:00:00')),
#  ('AAPL', Timestamp('2017-06-13 00:00:00')),
#  ('IBERD', Timestamp('2016-09-08 00:00:00')),
#  ('WCTES', Timestamp('2015-05-18 00:00:00')),
#  ('SASAEJ', Timestamp('2016-09-22 00:00:00')),
#  ('SASAXX', Timestamp('2016-09-26 00:00:00')),
#  ('FUXIN', Timestamp('2019-07-11 00:00:00')),
#  ('SICUM', Timestamp('2018-08-15 00:00:00')),
#  ('HZUBK', Timestamp('2019-08-14 00:00:00')),
#  ('VASKNV', Timestamp('2019-09-09 00:00:00')),
#  ('AZREA', Timestamp('2017-07-27 00:00:00')),
#  ('KGYEYT', Timestamp('2015-05-18 00:00:00')),
#  ('DFC', Timestamp('2018-12-10 00:00:00')),
#  ('CENMT', Timestamp('2018-09-05 00:00:00')),
#  ('IREDA', Timestamp('2019-01-02 00:00:00')),
#  ('TSLAS', Timestamp('2015-03-23 00:00:00')),
#  ('VASKNV', Timestamp('2016-10-11 00:00:00')),
#  ('MTSFD', Timestamp('2019-09-06 00:00:00')),
#  ('YPBTRM', Timestamp('2017-12-28 00:00:00')),
#  ('TNETH', Timestamp('2017-03-29 00:00:00')),
#  ('NDLWR', Timestamp('2015-05-18 00:00:00')),
#  ('PTNL', Timestamp('2019-09-16 00:00:00')),
#  ('HZCIGD', Timestamp('2019-12-13 00:00:00')),
#  ('UITMPS', Timestamp('2018-04-25 00:00:00')),
#  ('ACFTE', Timestamp('2019-01-31 00:00:00')),
#  ('ICBALF', Timestamp('2019-11-13 00:00:00')),
#  ('PARIS', Timestamp('2015-11-09 00:00:00')),
#  ('ENEIEG', Timestamp('2015-05-18 00:00:00')),
#  ('NAFIN', Timestamp('2015-10-29 00:00:00')),
#  ('ASEDVB', Timestamp('2015-05-18 00:00:00')),
#  ('TWBSB', Timestamp('2017-12-28 00:00:00')),
#  ('CAGRAB', Timestamp('2015-05-18 00:00:00')),
#  ('KOMBK', Timestamp('2017-11-22 00:00:00')),
#  ('JRFIC', Timestamp('2019-06-12 00:00:00')),
#  ('STKBO', Timestamp('2016-11-21 00:00:00')),
#  ('TSLAS', Timestamp('2015-06-22 00:00:00')),
#  ('ALSSBM', Timestamp('2019-02-26 00:00:00')),
#  ('EDF', Timestamp('2015-10-07 00:00:00')),
#  ('HUMLG', Timestamp('2019-09-30 00:00:00')),
#  ('BARC', Timestamp('2017-11-06 00:00:00')),
#  ('LAPST', Timestamp('2018-11-23 00:00:00')),
#  ('EBKGI', Timestamp('2018-04-27 00:00:00')),
#  ('BLGGD', Timestamp('2017-09-19 00:00:00')),
#  ('BKCHNX', Timestamp('2015-05-18 00:00:00')),
#  ('FORSAW', Timestamp('2019-01-10 00:00:00')),
#  ('STEXE', Timestamp('2015-05-12 00:00:00')),
#  ('KFW', Timestamp('2019-08-20 00:00:00')),
#  ('CAGRAB', Timestamp('2018-01-19 00:00:00')),
#  ('SOGRP', Timestamp('2019-03-12 00:00:00')),
#  ('QINGDD', Timestamp('2019-02-25 00:00:00')),
#  ('CHGQTO', Timestamp('2019-04-17 00:00:00')),
#  ('SEKRT', Timestamp('2019-10-25 00:00:00')),
#  ('FRNYKR', Timestamp('2019-05-29 00:00:00')),
#  ('SOPWR', Timestamp('2015-11-12 00:00:00')),
#  ('LVENG', Timestamp('2016-04-14 00:00:00')),
#  ('LNTST', Timestamp('2018-09-19 00:00:00')),
#  ('SOGNER', Timestamp('2019-07-08 00:00:00')),
#  ('IDCOL', Timestamp('2019-04-05 00:00:00')),
#  ('GTBRG', Timestamp('2016-06-08 00:00:00')),
#  ('JRCTT', Timestamp('2019-08-23 00:00:00')),
#  ('VASKNV', Timestamp('2015-10-20 00:00:00')),
#  ('CAGRAB', Timestamp('2017-10-11 00:00:00')),
#  ('MALMO', Timestamp('2019-10-22 00:00:00')),
#  ('HUANAB', Timestamp('2018-04-19 00:00:00')),
#  ('OPOSUY', Timestamp('2019-02-19 00:00:00')),
#  ('SNCFER', Timestamp('2017-07-11 00:00:00')),
#  ('INCI', Timestamp('2014-10-21 00:00:00')),
#  ('WOW', Timestamp('2019-04-12 00:00:00')),
#  ('GYCBK', Timestamp('2019-09-05 00:00:00')),
#  ('NACKA', Timestamp('2018-06-07 00:00:00')),
#  ('TCV', Timestamp('2016-07-18 00:00:00')),
#  ('RIKINR', Timestamp('2015-05-18 00:00:00')),
#  ('SOLTA', Timestamp('2019-01-25 00:00:00')),
#  ('KNDIX', Timestamp('2019-02-08 00:00:00')),
#  ('QBE', Timestamp('2015-05-18 00:00:00')),
#  ('STIABN', Timestamp('2019-09-12 00:00:00')),
#  ('ITOCA', Timestamp('2019-12-06 00:00:00')),
#  ('YPBTRM', Timestamp('2019-12-24 00:00:00')),
#  ('FAB', Timestamp('2017-03-27 00:00:00')),
#  ('STRGYW', Timestamp('2018-04-18 00:00:00')),
#  ('MTFGI', Timestamp('2019-07-16 00:00:00')),
#  ('KOMBK', Timestamp('2019-08-22 00:00:00')),
#  ('BAZLEF', Timestamp('2018-04-13 00:00:00')),
#  ('BOB', Timestamp('2016-12-01 00:00:00')),
#  ('ALPER', Timestamp('2017-10-17 00:00:00')),
#  ('KFW', Timestamp('2017-05-09 00:00:00')),
#  ('SASAHR', Timestamp('2016-07-07 00:00:00')),
#  ('OERBO', Timestamp('2017-12-08 00:00:00')),
#  ('C', Timestamp('2019-01-22 00:00:00')),
#  ('NSWTC', Timestamp('2018-11-09 00:00:00')),
#  ('HALUP', Timestamp('2018-07-10 00:00:00')),
#  ('GTBRG', Timestamp('2019-09-17 00:00:00')),
#  ('KOMEFS', Timestamp('2018-04-23 00:00:00')),
#  ('NDLWR', Timestamp('2017-04-04 00:00:00')),
#  ('XTRCB', Timestamp('2019-11-28 00:00:00')),
#  ('ENGIE', Timestamp('2015-05-18 00:00:00')),
#  ('FABG', Timestamp('2019-03-15 00:00:00')),
#  ('XELPS', Timestamp('2018-06-14 00:00:00')),
#  ('FABG', Timestamp('2017-09-19 00:00:00')),
#  ('EEOCA', Timestamp('2018-04-19 00:00:00')),
#  ('LTFHRA', Timestamp('2017-06-28 00:00:00')),
#  ('JHJHNG', Timestamp('2019-11-27 00:00:00')),
#  ('EXIMB', Timestamp('2015-05-18 00:00:00')),
#  ('SNCFER', Timestamp('2016-10-27 00:00:00')),
#  ('PKOHTZ', Timestamp('2019-06-10 00:00:00')),
#  ('QINGDD', Timestamp('2018-08-13 00:00:00')),
#  ('TCLEA', Timestamp('2018-06-21 00:00:00')),
#  ('NAB', Timestamp('2018-08-22 00:00:00')),
#  ('WALL', Timestamp('2019-05-15 00:00:00')),
#  ('SOGRP', Timestamp('2019-04-08 00:00:00')),
#  ('SNCFER', Timestamp('2017-03-22 00:00:00')),
#  ('MNDEFA', Timestamp('2018-04-23 00:00:00')),
#  ('WBC', Timestamp('2015-05-18 00:00:00')),
#  ('FZGOVD', Timestamp('2019-07-16 00:00:00')),
#  ('SIKAM', Timestamp('2018-01-26 00:00:00')),
#  ('NODTR', Timestamp('2015-05-18 00:00:00')),
#  ('SOGNTW', Timestamp('2019-07-09 00:00:00')),
#  ('COFX', Timestamp('2019-10-22 00:00:00')),
#  ('FINGD', Timestamp('2017-11-16 00:00:00')),
#  ('MODLA', Timestamp('2018-02-27 00:00:00')),
#  ('EDF', Timestamp('2017-01-20 00:00:00')),
#  ('JENEN', Timestamp('2019-04-15 00:00:00')),
#  ('GDONPD', Timestamp('2019-10-16 00:00:00')),
#  ('WHGVTS', Timestamp('2016-10-25 00:00:00')),
#  ('TNETH', Timestamp('2015-05-28 00:00:00')),
#  ('AGUA', Timestamp('2017-06-27 00:00:00')),
#  ('CONTUE', Timestamp('2014-12-15 00:00:00')),
#  ('LOTEJC', Timestamp('2018-07-31 00:00:00')),
#  ('SCAA', Timestamp('2017-11-01 00:00:00')),
#  ('OSTND', Timestamp('2019-09-10 00:00:00')),
#  ('JOHNB', Timestamp('2014-06-09 00:00:00')),
#  ('ATRLJ', Timestamp('2018-08-30 00:00:00')),
#  ('KAER', Timestamp('2017-09-29 00:00:00')),
#  ('BAMOHL', Timestamp('2015-05-18 00:00:00')),
#  ('CPFECI', Timestamp('2015-05-18 00:00:00')),
#  ('STGRE', Timestamp('2015-05-18 00:00:00')),
#  ('UMQCB', Timestamp('2015-05-18 00:00:00')),
#  ('BNP', Timestamp('2019-03-01 00:00:00')),
#  ('CAGRAB', Timestamp('2017-05-22 00:00:00')),
#  ('CENXX', Timestamp('2015-08-28 00:00:00')),
#  ('NAB', Timestamp('2017-02-28 00:00:00')),
#  ('ADRBCA', Timestamp('2015-05-18 00:00:00')),
#  ('KOMEFS', Timestamp('2015-05-18 00:00:00')),
#  ('BKWB', Timestamp('2019-07-01 00:00:00')),
#  ('SUNTG', Timestamp('2019-02-27 00:00:00')),
#  ('BNP', Timestamp('2019-02-21 00:00:00')),
#  ('SBBHF', Timestamp('2015-05-18 00:00:00')),
#  ('DFC', Timestamp('2019-03-11 00:00:00')),
#  ('GLPCP', Timestamp('2018-12-14 00:00:00')),
#  ('BKCOM', Timestamp('2016-11-15 00:00:00')),
#  ('CNCBLK', Timestamp('2019-10-15 00:00:00')),
#  ('SASADH', Timestamp('2018-07-31 00:00:00')),
#  ('KOMEFS', Timestamp('2017-05-17 00:00:00')),
#  ('SPDEV', Timestamp('2016-03-22 00:00:00')),
#  ('NRWBK', Timestamp('2016-11-10 00:00:00')),
#  ('CCGMH', Timestamp('2015-05-18 00:00:00')),
#  ('ENCEN', Timestamp('2018-11-20 00:00:00')),
#  ('LNTST', Timestamp('2019-03-25 00:00:00')),
#  ('EVRGT', Timestamp('2016-06-13 00:00:00')),
#  ('CAGRAB', Timestamp('2018-02-27 00:00:00')),
#  ('SFFHOS', Timestamp('2018-11-30 00:00:00')),
#  ('KFW', Timestamp('2016-05-12 00:00:00')),
#  ('BOBJG', Timestamp('2017-04-13 00:00:00')),
#  ('VASKNV', Timestamp('2018-09-07 00:00:00')),
#  ('IREDA', Timestamp('2017-03-03 00:00:00')),
#  ('LNDHYN', Timestamp('2019-11-08 00:00:00')),
#  ('ZJCZC', Timestamp('2018-05-31 00:00:00')),
#  ('CAGRAB', Timestamp('2017-12-28 00:00:00')),
#  ('IREDA', Timestamp('2017-02-22 00:00:00')),
#  ('ENGIE', Timestamp('2014-05-12 00:00:00')),
#  ('ENTRA', Timestamp('2017-03-15 00:00:00')),
#  ('BJEWGC', Timestamp('2016-10-26 00:00:00')),
#  ('RABO', Timestamp('2019-10-22 00:00:00')),
#  ('ORSTE', Timestamp('2019-11-27 00:00:00')),
#  ('VASKNV', Timestamp('2019-05-29 00:00:00')),
#  ('QTC', Timestamp('2019-02-27 00:00:00')),
#  ('ELECSF', Timestamp('2019-06-07 00:00:00')),
#  ('KFW', Timestamp('2016-11-22 00:00:00')),
#  ('AGBKFH', Timestamp('2019-05-29 00:00:00')),
#  ('EVRR', Timestamp('2016-12-07 00:00:00')),
#  ('BKCHIN', Timestamp('2017-11-15 00:00:00')),
#  ('MSULF', Timestamp('2018-04-11 00:00:00')),
#  ('ABNAM', Timestamp('2019-04-08 00:00:00')),
#  ('ARISE', Timestamp('2018-03-09 00:00:00')),
#  ('TSLAS', Timestamp('2015-08-31 00:00:00')),
#  ('TOKTT', Timestamp('2019-03-08 00:00:00')),
#  ('BALDL', Timestamp('2019-10-31 00:00:00')),
#  ('BJEWGC', Timestamp('2016-09-09 00:00:00')),
#  ('EVRBKH', Timestamp('2018-09-13 00:00:00')),
#  ('MTRCNC', Timestamp('2015-05-18 00:00:00')),
#  ('HRA', Timestamp('2019-06-26 00:00:00')),
#  ('SFFHOS', Timestamp('2018-08-27 00:00:00')),
#  ('ANWTRR', Timestamp('2017-07-31 00:00:00')),
#  ('MTFGI', Timestamp('2018-12-07 00:00:00')),
#  ('BRKMFC', Timestamp('2018-01-29 00:00:00')),
#  ('ENTRA', Timestamp('2016-09-16 00:00:00')),
#  ('BJEWG', Timestamp('2016-07-29 00:00:00')),
#  ('DACCO', Timestamp('2018-12-20 00:00:00')),
#  ('DFC', Timestamp('2016-06-15 00:00:00')),
#  ('SKIRJ', Timestamp('2018-12-06 00:00:00')),
#  ('BKCHNL', Timestamp('2018-05-31 00:00:00')),
#  ('HSTLP', Timestamp('2019-09-12 00:00:00')),
#  ('RBIV', Timestamp('2018-07-03 00:00:00')),
#  ('FUDIAN', Timestamp('2018-08-23 00:00:00')),
#  ('KITUS', Timestamp('2017-10-18 00:00:00')),
#  ('WCTES', Timestamp('2018-01-04 00:00:00')),
#  ('SRTFGB', Timestamp('2019-12-17 00:00:00')),
#  ('SINOPD', Timestamp('2017-05-16 00:00:00')),
#  ('PSTATG', Timestamp('2019-09-23 00:00:00')),
#  ('SUOYL', Timestamp('2018-11-02 00:00:00')),
#  ('ESTRW', Timestamp('2019-05-10 00:00:00')),
#  ('SKAFL', Timestamp('2018-05-17 00:00:00')),
#  ('NOBIN', Timestamp('2019-02-06 00:00:00')),
#  ('CGPWI', Timestamp('2015-05-18 00:00:00')),
#  ('TAEECJ', Timestamp('2015-05-18 00:00:00')),
#  ('VAEST', Timestamp('2016-11-30 00:00:00')),
#  ('ATRLJ', Timestamp('2017-03-15 00:00:00')),
#  ('BNS', Timestamp('2019-07-15 00:00:00')),
#  ('VOD', Timestamp('2019-05-21 00:00:00')),
#  ('KOMEFS', Timestamp('2018-10-16 00:00:00')),
#  ('GEALGR', Timestamp('2015-05-18 00:00:00')),
#  ('FUYOG', Timestamp('2018-10-26 00:00:00')),
#  ('NTPC', Timestamp('2016-08-03 00:00:00')),
#  ('STERV', Timestamp('2019-02-18 00:00:00')),
#  ('RMNTCN', Timestamp('2019-11-28 00:00:00')),
#  ('DFC', Timestamp('2015-11-16 00:00:00')),
#  ('VELLN', Timestamp('2018-06-11 00:00:00')),
#  ('BBVA', Timestamp('2019-06-21 00:00:00')),
#  ('TODA', Timestamp('2017-12-08 00:00:00')),
#  ('VASKNV', Timestamp('2019-02-18 00:00:00')),
#  ('ALTUM', Timestamp('2017-10-05 00:00:00')),
#  ('BNDES', Timestamp('2017-05-02 00:00:00')),
#  ('PKOHTZ', Timestamp('2019-12-02 00:00:00')),
#  ('YESB', Timestamp('2016-12-28 00:00:00')),
#  ('LMTREB', Timestamp('2019-07-18 00:00:00')),
#  ('SSE', Timestamp('2017-08-30 00:00:00')),
#  ('VASKNV', Timestamp('2019-01-23 00:00:00')),
#  ('CPPIBC', Timestamp('2019-12-03 00:00:00')),
#  ('SDFLCF', Timestamp('2019-11-05 00:00:00')),
#  ('SEVIAA', Timestamp('2018-03-15 00:00:00')),
#  ('CASTZ', Timestamp('2016-09-26 00:00:00')),
#  ('DLRDE', Timestamp('2019-01-11 00:00:00')),
#  ('SRBANB', Timestamp('2019-10-01 00:00:00')),
#  ('NBCBK', Timestamp('2018-10-22 00:00:00')),
#  ('LNPSHS', Timestamp('2015-09-09 00:00:00')),
#  ('TSLAS', Timestamp('2015-07-20 00:00:00')),
#  ('FABG', Timestamp('2019-03-25 00:00:00')),
#  ('MALMO', Timestamp('2017-12-04 00:00:00')),
#  ('DNBDB', Timestamp('2018-06-12 00:00:00')),
#  ('SBARQ', Timestamp('2015-05-18 00:00:00')),
#  ('MOEATF', Timestamp('2019-12-09 00:00:00')),
#  ('SFFHOS', Timestamp('2017-02-10 00:00:00')),
#  ('LKBF', Timestamp('2018-06-18 00:00:00')),
#  ('XINGON', Timestamp('2015-05-18 00:00:00')),
#  ('KAER', Timestamp('2019-07-15 00:00:00')),
#  ('ADNGN', Timestamp('2019-03-31 00:00:00')),
#  ('ANAFN', Timestamp('2017-09-08 00:00:00')),
#  ('CECWP', Timestamp('2017-09-05 00:00:00')),
#  ('DTEED', Timestamp('2019-02-11 00:00:00')),
#  ('CAGRAB', Timestamp('2017-09-01 00:00:00')),
#  ('ORSTE', Timestamp('2017-11-16 00:00:00')),
#  ('NETHR', Timestamp('2019-02-11 00:00:00')),
#  ('BPCSA', Timestamp('2019-11-26 00:00:00')),
#  ('AERIT', Timestamp('2019-11-15 00:00:00')),
#  ('CVOY', Timestamp('2016-05-09 00:00:00')),
#  ('ATRLJ', Timestamp('2017-10-19 00:00:00')),
#  ('VASKNV', Timestamp('2018-01-25 00:00:00')),
#  ('MARUI', Timestamp('2018-10-19 00:00:00')),
#  ('INGTR', Timestamp('2017-07-07 00:00:00')),
#  ('URW', Timestamp('2015-04-08 00:00:00')),
#  ('SICUM', Timestamp('2018-01-18 00:00:00')),
#  ('BJCPC', Timestamp('2015-05-18 00:00:00')),
#  ('FSPCNN', Timestamp('2019-06-14 00:00:00')),
#  ('BLGGD', Timestamp('2016-06-01 00:00:00')),
#  ('EAXX', Timestamp('2019-06-04 00:00:00')),
#  ('BPI', Timestamp('2019-09-02 00:00:00')),
#  ('SBB', Timestamp('2015-05-18 00:00:00')),
#  ('NDLWR', Timestamp('2018-11-27 00:00:00')),
#  ('DBAHNE', Timestamp('2017-10-23 00:00:00')),
#  ('SUNSB', Timestamp('2019-01-24 00:00:00')),
#  ('HITZO', Timestamp('2018-09-14 00:00:00')),
#  ('KFW', Timestamp('2019-07-17 00:00:00')),
#  ('HKCNGF', Timestamp('2017-11-14 00:00:00')),
#  ('AUMRCC', Timestamp('2019-11-19 00:00:00')),
#  ('KFW', Timestamp('2017-09-25 00:00:00')),
#  ('PPSIB', Timestamp('2019-02-12 00:00:00')),
#  ('VASKNV', Timestamp('2019-11-12 00:00:00')),
#  ('KLED', Timestamp('2019-12-04 00:00:00')),
#  ('DFC', Timestamp('2014-11-13 00:00:00')),
#  ('CWENCC', Timestamp('2015-05-18 00:00:00')),
#  ('OBAYA', Timestamp('2018-10-19 00:00:00')),
#  ('TSLAS', Timestamp('2015-06-15 00:00:00')),
#  ('ING', Timestamp('2018-11-08 00:00:00')),
#  ('SOPWR', Timestamp('2015-05-18 00:00:00')),
#  ('RIKINR', Timestamp('2016-11-15 00:00:00')),
#  ('CAGR', Timestamp('2019-10-14 00:00:00')),
#  ('MITES', Timestamp('2018-06-20 00:00:00')),
#  ('VASKNV', Timestamp('2019-08-22 00:00:00')),
#  ('VASKNV', Timestamp('2018-01-24 00:00:00')),
#  ('GREG', Timestamp('2019-11-08 00:00:00')),
#  ('KITUS', Timestamp('2016-09-27 00:00:00')),
#  ('SVSKG', Timestamp('2019-04-11 00:00:00')),
#  ('PPSIN', Timestamp('2019-10-31 00:00:00')),
#  ('AMZCB', Timestamp('2015-05-18 00:00:00')),
#  ('HKCNGF', Timestamp('2017-11-08 00:00:00')),
#  ('KEPCOM', Timestamp('2019-01-14 00:00:00')),
#  ('PNBKH', Timestamp('2016-03-30 00:00:00')),
#  ('ZYBCL', Timestamp('2018-04-19 00:00:00')),
#  ('HYMTRD', Timestamp('2019-01-29 00:00:00')),
#  ('OERBO', Timestamp('2019-06-11 00:00:00')),
#  ('KOMEFS', Timestamp('2019-11-13 00:00:00')),
#  ('DFC', Timestamp('2015-03-10 00:00:00')),
#  ('GARAN', Timestamp('2019-12-20 00:00:00')),
#  ('SOGFJ', Timestamp('2019-04-10 00:00:00')),
#  ('ENGIE', Timestamp('2019-10-17 00:00:00')),
#  ('REIVL', Timestamp('2019-07-05 00:00:00')),
#  ('JRFIC', Timestamp('2018-05-11 00:00:00')),
#  ('CNPEDC', Timestamp('2015-05-18 00:00:00')),
#  ('BKCHNW', Timestamp('2015-05-18 00:00:00')),
#  ('RIKINR', Timestamp('2017-10-12 00:00:00')),
#  ('CDGODT', Timestamp('2019-02-28 00:00:00')),
#  ('ANAFN', Timestamp('2019-10-02 00:00:00')),
#  ('BAZLEF', Timestamp('2018-05-14 00:00:00')),
#  ('HSBASR', Timestamp('2015-11-25 00:00:00')),
#  ('CNCBLK', Timestamp('2018-09-17 00:00:00')),
#  ('MALMO', Timestamp('2018-11-19 00:00:00')),
#  ('ANWTRR', Timestamp('2018-11-29 00:00:00')),
#  ('GTBRG', Timestamp('2018-10-23 00:00:00')),
#  ('PAPIG', Timestamp('2015-05-18 00:00:00')),
#  ('ODERY', Timestamp('2019-01-10 00:00:00')),
#  ('HANEN', Timestamp('2019-07-23 00:00:00')),
#  ('ASEID', Timestamp('2019-09-27 00:00:00')),
#  ('BEJINK', Timestamp('2018-11-21 00:00:00')),
#  ('AB', Timestamp('2019-07-05 00:00:00')),
#  ('INGBK', Timestamp('2015-05-18 00:00:00')),
#  ('IREDA', Timestamp('2019-01-16 00:00:00')),
#  ('VASKNV', Timestamp('2019-02-19 00:00:00')),
#  ('CNFBG', Timestamp('2018-05-02 00:00:00')),
#  ('SOGNTW', Timestamp('2019-07-05 00:00:00')),
#  ('RCB', Timestamp('2015-05-18 00:00:00')),
#  ('MS', Timestamp('2015-05-18 00:00:00')),
#  ('AAPL', Timestamp('2016-02-16 00:00:00')),
#  ('CAGRAF', Timestamp('2019-05-08 00:00:00')),
#  ('IGYIG', Timestamp('2017-10-13 00:00:00')),
#  ...}

# %%
a = get_stock_data('BNP', pd.to_datetime('2019-02-27'))

# %%
is_private['BNP']
# Out:
# True

# %% [markdown]
# # EIKON

# %%
symbolList = ["AMXL.MX", "CMXCPO.MX"]
ret = ek.get_timeseries(symbolList, start_date="2018-09-06T20:00:00", end_date="2018-09-06T20:10:00",
                        interval="tick", raw_output=True)
# Out:
# 2020-10-17 15:24:54,870 P[2016] [MainThread 6384] Error with AMXL.MX: No data available for the requested date range
# 2020-10-17 15:24:54,870 P[2016] [MainThread 6384] Error with CMXCPO.MX: No data available for the requested date range
# 2020-10-17 15:24:54,870 P[2016] [MainThread 6384] AMXL.MX: No data available for the requested date range | CMXCPO.MX: No data available for the requested date range |
# ---------------------------------------------------------------------------
# EikonError                                Traceback (most recent call last)
# <ipython-input-32-826a01581b4e> in <module>
#       1 symbolList = ["AMXL.MX", "CMXCPO.MX"]
#       2 ret = ek.get_timeseries(symbolList, start_date="2018-09-06T20:00:00", end_date="2018-09-06T20:10:00",
# ----> 3                         interval="tick", raw_output=True)
#
# ~\miniconda3\lib\site-packages\eikon\time_series.py in get_timeseries(rics, fields, start_date, end_date, interval, count, calendar, corax, normalize, raw_output, debug)
#     197     if len(ts_status_errors) == len(ts_timeserie_data):
#     198         logger.error(ts_error_messages)
# --> 199         raise EikonError(-1, message=ts_error_messages)
#     200
#     201     if raw_output: return ts_result
#
# EikonError: Error code -1 | AMXL.MX: No data available for the requested date range | CMXCPO.MX: No data available for the requested date range |

# %%
ek.get_data(['VOD.L', 'GOOG.O'],
            ['TR.PriceClose.date','TR.PriceClose'],
           {'SDate':'24-Sep-2018', 'EDate':'29-Oct-2019'})
# Out:
# (    Instrument                  Date  Price Close
#  0        VOD.L  2018-09-24T00:00:00Z       170.00
#  1        VOD.L  2018-09-25T00:00:00Z       168.74
#  2        VOD.L  2018-09-26T00:00:00Z       166.94
#  3        VOD.L  2018-09-27T00:00:00Z       168.14
#  4        VOD.L  2018-09-28T00:00:00Z       164.50
#  ..         ...                   ...          ...
#  551     GOOG.O  2019-10-23T00:00:00Z      1259.13
#  552     GOOG.O  2019-10-24T00:00:00Z      1260.99
#  553     GOOG.O  2019-10-25T00:00:00Z      1265.13
#  554     GOOG.O  2019-10-28T00:00:00Z      1290.00
#  555     GOOG.O  2019-10-29T00:00:00Z      1262.62
#
#  [556 rows x 3 columns],
#  None)

# %%
ek.get_timeseries(['VOD.L', 'GOOG.O'], 
                  start_date=timedelta(-5), 
                  end_date=timedelta(0), 
                  interval='day')
# Out:
# 2020-10-16 20:28:39,524 P[13876] [MainThread 1836] Can not process metadata for request: TimeSeries.interval - value doesn't fall in valid range: [tick tas taq tastaq minute hour session daily weekly monthly quarterly yearly]
# ---------------------------------------------------------------------------
# EikonError                                Traceback (most recent call last)
# <ipython-input-16-887b484b5679> in <module>
#       2                   start_date=timedelta(-5),
#       3                   end_date=timedelta(0),
# ----> 4                   interval='day')
#
# ~\miniconda3\lib\site-packages\eikon\time_series.py in get_timeseries(rics, fields, start_date, end_date, interval, count, calendar, corax, normalize, raw_output, debug)
#     177                 raise ValueError(error_msg)
#     178
# --> 179     ts_result = eikon.json_requests.send_json_request(TimeSeries_UDF_endpoint, payload, debug=debug)
#     180
#     181     # Catch all errors to raise a warning
#
# ~\miniconda3\lib\site-packages\eikon\json_requests.py in send_json_request(entity, payload, debug)
#     125                         ticket = _check_ticket_async(result)
#     126
# --> 127                 _check_server_error(result)
#     128                 return result
#     129             else:
#
# ~\miniconda3\lib\site-packages\eikon\json_requests.py in _check_server_error(server_response)
#     201             status, reason_phrase, version, content, headers = error_message.split(',')[:5]
#     202         logger.error(error_message)
# --> 203         raise EikonError(int(server_response['ErrorCode']), error_message)
#     204
#     205     # check DataGrid response (server response is JSON and it can contain error + transactionId keys)
#
# EikonError: Error code 1422 | Can not process metadata for request: TimeSeries.interval - value doesn't fall in valid range: [tick tas taq tastaq minute hour session daily weekly monthly quarterly yearly]

# %%
error
