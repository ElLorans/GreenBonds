# %%
import eikon as ek
import pandas as pd

from utilities import columns, filter_dataset

# %% [markdown]
# # CONSTANTS

# %%
with open('key.secret') as file:
    KEY = file.read()

# %%
FILENAME = 'green_bonds_IsPublic.csv'

# %%
try:
    ek.set_app_key(KEY)
    bonds, err = ek.get_data(['CN151819SH='], 'TR.FirstAnnounceDate')
    if bonds['First Announcement Date'][0] != '2019-07-11':
        raise ValueError
except ek.EikonError:
    raise ValueError('Please check key.secret, then run Eikon Desktop or Eikon API Proxy')

# %% [markdown]
# # CHECK DB

# %%
green_bonds = pd.read_csv(FILENAME, parse_dates=['Issue Date'])

# %%
col_set = set(green_bonds.columns)

if columns.col_names != col_set:
    if len(col_set) < len(columns.col_names):
        raise TypeError(
            f"{columns.col_names - set(green_bonds.columns)} ARE MISSING COLUMNS!")

    elif len(col_set) > len(columns.col_names):
        raise TypeError(f"{set(green_bonds.columns) - columns.col_names} ARE ADDITIONAL COLUMNS!\nPlease ADD THEM"
                        " to columns.py OR REMOVE THEM")

    else:
        raise TypeError(
            f"{columns.col_names - set(green_bonds.columns)} ARE MISSING COLUMNS!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-fdcb57767155> in <module>
#       7
#       8     elif len(col_set) > len(columns.col_names):
# ----> 9         raise TypeError(f"{set(green_bonds.columns) - columns.col_names} ARE ADDITIONAL COLUMNS!\nPlease ADD THEM"
#      10                         " to columns.py OR REMOVE THEM")
#      11
#
# TypeError: {'IsPublic'} ARE ADDITIONAL COLUMNS!
# Please ADD THEM to columns.py OR REMOVE THEM

# %% [markdown]
# # FILTER DB

# %%
green_bonds = filter_dataset.filter_dataset(green_bonds)
# Out:
# Excluded 0 rows over 1871. Green bonds before 2009 must be due to errors and 2020 might pollute data due to COVID and year not finished yet.

# %% [markdown]
# # GET FIRST ANNOUNCEMENT DATE

# %%
bonds, err = ek.get_data(green_bonds.ISIN.dropna().to_list(), 'TR.FirstAnnounceDate')

# %%
bonds
# Out:
#         Instrument First Announcement Date
# 0     XS1890845875              2019-02-05
# 1     CND10000C3L5              2016-09-01
# 2     XS2082433736              2019-11-26
# 3     CND100017CJ8              2017-09-08
# 4     CND10001WQ91              2019-01-02
# ...            ...                     ...
# 1849  XS1207105161              2015-03-20
# 1850  US83417KFC71              2015-11-30
# 1851  XS1512929842              2016-10-28
# 1852  XS1566937154              2017-07-26
# 1853  US83417KBK34              2015-05-18
#
# [1854 rows x 2 columns]

# %%
isin_to_date = dict(zip(bonds['Instrument'], bonds['First Announcement Date']))

# %%
isin_to_date
# Out:
# {'XS1890845875': '2019-02-05',
#  'CND10000C3L5': '2016-09-01',
#  'XS2082433736': '2019-11-26',
#  'CND100017CJ8': '2017-09-08',
#  'CND10001WQ91': '2019-01-02',
#  'XS2079413527': '2019-11-18',
#  'FR0013310505': '2018-01-10',
#  'CND100017C17': '2016-10-26',
#  'XS1721244371': '2017-11-15',
#  'XS1591694481': '2017-03-29',
#  'XS1797138960': '2018-03-19',
#  'CND10000C3M3': '2016-05-23',
#  'INE028A08083': '2016-12-01',
#  'CND1000163S9': '2018-04-04',
#  'XS1908374322': '2018-11-28',
#  'FR0013398229': '2019-01-17',
#  'CND100017CK6': '2018-05-24',
#  'CND10000J7Q8': '2017-09-12',
#  'HK0000525334': '2019-09-09',
#  'US83417KDY10': '2015-09-14',
#  'XS0970680541': '2013-09-05',
#  'XS1882030510': '2018-09-18',
#  'XS1687735107': '2017-09-26',
#  'US48245ACL35': '2017-09-25',
#  'XS1566941933': '2017-09-01',
#  'US83417KED63': '2015-09-14',
#  'MYBVG1702910': '2017-10-04',
#  'XS1691909334': '2017-09-28',
#  'XS1692890343': '2017-09-28',
#  'US83417KEJ34': '2015-10-16',
#  'US865622BY94': '2015-10-14',
#  'XS1303791336': '2015-10-02',
#  'SE0007666128': '2015-10-20',
#  'SE0007666136': '2015-10-20',
#  'XS1508672828': '2016-10-19',
#  'US50048MCD02': '2016-10-26',
#  'XS1311459694': '2015-10-20',
#  'US83417KEP93': '2015-11-02',
#  'USP7071QAA24': '2015-10-29',
#  'US629598AS28': '2015-10-29',
#  'US83417KEU88': '2015-11-16',
#  'XS1566943558': '2017-10-18',
#  'XS1720540217': '2017-11-15',
#  'XS1720540308': '2017-11-15',
#  'XS1324217733': '2015-11-17',
#  'SE0011088814': '2018-05-17',
#  'XS1324923520': '2015-11-18',
#  'SE0011643105': '2018-11-20',
#  'XS1878123139': '2018-11-22',
#  'US500769GU24': '2015-11-10',
#  'XS1325600994': '2015-11-23',
#  'CND10000L024': '2017-11-23',
#  'FR0013064755': '2015-11-25',
#  'SE0010599423': '2018-11-30',
#  'US83417KEZ75': '2015-11-16',
#  'US22411WAL00': '2019-12-03',
#  'US22411VAL27': '2019-12-03',
#  'XS1333145040': '2015-12-07',
#  'XS1417413140': '2016-11-10',
#  'US83417KFE38': '2015-11-30',
#  'ARPLAZ560011': '2017-12-14',
#  'US83417KFK97': '2015-12-14',
#  'TW000G121289': '2017-12-28',
#  'MYBUG1800047': '2018-01-04',
#  'XS1334472708': '2017-11-28',
#  'US83417KFQ67': '2015-12-28',
#  'XS1676123851': '2018-01-16',
#  'SE0010599084': '2018-01-24',
#  'XS1351716896': '2016-01-20',
#  'XS1334467450': '2018-01-19',
#  'MYBVG1800508': '2018-01-26',
#  'XS1746281226': '2018-01-23',
#  'US302154BZ10': '2016-02-02',
#  'SE0011062298': '2018-03-16',
#  'XS1334475123': '2018-02-27',
#  'MYBVF1900466': '2019-02-27',
#  'SE0008092795': '2016-03-01',
#  'SE0008092787': '2016-03-01',
#  'XS1334474829': '2018-01-10',
#  'XS1334464861': '2018-01-24',
#  'SE0010948661': '2018-02-27',
#  'XS1775946285': '2018-02-27',
#  'CND10000L966': '2018-03-08',
#  'USY3815NAV39': '2016-03-07',
#  'SE0010920900': '2018-03-09',
#  'US44920UAG31': '2016-03-07',
#  'XS1792571652': '2018-03-19',
#  'CND100010PP2': '2018-03-23',
#  'CND100009JH4': '2016-03-22',
#  'INE572E07019': '2016-03-30',
#  'MYBVH1702926': '2017-10-04',
#  'CND10000LQW6': '2018-04-04',
#  'SE0011088756': '2018-04-11',
#  'CND10000LTB4': '2018-04-19',
#  'TW000G189AR7': '2018-04-19',
#  'US059613AC35': '2016-04-20',
#  'USP14623AC98': '2016-04-20',
#  'XS1798001449': '2018-04-19',
#  'FR0011637586': '2013-11-20',
#  'MYBVG1801761': '2018-04-25',
#  'HK0000416609': '2018-04-27',
#  'CND100016JY4': '2018-04-25',
#  'CND100016LR4': '2018-05-02',
#  'SE0007075122': '2015-05-12',
#  'NO0010852429': '2019-05-10',
#  'COB31CB00306': '2018-05-24',
#  'SE0011643329': '2019-05-15',
#  'TH0221031501': '2019-04-30',
#  'XS1412748136': '2016-05-19',
#  'SE0010599241': '2018-05-28',
#  'SE0010599233': '2018-05-28',
#  'CND100010K22': '2018-05-22',
#  'KR310221G855': '2018-05-29',
#  'US05463CAD48': '2016-05-23',
#  'XS1410341389': '2016-05-23',
#  'US50049GAB86': '2017-05-17',
#  'XS1618289802': '2017-05-16',
#  'XS1367229488': '2016-06-02',
#  'AU3CB0237683': '2016-05-25',
#  'XS1241581179': '2015-05-28',
#  'CND100010LR7': '2018-05-31',
#  'CND100010LB1': '2018-05-31',
#  'SE0008431720': '2016-06-02',
#  'XS1830915572': '2018-05-31',
#  'DE000GRN0008': '2016-06-01',
#  'SE0010599340': '2018-09-07',
#  'XS1831163396': '2018-06-05',
#  'XS1830984628': '2018-06-05',
#  'XS1839369300': '2018-06-13',
#  'XS1436518606': '2016-06-16',
#  'XS1436728916': '2016-06-16',
#  'SE0011062967': '2018-08-23',
#  'XS1253847815': '2015-06-23',
#  'XS1852213930': '2018-07-03',
#  'IDA0000926A8': '2018-06-06',
#  'SE0010832923': '2018-07-03',
#  'TW000G137046': '2019-07-02',
#  'CND10000CH30': '2016-07-07',
#  'FR0013188067': '2016-07-11',
#  'CND1000116Q1': '2018-07-05',
#  'XS1437622977': '2016-07-05',
#  'XS1437623355': '2016-07-05',
#  'CND100011246': '2018-07-10',
#  'COB07CB00595': '2018-07-18',
#  'CND100009ZG2': '2016-07-11',
#  'IT0005057770': '2014-10-21',
#  'XS1720639779': '2017-11-17',
#  'CND100017227': '2018-07-17',
#  'MYBVH1702215': '2017-07-27',
#  'AU0000XVGHK0': '2016-07-18',
#  'XS1566936180': '2017-06-15',
#  'INE003S07148': '2016-07-29',
#  'CND10001PSZ4': '2018-07-31',
#  'XS2036670607': '2019-07-30',
#  'XS1852560819': '2018-07-31',
#  'XS1655322102': '2017-07-25',
#  'XS1655322953': '2017-07-25',
#  'XS1467374473': '2016-08-03',
#  'INE918T07020': '2016-02-15',
#  'CND10001LZT1': '2018-08-13',
#  'XS1953912117': '2019-02-13',
#  'SE0010297275': '2017-08-22',
#  'SE0010832949': '2018-08-23',
#  'CND10001MX11': '2018-08-23',
#  'SE0011425834': '2018-08-23',
#  'CND10001MXY4': '2018-08-24',
#  'SE0011426089': '2019-02-15',
#  'SE0011426097': '2019-02-15',
#  'SE0012676476': '2019-08-26',
#  'NO0010780356': '2016-11-30',
#  'SE0011425875': '2018-08-30',
#  'SE0011425883': '2018-08-30',
#  'VNBVGD164973': '2016-09-08',
#  'XS1867060722': '2018-09-05',
#  'CND10002LPH5': '2018-09-10',
#  'CND10000L1T1': '2016-09-09',
#  'CND10000L222': '2016-09-14',
#  'HK0000525359': '2019-09-09',
#  'XS1866651471': '2018-09-13',
#  'US62630CAH43': '2016-09-27',
#  'XS1498532271': '2016-09-27',
#  'JP378900BJ98': '2018-09-14',
#  'MX94BA0A00F4': '2018-09-27',
#  'CH0495570944': '2019-08-29',
#  'XS1877506367': '2018-09-17',
#  'CND10000KSZ7': '2016-09-26',
#  'XS1566942071': '2017-09-20',
#  'XS1566942154': '2017-09-20',
#  'SE0009161615': '2016-09-26',
#  'XS2060619876': '2019-10-02',
#  'SE0009161607': '2016-09-26',
#  'XS1500337644': '2016-09-28',
#  'NO0010720972': '2014-09-25',
#  'SE0009164213': '2016-10-03',
#  'MYBVH1702934': '2017-10-04',
#  'SE0009161458': '2016-09-23',
#  'SE0009161441': '2016-09-23',
#  'XS1502438820': '2016-10-04',
#  'XS1566941859': '2017-10-11',
#  'CND10000KCJ5': '2016-09-30',
#  'XS2060692873': '2019-10-09',
#  'XS2061682188': '2019-10-10',
#  'SE0012193670': '2019-04-15',
#  'SE0009190606': '2016-10-11',
#  'SE0009190614': '2016-10-11',
#  'MX95FE040186': '2018-10-19',
#  'CND10000KT44': '2016-10-18',
#  'XS1986632716': '2019-04-17',
#  'XS1566942311': '2017-09-12',
#  'CND10001QN92': '2018-10-22',
#  'CND10001QPZ8': '2018-10-25',
#  'XS1130340091': '2014-10-23',
#  'SE0012676583': '2019-11-04',
#  'CND10001WM38': '2018-11-08',
#  'IDJ000015003': '2019-10-31',
#  'NO0010723265': '2014-11-04',
#  'XS1908898668': '2018-11-07',
#  'XS1716989287': '2017-11-07',
#  'SE0010599407': '2018-11-14',
#  'NZCEND0030L2': '2015-08-28',
#  'US63983TBK07': '2017-11-07',
#  'XS1711173218': '2017-11-09',
#  'NO0010809684': '2017-11-01',
#  'CND10001RSX5': '2018-11-13',
#  'XS1898122301': '2018-11-13',
#  'XS1898123374': '2018-11-13',
#  'XS1566943632': '2017-10-06',
#  'CND10000F3H0': '2016-11-15',
#  'CND10002LRW0': '2018-11-21',
#  'CND10001RTN4': '2018-11-19',
#  'CND10001RTM6': '2018-11-20',
#  'XS1901209376': '2018-11-19',
#  'HK0000545670': '2019-11-20',
#  'XS1899011784': '2018-11-22',
#  'SE0009357338': '2016-11-30',
#  'SE0009357007': '2016-11-21',
#  'US500769HD99': '2016-11-22',
#  'SE0009357320': '2016-11-30',
#  'MX90GC040000': '2016-12-07',
#  'CND10001T8V3': '2018-11-28',
#  'KR60298819C4': '2019-12-05',
#  'CH0419045809': '2019-11-08',
#  'CND10000G4C8': '2016-12-05',
#  'CND10001TMB0': '2018-11-30',
#  'DE000LB1M214': '2017-12-05',
#  'CND10001TMS4': '2018-12-06',
#  'CND10000G5V5': '2016-12-07',
#  'US843646AT75': '2016-11-10',
#  'XS1814404577': '2018-04-23',
#  'AU3CB0226090': '2014-12-04',
#  'XS1566946577': '2017-12-21',
#  'CND10001V5J0': '2018-12-20',
#  'CND10001V5K8': '2018-12-21',
#  'XS1334464606': '2017-12-28',
#  'DK0009523466': '2019-05-29',
#  'MYBUH1800052': '2018-01-04',
#  'SE0012676682': '2019-12-04',
#  'XS1917957687': '2019-01-14',
#  'CND10001XG35': '2019-01-24',
#  'JP319600AK10': '2019-01-10',
#  'MYBVH1800514': '2018-01-26',
#  'XS1939355753': '2019-01-22',
#  'CND10001XSP9': '2019-01-24',
#  'CND10001ZNB5': '2019-01-25',
#  'XS1940978163': '2019-01-31',
#  'NO0010842321': '2019-01-24',
#  'SE0011643154': '2019-01-29',
#  'XS1941844174': '2019-01-21',
#  'US64009VAA61': '2017-02-06',
#  'USV6277KAA26': '2017-02-06',
#  'XS1917357573': '2018-11-27',
#  'CND10000GK07': '2017-02-09',
#  'XS1567475303': '2017-02-10',
#  'SE0009606759': '2017-02-10',
#  'SE0009345630': '2016-11-15',
#  'SE0009345622': '2016-11-15',
#  'XS1940194753': '2019-01-17',
#  'MYBVG1900456': '2019-02-27',
#  'CND100020S55': '2019-02-21',
#  'FR0013239985': '2017-02-22',
#  'XS1732403925': '2017-12-04',
#  'XS1197336263': '2015-03-04',
#  'SE0009773203': '2017-03-15',
#  'CND100024G14': '2019-03-14',
#  'SE0010599100': '2018-03-20',
#  'SE0009773211': '2017-03-15',
#  'SE0010599118': '2018-03-20',
#  'CND1000250Y2': '2019-03-20',
#  'CND10002F9X2': '2019-03-25',
#  'XS1587035996': '2017-03-27',
#  'AU3FN0035317': '2017-03-28',
#  'AU3CB0243657': '2017-03-28',
#  'CND100025Q45': '2019-03-28',
#  'SE0011063163': '2018-03-27',
#  'MYBVI1702940': '2017-10-04',
#  'CND100025TR8': '2019-04-03',
#  'CND10000H691': '2017-04-13',
#  'CND100026Z27': '2019-04-16',
#  'XS1982691237': '2019-04-16',
#  'XS1982691070': '2019-04-16',
#  'XS1982690858': '2019-04-16',
#  'PEP11100M336': '2019-04-23',
#  'MYBVH1801751': '2018-04-25',
#  'CND10000H8V8': '2017-04-20',
#  'NZMELDT003C6': '2012-04-26',
#  'ZAG000158999': '2019-04-29',
#  'CND10000H8X4': '2017-04-27',
#  'DE000BHY0GP5': '2015-04-27',
#  'CND10000H8R6': '2017-05-02',
#  'US26442CAW47': '2018-11-05',
#  'CND10000JT96': '2017-05-11',
#  'SE0009921950': '2017-05-12',
#  'US06051GHH56': '2018-05-14',
#  'SE0007075130': '2015-05-12',
#  'SE0009947500': '2017-05-18',
#  'SE0009983802': '2017-05-17',
#  'SE0009983810': '2017-05-17',
#  'TH0221032509': '2019-04-30',
#  'SE0011974351': '2018-11-23',
#  'DE000LB2CJ96': '2019-05-21',
#  'XS1422841202': '2016-05-23',
#  'XS1527753187': '2016-11-24',
#  'XS1242327168': '2015-05-29',
#  'XS2007223709': '2019-05-28',
#  'XS1242327325': '2015-05-29',
#  'CND10002C045': '2019-05-29',
#  'CND10002C052': '2019-05-29',
#  'INE918T07038': '2016-12-20',
#  'SE0011062876': '2018-05-31',
#  'SE0010599282': '2018-06-07',
#  'INE316W07021': '2019-06-10',
#  'LV0010801775': '2016-04-14',
#  'LV0000801777': '2015-06-08',
#  'INE918T07046': '2019-06-10',
#  'XS1433082861': '2016-06-08',
#  'XS1238024035': '2015-06-03',
#  'CND10002GW01': '2019-06-11',
#  'XS1434560642': '2016-06-13',
#  'INE316W07013': '2016-12-20',
#  'XS1679505070': '2018-03-13',
#  'SE0010101626': '2017-06-15',
#  'SE0010101634': '2017-06-15',
#  'XS1636000561': '2017-06-16',
#  'XS1640493372': '2017-06-26',
#  'XS1490310064': '2017-05-22',
#  'MYBVG1901934': '2019-10-10',
#  'DK0004611993': '',
#  'XS2022165521': '2019-06-26',
#  'SE0012741064': '2019-07-05',
#  'US500630CQ96': '2017-06-27',
#  'TH3545032700': '2019-06-04',
#  'CND10002DK40': '2019-07-08',
#  'CND10002DCY5': '2019-07-11',
#  'CND10002DYF8': '2019-07-17',
#  'USN3700LAC92': '2017-07-17',
#  'US39530LAC46': '2017-07-17',
#  'US24023LAC00': '2017-07-18',
#  'US24023KAC27': '2017-07-18',
#  'CH0370943570': '2017-06-21',
#  'MYBVI1702205': '2017-07-27',
#  'USU3821WAA54': '2019-07-23',
#  'US41135WAA99': '2019-07-23',
#  'XS1943619558': '2019-01-23',
#  'TW000G102B09': '2019-08-12',
#  'TH3545032809': '2019-07-25',
#  'CND10002F543': '2019-08-14',
#  'XS1923123613': '2019-05-08',
#  'CND10000JRT4': '2017-08-18',
#  'CA30216BGV86': '2017-08-29',
#  'CND10000JSD6': '2017-09-05',
#  'XS1575474371': '2017-02-28',
#  'CND10002LRY6': '2019-09-09',
#  'CND10002G236': '2019-09-05',
#  'SE0010833020': '2018-09-07',
#  'XS2052134223': '2019-09-09',
#  'XS2052134652': '2019-09-09',
#  'CND10002G2M9': '2019-09-11',
#  'XS1685589027': '2017-09-12',
#  'JP348260AK93': '2019-09-13',
#  'JP2130002HA8': '2017-10-20',
#  'SE0010414425': '2017-09-19',
#  'SE0010414680': '2017-09-19',
#  'SE0010414698': '2017-09-19',
#  'USY7278TAF67': '2019-09-05',
#  'US75974LAA52': '2019-09-05',
#  'US500769HP20': '2017-09-27',
#  'PAL3009913A2': '2019-09-30',
#  'DK0009523110': '2019-05-02',
#  'TW000F154018': '2019-09-27',
#  'MYBVI1702957': '2017-10-04',
#  'XS1692377945': '2017-09-28',
#  'XS1697577556': '2017-10-04',
#  'XS1892240281': '2018-10-04',
#  'XS1697766951': '2017-10-04',
#  'XS1691909177': '2017-09-28',
#  'XS2057847050': '2019-10-09',
#  'SE0012676567': '2019-10-17',
#  'SE0010468900': '2017-10-12',
#  'SE0010469031': '2017-10-12',
#  'NO0010861883': '2019-08-30',
#  'XS2066776274': '2019-10-15',
#  'XS2066780466': '2019-10-15',
#  'CND10002K2W2': '2019-10-16',
#  'XS1057055060': '2014-04-08',
#  'PEP11100M351': '2019-10-22',
#  'ZAG000163726': '2019-10-22',
#  'XS2067132675': '2019-10-24',
#  'SE0010494823': '2017-10-19',
#  'XS1697899596': '2017-11-02',
#  'XS1861336250': '2018-07-27',
#  'US05502JAA88': '2017-07-27',
#  'USV00027AA65': '2017-07-27',
#  'HK0000536349': '2019-11-04',
#  'XS1711933033': '2017-10-30',
#  'NZCEND0040L1': '2016-02-13',
#  'XS1711039591': '2017-11-09',
#  'CND10002HWJ5': '2019-11-07',
#  'XS1566946650': '2017-11-09',
#  'XS1720540134': '2017-11-15',
#  'SE0010600262': '2017-11-21',
#  'TW000G124374': '2019-11-25',
#  'XS1725678277': '2017-11-21',
#  'XS2048590439': '2019-08-22',
#  'SE0010599027': '2017-11-28',
#  'XS1917719319': '2018-11-27',
#  'XS2069318686': '2019-11-28',
#  'AU3FN0051934': '2019-11-26',
#  'US63983TBP93': '2018-11-27',
#  'KR60298829C3': '2019-12-05',
#  'CND10002JLB1': '2019-12-03',
#  'SE0012676674': '2019-12-03',
#  'PAL0000321A3': '',
#  'JP362700AHC2': '2017-12-08',
#  'FR0013067170': '2015-12-02',
#  'SE0010599035': '2017-12-08',
#  'XS1725677030': '2017-12-15',
#  'CND10002K7X9': '2019-12-20',
#  'MYBVI1704102': '2017-12-28',
#  'CND10000LGZ0': '2017-12-27',
#  'MYBUI1800068': '2018-01-04',
#  'TW000B501576': '2018-01-03',
#  'SE0010766121': '2018-01-09',
#  'US064159QD10': '2019-07-15',
#  'XS1756110703': '2018-01-18',
#  'XS1756683659': '2018-01-16',
#  'SE0010830893': '2018-01-25',
#  'SE0012012698': '2019-01-25',
#  'XS1555168951': '2017-01-25',
#  'XS1758752635': '2018-01-19',
#  'MYBVI1800520': '2018-01-26',
#  'XS1713473947': '2018-01-26',
#  'XS1713474168': '2018-01-26',
#  'SE0012676591': '2019-10-31',
#  'MX95FE0401J4': '2019-11-21',
#  'XS2049154664': '2019-08-28',
#  'NO0010815822': '2018-02-05',
#  'US037833BU32': '2016-02-16',
#  'XS1770774021': '2018-02-07',
#  'SE0010947135': '2018-02-21',
#  'MYBVH1900447': '2019-02-27',
#  'FR0013284247': '2017-09-19',
#  'SE0010947143': '2018-02-21',
#  'US71567RAJ59': '2018-02-22',
#  'US71567PAJ93': '2018-02-22',
#  'SE0011869692': '2019-02-28',
#  'SE0010599092': '2018-03-08',
#  'ZAG000150137': '2018-03-08',
#  'ZAG000150111': '2018-03-08',
#  'NZMELDT016C8': '2016-03-07',
#  'XS1790099862': '2018-03-08',
#  'SE0011923267': '2019-03-14',
#  'SE0013042611': '2019-09-20',
#  'XS1800142330': '2018-03-22',
#  'XS1800143650': '2018-03-22',
#  'CND100010QH7': '2018-03-27',
#  'DK0009523037': '2019-05-02',
#  'MYBVJ1702963': '2017-10-04',
#  'CND10000LRW4': '2018-04-04',
#  'XS1972557737': '2019-04-08',
#  'XS1972559352': '2019-04-08',
#  'SE0011062793': '2018-04-10',
#  'SE0011062801': '2018-04-10',
#  'JP349980AJ44': '2018-04-11',
#  'NO0010790769': '2017-04-05',
#  'XS2081157401': '2019-11-13',
#  'US50046PBL85': '2019-11-13',
#  'SE0010494351': '2017-10-19',
#  'CND100016KY2': '2018-04-24',
#  'MYBVI1801742': '2018-04-25',
#  'AT0000A1Y6S4': '2017-09-29',
#  'SE0010832774': '2018-05-03',
#  'XS1798774656': '2018-05-08',
#  'COB31CB00314': '2018-05-24',
#  'JP375300AJ59': '2018-05-18',
#  'SE0011088822': '2018-05-17',
#  'XS1824244807': '2018-05-16',
#  'JP303971AJ59': '2018-05-11',
#  'NO0010823362': '2018-05-24',
#  'XS1897258098': '2018-10-16',
#  'XS1832452103': '2018-05-31',
#  'SE0010832873': '2018-06-05',
#  'XS1627778316': '2017-06-01',
#  'XS1830985278': '2018-06-05',
#  'XS2093119175': '2019-12-10',
#  'XS2093119845': '2019-12-12',
#  'US63254ABA51': '2018-06-11',
#  'XS1919458247': '2018-12-20',
#  'XS1839372601': '2018-06-13',
#  'JP389960AJ69': '2018-06-20',
#  'DE000LB1P9C8': '2018-06-18',
#  'SGXZ61262531': '2019-06-20',
#  'BE0002602804': '2018-06-25',
#  'NZAKCDT453C0': '2018-06-21',
#  'SE0012193753': '2019-06-24',
#  'XS1439531812': '2016-06-30',
#  'MYBVH1901940': '2019-10-10',
#  'XS1848875172': '2018-06-25',
#  'ES0200002022': '2017-06-28',
#  'IDA0000926B6': '2018-06-06',
#  'SE0012676435': '2019-07-02',
#  'SE0011231166': '2018-07-10',
#  'DE000DHY4978': '2018-07-02',
#  'COB07CB00603': '2018-07-18',
#  'CND10001LFM8': '2018-07-12',
#  'XS1858912915': '2018-07-16',
#  'US50064YAN31': '2018-07-18',
#  'USY4899GDC43': '2018-07-18',
#  'MYBVJ1702195': '2017-07-27',
#  'MYBVH1901494': '2019-08-06',
#  'CND10001PWR3': '2018-08-13',
#  'CND10001M0W5': '2018-08-08',
#  'US39530XAA28': '2016-08-10',
#  'USV3854PAA94': '2016-08-10',
#  'CND10000GN95': '2016-08-15',
#  'XS2046690827': '2019-08-20',
#  'XS1872032369': '2018-08-22',
#  'SE0011062942': '2018-08-23',
#  'SE0011062959': '2018-08-23',
#  'JP336270AJ81': '2018-08-24',
#  'MXCDNA0R0037': '2016-09-02',
#  'SE0010599316': '2018-08-29',
#  'SE0010599324': '2018-08-29',
#  'SE0011425842': '2018-08-27',
#  'AU3CB0256162': '2018-08-28',
#  'XS2050862262': '2019-09-04',
#  'JP397410BJ91': '2018-08-31',
#  'JP336270AJ99': '2018-08-24',
#  'SE0012193811': '2019-09-09',
#  'SE0010833012': '2018-09-05',
#  'US606822AH76': '2016-09-06',
#  'DK0030448238': '2019-06-13',
#  'JP2130002JA4': '2018-10-19',
#  'NO0010774797': '2016-09-16',
#  'DE000BHY0GU5': '2016-09-19',
#  'CND10000L1N4': '2016-09-22',
#  'IT0005346579': '2018-09-18',
#  'XS1879525654': '2018-09-11',
#  'XS1856795510': '2018-09-19',
#  'SE0012193894': '2019-09-25',
#  'XS1886399093': '2018-09-26',
#  'DE000DDA0NB1': '2018-09-25',
#  'SE0011643246': '2019-03-25',
#  'NO0010806862': '2017-09-25',
#  'MYBVJ1702971': '2017-10-04',
#  'XS1890709774': '2018-10-01',
#  'JP342495AJA4': '2018-10-05',
#  'CND10001TQ47': '2018-10-15',
#  'TW000G137012': '2018-10-02',
#  'DE000BHY0GH2': '2017-06-07',
#  'DE000CZ40NG4': '2018-10-16',
#  'SE0011063049': '2018-10-17',
#  'JP319000AJA1': '2018-10-19',
#  'JP387040BJA2': '2018-10-19',
#  'SE0010494757': '2017-10-19',
#  'JP302768AJB0': '2018-10-26',
#  'FI4000353909': '2018-11-02',
#  'JP382627AJB1': '2018-10-26',
#  'NO0010835192': '2018-10-26',
#  'XS2075800743': '2019-11-04',
#  'XS1716820029': '2017-11-06',
#  'TW000B903WU4': '2018-11-15',
#  'SE0011063056': '2018-11-13',
#  'CND10002LRX8': '2018-11-21',
#  'DE000DHY4887': '2017-11-16',
#  'SE0011088863': '2018-06-11',
#  'JP350220AJB3': '2018-11-22',
#  'CND10001TP30': '2018-11-27',
#  'FR0013385515': '2018-11-28',
#  'XS1915712233': '2018-11-28',
#  'CND10001WJG9': '2018-11-30',
#  'XS1732404063': '2017-12-04',
#  'XS1732400319': '2017-11-30',
#  'FR0013301066': '2017-12-07',
#  'XS1921553803': '2018-12-06',
#  'DE000MHB21J0': '2018-10-30',
#  'JP304776AJC9': '2018-12-07',
#  'JP378660AK21': '2019-02-22',
#  'SE0010599183': '2018-04-18',
#  'JP362700AJC8': '2018-12-07',
#  'XS1885967890': '2019-12-27',
#  'CND10001V5L6': '2018-12-21',
#  'MYBVJ1704118': '2017-12-28',
#  'INE528G08360': '2016-12-28',
#  'MYBUJ1800074': '2018-01-04',
#  'XS1818356484': '2019-06-28',
#  'SE0011870567': '2019-01-10',
#  'US015271AM12': '2018-06-12',
#  'SE0012012995': '2019-01-10',
#  'SE0012013001': '2019-01-10',
#  'SGXF33778741': '2019-01-09',
#  'XS1940840132': '2019-01-22',
#  'MYBVJ1800536': '2018-01-26',
#  'XS1979491559': '2019-04-05',
#  'XS1945126867': '2019-01-29',
#  'XS1946004451': '2019-01-28',
#  'AU3CB0266484': '2019-09-05',
#  'NO0010843121': '2019-02-08',
#  'SE0011973973': '2019-02-12',
#  'SE0012194165': '2019-02-06',
#  'SE0012256741': '2019-02-07',
#  'JP304627AK29': '2019-02-08',
#  'XS1953911812': '2019-02-18',
#  'XS1953035844': '2019-02-11',
#  'XS1953910764': '2019-02-13',
#  'XS1564443759': '2017-02-06',
#  'CND100020XB5': '2019-02-15',
#  'XS1951372777': '2019-02-27',
#  'CND100024YG4': '2019-02-25',
#  'XS1038708522': '2014-02-26',
#  'XS1956027277': '2019-02-19',
#  'XS1956022716': '2019-02-19',
#  'CH0419040917': '2019-01-29',
#  'XS1750056928': '2018-02-20',
#  'MYBVI1900437': '2019-02-27',
#  'SE0012011864': '2019-03-01',
#  'SE0010869156': '2018-02-02',
#  'CND100022R96': '2019-02-28',
#  'XS1960260021': '2019-03-01',
#  'XS1527758145': '2016-11-24',
#  'USY7275HAA69': '2019-03-05',
#  'US75973NAA28': '2019-03-05',
#  'CND10002D7J7': '2019-03-11',
#  'CND100023Q47': '2019-03-08',
#  'XS1963849440': '2019-03-12',
#  'NGAGB2024S08': '',
#  'NO0010789464': '2017-03-15',
#  'NZMELDT024C2': '2017-03-06',
#  'US690355BB70': '2016-01-28',
#  'AU000XQLQAD1': '2017-03-15',
#  'CND10002D6F7': '2019-03-25',
#  'XS1969611943': '2019-03-20',
#  'FR0013245859': '2017-03-15',
#  'XS1968465572': '2019-03-25',
#  'FR0013409265': '2019-03-26',
#  'XS1943443769': '2019-01-23',
#  'SE0011869767': '2019-03-19',
#  'XS1961891147': '2019-03-07',
#  'SE0012194116': '2019-04-04',
#  'MYBVK1702987': '2017-10-04',
#  'AU3CB0243681': '2017-03-30',
#  'XS1055718875': '2014-04-10',
#  'XS1979446843': '2019-04-08',
#  'CND100026715': '2019-04-03',
#  'JP319900AK41': '2019-04-05',
#  'SE0011062785': '2018-04-05',
#  'JP338860AK49': '2019-04-09',
#  'XS1808338542': '2018-04-10',
#  'CND100027BZ5': '2019-04-17',
#  'SE0012193688': '2019-04-15',
#  'JP363360BK41': '2019-04-05',
#  'AU3CB0262533': '2019-04-12',
#  'NO0010849979': '2019-04-09',
#  'XS1982691153': '2019-04-16',
#  'MYBVJ1801732': '2018-04-25',
#  'ZAG000159005': '2019-04-29',
#  'XS1989375412': '2019-04-30',
#  'CH0474178420': '2019-04-15',
#  'US059614AP21': '2017-05-02',
#  'USP14486AM92': '2017-05-02',
#  'SE0012454841': '2019-05-08',
#  'SE0012350973': '2019-05-14',
#  'XS1989704843': '2019-05-14',
#  'XS1955184590': '2019-02-18',
#  'DE000LB2CHW4': '2019-05-15',
#  'TH0221034505': '2019-04-30',
#  'XS1414146669': '2016-05-12',
#  'SE0011643378': '2019-05-22',
#  'SE0011869825': '2019-05-29',
#  'ZAG000116708': '2014-06-09',
#  'US75884RAT05': '2014-05-13',
#  'SE0011869841': '2019-06-11',
#  'XS2015229516': '2019-06-13',
#  'XS2015229862': '2019-06-18',
#  'XS2015238269': '2019-06-13',
#  'JP354565AK51': '2019-05-23',
#  'XS2015238855': '2019-06-13',
#  'XS1577956789': '2017-06-14',
#  'XS2013709220': '2019-06-14',
#  'SE0011869759': '2019-03-15',
#  'US500631AT37': '2019-06-17',
#  'USY4907LAA09': '2019-06-17',
#  'JP303971AK64': '2019-06-12',
#  'XS2016070430': '2019-06-18',
#  'TW000G110AG6': '2019-06-24',
#  'XS2002496409': '2019-06-17',
#  'XS1439448678': '2016-06-24',
#  'MYBVI1901955': '2019-10-10',
#  'XS2014454933': '2019-06-13',
#  'XS1084043451': '2014-06-26',
#  'JP304749AK71': '2019-07-03',
#  'XS2022179159': '2019-07-02',
#  'TW000G137053': '2019-07-05',
#  'JP304782AK79': '2019-07-05',
#  'US418751AA11': '2019-06-26',
#  'USU2467RAB51': '2019-09-10',
#  'USU2467RAA78': '2019-06-26',
#  'JP304088AK70': '2019-07-11',
#  'CND10002DXX3': '2019-07-16',
#  'XS2022227222': '2019-07-05',
#  'JP391980AK76': '2019-07-17',
#  'US39530LAB62': '2017-07-17',
#  'USN3700LAB10': '2017-07-17',
#  'AU3CB0265239': '2019-07-17',
#  'JP304716AK70': '2019-07-17',
#  'MYBVK1702185': '2017-07-27',
#  'XS2010185523': '2019-07-30',
#  'CA30216BHL95': '2019-07-24',
#  'JP304640AK71': '2019-07-23',
#  'CND10000HVK9': '2017-07-24',
#  'CND10000GGG0': '2016-07-29',
#  'MYBVI1901500': '2019-08-06',
#  'GB00BK5S2353': '2019-08-15',
#  'TH3545034805': '2019-07-25',
#  'NZCEND0050L0': '2019-02-22',
#  'US71567RAL06': '2019-02-12',
#  'US71567PAL40': '2019-02-12',
#  'SE0011643303': '2019-05-13',
#  'SE0011643311': '2019-05-13',
#  'XS2047500769': '2019-08-21',
#  'FR0013405537': '2019-02-21',
#  'AT0000A28XQ4': '2019-07-15',
#  'NO0010752702': '2015-12-02',
#  'XS2050923825': '2019-09-02',
#  'SE0012676484': '2019-09-03',
#  'CND10002LRZ3': '2019-09-09',
#  'XS2051470552': '2019-09-06',
#  'JP389320AK95': '2019-09-06',
#  'XS2052503872': '2019-09-12',
#  'XS2052134496': '2019-09-09',
#  'XS1550149204': '2017-01-09',
#  'XS1111084718': '2014-09-10',
#  'XS1913339690': '2018-11-19',
#  'XS1913343882': '2018-11-19',
#  'SE0012193845': '2019-09-10',
#  'NO0010871551': '2019-12-12',
#  'JP2130002KA2': '2019-10-18',
#  'XS2052453912': '2019-09-17',
#  'JP340700AK98': '2019-09-13',
#  'DE000GRN0016': '2017-09-19',
#  'PLPKOHP00132': '2019-06-10',
#  'PAL3009913B0': '2019-09-30',
#  'AT0000A239X8': '2018-08-30',
#  'SE0013103694': '2019-09-27',
#  'XS2057887353': '2019-09-24',
#  'XS2057888591': '2019-09-23',
#  'IT0005394892': '2019-12-11',
#  'TW000F154026': '2019-09-27',
#  'MYBVK1702995': '2017-10-04',
#  'SE0012676526': '2019-09-30',
#  'SE0012676542': '2019-09-30',
#  'SE0013103710': '2019-10-02',
#  'XS2063297423': '2019-10-10',
#  'JP397410BKA3': '2019-10-04',
#  'XS1694219780': '2017-10-04',
#  'USY52758AC63': '2019-04-08',
#  'US501955AA67': '2019-04-08',
#  'SE0012193662': '2019-04-11',
#  'XS1691909920': '2017-10-10',
#  'LV0000802353': '2017-10-05',
#  'SE0013103744': '2019-10-14',
#  'PEP50420M017': '2018-10-23',
#  'ZAG000163734': '2019-10-22',
#  'AT000B014782': '2019-10-02',
#  'JP304782AKB7': '2019-10-25',
#  'US693475AY16': '2019-10-29',
#  'XS1900633303': '2018-10-23',
#  'XS1900629616': '2018-10-25',
#  'ES0305079008': '2019-11-08',
#  'XS2070013250': '2019-11-01',
#  'XS2069980246': '2019-11-01',
#  'INE691I07DZ9': '2017-06-28',
#  'XS2081246337': '2019-11-12',
#  'XS1140300663': '2014-11-13',
#  'XS2057900552': '2019-11-13',
#  'XS1722859532': '2017-11-16',
#  'SE0010600270': '2017-11-21',
#  'JP373480BKB2': '2019-11-22',
#  'CND10002J313': '2019-11-25',
#  'US05351WAA18': '2017-11-16',
#  'PLPKOHP00199': '2019-12-02',
#  'XS2089368596': '2019-11-27',
#  'FR0013464930': '2019-11-26',
#  'XS1917601582': '2018-11-27',
#  'XS2089242064': '2019-11-27',
#  'CND10002HY24': '2019-11-28',
#  'SE0013103793': '2019-12-05',
#  'SE0013359494': '2019-11-29',
#  'SE0013103801': '2019-12-04',
#  'FR0013301074': '2017-12-08',
#  'DE000DHY4994': '2018-09-03',
#  'XS1854172043': '2019-03-31',
#  'US00654AAA43': '2019-03-31',
#  'XS1725553066': '2017-12-05',
#  'JP304877AKC3': '2019-12-06',
#  'JP335880AKC0': '2019-12-06',
#  'XS2092381107': '2019-12-05',
#  'XS2092381289': '2019-12-05',
#  'CND10002KQH5': '2019-12-13',
#  'XS2094608580': '2019-12-20',
#  'USV04008AA29': '2019-09-17',
#  'US05502TAA60': '2019-09-17',
#  'MYBVK1704124': '2017-12-28',
#  'MYBUK1800080': '2018-01-04',
#  'XS1756110968': '2018-01-19',
#  'USV3855GAA86': '2019-07-22',
#  'US39530VAA61': '2019-07-22',
#  'XS1760129608': '2018-01-23',
#  'MYBVK1800542': '2018-01-26',
#  'XS1188118100': '2015-02-04',
#  'US50048MBX74': '2015-02-04',
#  'NO0010815616': '2018-02-01',
#  'INE528G08279': '2015-02-16',
#  'MYBVJ1900427': '2019-02-27',
#  'NO0010869670': '2019-11-27',
#  'XS1575444622': '2017-02-28',
#  'NO0010870009': '2019-11-28',
#  'SE0012193944': '2019-12-09',
#  'XS1218319702': '2015-04-08',
#  'XS2072775765': '2019-10-25',
#  'XS2072775500': '2019-10-22',
#  'CL0002435833': '2018-03-15',
#  'US83417KAD00': '2015-03-16',
#  'US83417KAJ79': '2015-03-23',
#  'XS1794211786': '2018-03-15',
#  'XS1794213055': '2018-03-15',
#  'XS1794213642': '2018-03-15',
#  'XS1794209459': '2018-03-15',
#  'US83417KAP30': '2015-03-30',
#  'MYBVL1703009': '2017-10-04',
#  'US83417KAU25': '2015-04-06',
#  'XS1981060624': '2019-04-04',
#  'XS1595814465': '2017-04-04',
#  'BRTRPLDBS071': '2018-05-25',
#  'XS1808739459': '2018-04-11',
#  'US83417KAZ12': '2015-04-20',
#  'XS1984970373': '2019-04-15',
#  'XS1222743061': '2015-04-22',
#  'MYBVK1801722': '2018-04-25',
#  'US83417KBC18': '2015-04-27',
#  'CH0373476677': '2018-04-19',
#  'XS1820037270': '2018-05-03',
#  'US83417KBH05': '2015-05-11',
#  'XS1718393439': '2017-11-08',
#  'US83417KBM99': '2015-05-18',
#  'NO0010852692': '2019-05-14',
#  'NO0010822984': '2018-05-15',
#  'US83417KBR86': '2015-05-18',
#  'CH0461238906': '2019-11-08',
#  'US83417KBV98': '2015-05-26',
#  'US83417KBZ03': '2015-06-15',
#  'XS1839888754': '2018-06-12',
#  'US83417KCD81': '2015-06-15',
#  'XS1632897762': '2017-06-22',
#  'NZMELDT042C4': '2018-06-11',
#  'MYBVJ1901961': '2019-10-10',
#  'XS1612940558': '2017-05-09',
#  'US83417KCH95': '2015-06-22',
#  'XS1818356302': '2019-06-28',
#  'XS2024769619': '2019-07-02',
#  'NZAKCDT484C5': '2019-07-01',
#  'US83417KCN63': '2015-07-13',
#  'BRRANIDBS023': '2019-08-02',
#  'XS1937665955': '2019-01-14',
#  'CA33829XAA50': '2015-07-21',
#  'US83417KCT34': '2015-07-13',
#  'MYBVL1702175': '2017-07-27',
#  'INE528G08295': '2015-08-04',
#  'US83417KCY29': '2015-07-20',
#  'MYBVJ1901516': '2019-08-06',
#  'XS1659112616': '2017-07-31',
#  'US83417KDD72': '2015-08-03',
#  'AU3CB0265700': '2019-08-08',
#  'AU3FN0049490': '2019-08-07',
#  'US83417KDJ43': '2015-08-10',
#  'MX91VI050060': '2018-08-31',
#  'US83417KDP03': '2015-08-17',
#  'XS2046731365': '2019-02-20',
#  'XS2066574489': '2019-10-14',
#  'XS2049414167': '2019-08-26',
#  'SE0010832956': '2018-08-24',
#  'XS1284550941': '2015-08-26',
#  'US83417KDU97': '2015-08-24',
#  'XS1676952481': '2017-08-30',
#  'XS1867412006': '2018-09-05',
#  'XS1490726590': '2016-09-08',
#  'US83417KDZ84': '2015-08-31',
#  'PTGRPAOM0012': '2019-09-23',
#  'XS2054601369': '2019-09-17',
#  'XS2054601443': '2019-09-17',
#  'US83417KEE47': '2015-09-14',
#  'CH0494734426': '2019-09-04',
#  'MYBVL1703017': '2017-10-04',
#  'US690353D959': '2015-03-10',
#  'US690353L705': '2016-01-28',
#  'US690353K301': '2015-11-09',
#  'US268317AS33': '2015-10-07',
#  'USF2893TAS53': '2015-10-08',
#  'XS1893621026': '2018-10-09',
#  'US83417KEK07': '2015-10-13',
#  'XS2067135421': '2019-10-14',
#  'DE000BHY0GC3': '2018-10-12',
#  'JP344040AJA6': '2018-10-19',
#  'XS1784701911': '2018-10-03',
#  'SE0012676575': '2019-10-24',
#  'US83417KEQ76': '2015-10-13',
#  'DE000NWB0AC0': '2015-11-03',
#  'SE0011870021': '2019-11-08',
#  'US83417KEV61': '2015-11-16',
#  'FR0013459435': '2019-11-21',
#  'XS1910934709': '2018-11-20',
#  'XS2084421986': '2019-11-20',
#  'XS2084423925': '2019-11-22',
#  'US843646AM23': '2015-11-12',
#  'US83417KFA16': '2015-11-16',
#  'XS1924319301': '2018-12-21',
#  'US83417KFF03': '2015-11-30',
#  'XS2083187059': '2019-12-19',
#  'MYBVL1704130': '2017-12-28',
#  'US83417KFL70': '2015-12-14',
#  'USN4580HAA51': '2018-11-08',
#  'US45685NAA46': '2018-11-08',
#  'MYBUL1800096': '2018-01-04',
#  'US83417KFR41': '2015-12-28',
#  'XS1891174341': '2019-01-11',
#  'XS1912388854': '2019-01-18',
#  'HK0000477320': '2019-01-18',
#  'DE000DHY4895': '2018-01-10',
#  'MYBVL1800557': '2018-01-26',
#  'XS1951192795': '2019-02-13',
#  'MYBVK1900417': '2019-02-27',
#  'XS1962536451': '2019-03-06',
#  'US63983TBB08': '2016-03-18',
#  'XS1386139841': '2016-03-18',
#  'NZARGDT001C6': '2019-03-06',
#  'US373334KE00': '2016-03-02',
#  'MYBVM1702876': '2017-10-04',
#  'XS1980270810': '2019-04-03',
#  'XS1981094102': '2019-04-04',
#  'XS1982037696': '2019-04-08',
#  'US015271AP43': '2019-03-12',
#  'XS1799545329': '2018-04-12',
#  'XS1398476793': '2016-04-14',
#  'XS1400167133': '2016-04-18',
#  'MYBVL1801712': '2018-04-25',
#  'ZAG000159013': '2019-04-29',
#  'ES0200002030': '2018-04-23',
#  'FR0011911247': '2014-05-12',
#  'FR0013170834': '2016-05-09',
#  'NO0010852684': '2019-05-14',
#  'NO0010867823': '2019-10-30',
#  'JP304554AK59': '2019-05-08',
#  'TH0221036500': '2019-04-30',
#  'XS2003499386': '2019-05-24',
#  'FR0013465358': '2019-11-27',
#  'XS1432384664': '2016-06-06',
#  'XS1435056426': '2016-06-13',
#  'XS2013745703': '2019-06-21',
#  'XS2009891479': '2019-06-13',
#  'MYBVK1901977': '2019-10-10',
#  'US95709TAN00': '2016-06-13',
#  'XS2026171079': '2019-07-04',
#  'USA9890AAA81': '2016-07-07',
#  'US05674XAA90': '2016-07-07',
#  'JP345520AK79': '2019-07-09',
#  'XS1453462076': '2016-07-14',
#  'MYBVM1702165': '2017-07-27',
#  'US39530VAB45': '2019-07-22',
#  'DE000LB2CLH7': '2019-07-17',
#  'USV3855GAB69': '2019-07-22',
#  'DE000DHY5041': '2019-07-09',
#  'TW000G138010': '2019-07-30',
#  'MYBVK1901522': '2019-08-06',
#  'XS2036691868': '2019-08-05',
#  'US690353K228': '2015-10-30',
#  'JP354565AK85': '2019-08-23',
#  'XS2047497289': '2019-08-22',
#  'SE0012193829': '2019-09-09',
#  'XS2051032444': '2019-09-04',
#  'XS2034715305': '2019-07-23',
#  'JP376280AG96': '2016-09-09',
#  ...}

# %%
green_bonds['First Announcement Date'] = green_bonds.ISIN.map(isin_to_date)

# %%
sum(green_bonds['First Announcement Date'].isna())
# Out:
# 17

# %% [raw]
# # get {Preferred RIC: First Announcement Date} to get missing announcement dates
# rics_to_dates = dict(zip(green_bonds['Preferred RIC'], green_bonds['First Announcement Date']))

# %% [raw]
# missing_RICS = set(green_bonds[green_bonds['First Announcement Date'].isna()]['Preferred RIC'])

# %%
#missing_RICS = [ric for ric in missing_RICS if isinstance(ric, str)]
bonds, err = ek.get_data(green_bonds[green_bonds['First Announcement Date'].isna(
)]['Preferred RIC'].dropna().to_list(), 'TR.FirstAnnounceDate')

# %%
rics_to_dates = dict(
    zip(bonds['Instrument'], bonds['First Announcement Date']))

# %%
rics_to_dates
# Out:
# {'CN114265SZ=': '2017-12-01',
#  'CN143952SH=': '2018-03-07',
#  'CN150502SH=': '2018-06-21',
#  'CN150701SH=': '2018-11-07',
#  'CN155057SH=': '2018-11-29',
#  'CN155956SH=': '2019-02-27',
#  'CN143518SH=': '2018-03-14',
#  'CN143745SH=': '2018-07-31',
#  'CN143525SH=': '2018-08-15',
#  'CN150646SH=': '2018-08-21',
#  'CN143822SH=': '2018-09-17',
#  'CN114375SZ=': '2018-09-20',
#  'CN114415SZ=': '2018-12-19',
#  'CN151739SH=': '2019-06-27',
#  'CN151819SH=': '2019-07-11',
#  'CN163044SH=': '2019-11-28'}

# %%
sum(green_bonds['First Announcement Date'].isna())
# Out:
# 1

# %%
green_bonds['First Announcement Date'] = green_bonds['First Announcement Date'].fillna(
    green_bonds['Preferred RIC'].map(rics_to_dates))

# %%
green_bonds['First Announcement Date']
# Out:
# 0       2019-02-05
# 1       2016-09-01
# 2       2019-11-26
# 3       2017-09-08
# 4       2019-01-02
#            ...
# 1866    2015-03-20
# 1867    2015-11-30
# 1868    2016-10-28
# 1869    2017-07-26
# 1870    2015-05-18
# Name: First Announcement Date, Length: 1871, dtype: object

# %%
green_bonds.IsPublic = green_bonds.IsPublic.astype(bool)

# %%
green_bonds.to_csv('cleaned_green_bonds.csv', index=False)
